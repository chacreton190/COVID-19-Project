# %% [markdown]
# # New Analysis Notebook
#
# ### To Do:
# 1. [ ] Merge in the COVID State level control measures
# - [ ] ffill the COVID control measures
# - [ ] Research the query system here, [FDOH Open Data](https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/state_daily_testing/FeatureServer/0/query?where=3%3D3&objectIds=&time=&resultType=none&outFields=*&returnIdsOnly=true&returnUniqueIdsOnly=false&returnCountOnly=false&returnDistinctValues=false&cacheHint=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=&sqlFormat=none&f=html&token=) [ALT Link](https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/state_daily_testing/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json) it seems like you will be able to get out the county level, daily testing numbers
# - [ ] Remember to deal with:
# - - counties listed as unknown. They should not be included in your analysis
# - - Cases not dx'd or isolated in FL

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns
rcParams['figure.figsize'] =15 ,9
import numpy as np
import seaborn as sns
import datetime
from matplotlib.pyplot import figure
import os
from pathlib import Path
import shutil
import missingno as msno
import json
import requests
import timeit
qa_path = '../data/QA Checks/'
graphics_path = '../Graphics/'
data_path = '../data/'
log_path = f'{data_path}covid data/Log of Last ObsID.txt'
line_list_path = f'{data_path}covid data/Case Line List/FLORIDA COVID COMPLETE CASE LINE LIST.xlsx'
code_path = os.getcwd()
today = datetime.date.today()
mon = today.month
day = today.day
year = today.year
date_today = f'{mon}-{day}-{year}'
p1 = pd.to_datetime('05/04/2020')# start phase1
p2 = pd.to_datetime('06/03/2020')# start phase2
p3 = pd.to_datetime('09/25/2020')# start phase3
def stats_col_renamer(dframe):  
    dframe.columns = dframe.columns.str.lower()
    dframe.columns = dframe.columns.str.replace('\s{2,}',' ',regex=True).str.replace('-',' ').str.replace(' ','_').str.replace('[^A-Za-z0-9_]+','',regex=True)
    return dframe

# %% [markdown]
# # Importing COVID Line List Data

# %% [markdown]
# Time in the original data set is in the format 'ms' in pandas see [epoch unix](https://www.unixtimestamp.com/index.php)

# %%
with open(log_path, 'r') as log:
    for lines in log:
        last_obs_read = int(lines.replace('Last ID Number Read: ',''))

# %%
ids_url = r'https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/Florida_COVID19_Case_Line_Data_NEW/FeatureServer/0/query?where=1%3D1&outFields=*&returnIdsOnly=true&outSR=4326&f=json'
ids = requests.get(ids_url).json()
id_n = len(list(ids['objectIds']))

if os.path.exists(log_path):
    with open(log_path, 'r') as log:
        for lines in log:
            last_obs_read = int(lines.replace('Last ID Number Read: ',''))
    min_obs = last_obs_read + 1
    id_n = len(list(ids['objectIds'])) - last_obs_read
else:
    min_obs = 1
    id_n = len(list(ids['objectIds']))
max_obs = min_obs + 1999
line_url = f'https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/Florida_COVID19_Case_Line_Data_NEW/FeatureServer/0/query?where=ObjectId%20%3E%3D%201%20AND%20ObjectId%20%3C%3D%202000&outFields=*&outSR=4326&f=json'
line_list_json = requests.get(line_url).json()
cols = list(line_list_json['features'][0]['attributes'].keys())
if id_n%2000 >0:
    iters = (id_n // 2000) + 1
else:
    iters = id_n // 2000
df = pd.DataFrame(columns=cols)

# %%
df
# Out:
# Empty DataFrame
# Columns: [County, Age, Age_group, Gender, Jurisdiction, Travel_related, Origin, EDvisit, Hospitalized, Died, Case_, Contact, Case1, EventDate, ChartDate, ObjectId]
# Index: []

# %% [markdown]
# ### Creating the Data Set Containing the New Records

# %%
start = timeit.default_timer()
if id_n == 0:
    print('No new records found.')
    df.drop(columns=['ObjectId','Case1'],inplace=True)
else:
    print(f'{id_n} New records Found')
    print(f'This update will take {iters} iterations to complete')
    input('Press Enter to start the update.\n>>')
    for iterations in range(0,iters):
        line_url = f'https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/Florida_COVID19_Case_Line_Data_NEW/FeatureServer/0/query?where=ObjectId%20%3E%3D%20{min_obs}%20AND%20ObjectId%20%3C%3D%20{max_obs}&outFields=*&outSR=4326&f=json'
        line_list_json = requests.get(line_url).json()
        max_obs += 2000
        min_obs += 2000
        #Creating the Temporary Line List
        line_list_df_temp = pd.DataFrame.from_dict(line_list_json['features'][0])
        line_list_df_temp = line_list_df_temp.T
        for rows in range(1,len(line_list_json['features'])):
            row_df = pd.DataFrame.from_dict(line_list_json['features'][rows])
            row_df = row_df.T
            line_list_df_temp = pd.concat([line_list_df_temp,row_df])
        df = pd.concat([df,line_list_df_temp])
        line_url = f'https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/Florida_COVID19_Case_Line_Data_NEW/FeatureServer/0/query?where=ObjectId%20%3E%3D%20{min_obs}%20AND%20ObjectId%20%3C%3D%20{max_obs}&outFields=*&outSR=4326&f=json'
        stop = timeit.default_timer()
    print(f'Runtime: {round((stop - start)/60,3)} Minutes')
    df.reset_index(inplace=True)
    #case1 dropped because it is completely redundate with chartdate
    df.drop(columns=['index','ObjectId','Case1'],inplace=True)
    with open(f'{data_path}covid data/Log of Last ObsID.txt','w') as log:
        log.write(f'Last ID Number Read: {df.ObjectId.max()}')
df.columns = df.columns.str.lower()
df.contact = df.contact.str.upper()
df.contact = df.contact.str.upper()
df.eventdate = pd.to_datetime(df.eventdate ,unit='ms').dt.date
df.chartdate = pd.to_datetime(df.chartdate,unit='ms').dt.date
# Out:
# No new records found.

# %%
df.chartdate.max()
# Out:
# datetime.date(2020, 10, 30)

# %%
df = line_list.copy()

# %%
line_list = df.copy()
# del df

# %%
# line_list = pd.read_excel(line_list_path)
# line_list = pd.concat([line_list,df])
# line_list.to_excel(line_list_path,index=False)

# %%
counties = line_list.county.unique()

# %%
counties.sort()
counties
# Out:
# array(['Alachua', 'Baker', 'Bay', 'Bradford', 'Brevard', 'Broward',
#        'Calhoun', 'Charlotte', 'Citrus', 'Clay', 'Collier', 'Columbia',
#        'Dade', 'Desoto', 'Dixie', 'Duval', 'Escambia', 'Flagler',
#        'Franklin', 'Gadsden', 'Gilchrist', 'Glades', 'Gulf', 'Hamilton',
#        'Hardee', 'Hendry', 'Hernando', 'Highlands', 'Hillsborough',
#        'Holmes', 'Indian River', 'Jackson', 'Jefferson', 'Lafayette',
#        'Lake', 'Lee', 'Leon', 'Levy', 'Liberty', 'Madison', 'Manatee',
#        'Marion', 'Martin', 'Monroe', 'Nassau', 'Okaloosa', 'Okeechobee',
#        'Orange', 'Osceola', 'Palm Beach', 'Pasco', 'Pinellas', 'Polk',
#        'Putnam', 'Santa Rosa', 'Sarasota', 'Seminole', 'St. Johns',
#        'St. Lucie', 'Sumter', 'Suwannee', 'Taylor', 'Union', 'Unknown',
#        'Volusia', 'Wakulla', 'Walton', 'Washington'], dtype=object)

# %%
line_list.reset_index(inplace =True)

# %%
line_list
# Out:
#              index      county age    age_group  gender jurisdiction  \
# 0       attributes  Palm Beach  32  25-34 years    Male  FL resident
# 1       attributes      Putnam  12   5-14 years    Male  FL resident
# 2       attributes    Escambia  37  35-44 years    Male  FL resident
# 3       attributes    Seminole  52  45-54 years    Male  FL resident
# 4       attributes   St. Johns  29  25-34 years    Male  FL resident
# ...            ...         ...  ..          ...     ...          ...
# 802542  attributes     Osceola  51  45-54 years  Female  FL resident
# 802543  attributes     Osceola  64  55-64 years    Male  FL resident
# 802544  attributes     Osceola  20  15-24 years    Male  FL resident
# 802545  attributes     Broward  21  15-24 years  Female  FL resident
# 802546  attributes        Polk  65  65-74 years    Male  FL resident
#
#        travel_related origin  edvisit hospitalized died case_  contact  \
# 0                  No     NA       NO           NO   NA   Yes      YES
# 1                  No     NA       NO           NO   NA   Yes      YES
# 2                  No     NA       NO           NO   NA   Yes  UNKNOWN
# 3             Unknown     NA  UNKNOWN      UNKNOWN   NA   Yes       NA
# 4                  No     NA  UNKNOWN      UNKNOWN   NA   Yes      YES
# ...               ...    ...      ...          ...  ...   ...      ...
# 802542             No     NA       NO           NO   NA   Yes      YES
# 802543             No     NA       NO           NO   NA   Yes      YES
# 802544             No     NA       NO           NO   NA   Yes      YES
# 802545        Unknown     NA  UNKNOWN      UNKNOWN   NA   Yes  UNKNOWN
# 802546             No     NA       NO           NO   NA   Yes      YES
#
#          eventdate   chartdate
# 0       2020-07-28  2020-07-29
# 1       2020-07-28  2020-07-29
# 2       2020-07-17  2020-07-29
# 3       2020-07-08  2020-07-29
# 4       2020-07-28  2020-07-29
# ...            ...         ...
# 802542  2020-06-27  2020-07-31
# 802543  2020-07-09  2020-07-31
# 802544  2020-07-06  2020-07-31
# 802545  2020-07-24  2020-07-31
# 802546  2020-07-23  2020-08-07
#
# [802547 rows x 15 columns]

# %%
line_list.drop(columns='index',inplace=True)

# %%
line_list.head()
# Out:
#                 county age    age_group gender jurisdiction travel_related  \
# attributes  Palm Beach  32  25-34 years   Male  FL resident             No
# attributes      Putnam  12   5-14 years   Male  FL resident             No
# attributes    Escambia  37  35-44 years   Male  FL resident             No
# attributes    Seminole  52  45-54 years   Male  FL resident        Unknown
# attributes   St. Johns  29  25-34 years   Male  FL resident             No
#
#            origin  edvisit hospitalized died case_  contact   eventdate  \
# attributes     NA       NO           NO   NA   Yes      YES  2020-07-28
# attributes     NA       NO           NO   NA   Yes      Yes  2020-07-28
# attributes     NA       NO           NO   NA   Yes  UNKNOWN  2020-07-17
# attributes     NA  UNKNOWN      UNKNOWN   NA   Yes       NA  2020-07-08
# attributes     NA  UNKNOWN      UNKNOWN   NA   Yes      Yes  2020-07-28
#
#              chartdate
# attributes  2020-07-29
# attributes  2020-07-29
# attributes  2020-07-29
# attributes  2020-07-29
# attributes  2020-07-29

# %% [markdown]
# # Old Data Import

# %%
# line_path = f'{data_path}covid data/case line list/'

# %%
# line_list = pd.read_excel(f'{line_path}/FLORIDA COVID COMPLETE CASE LINE LIST 10-30-2020.xlsx')
line_list.columns = line_list.columns.str.lower()

# %%
line_list.shape
# Out:
# (802547, 16)

# %%
line_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802547 entries, attributes to attributes
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   county          802547 non-null  object
#  1   age             802547 non-null  object
#  2   age_group       802547 non-null  object
#  3   gender          802547 non-null  object
#  4   jurisdiction    802547 non-null  object
#  5   travel_related  802547 non-null  object
#  6   origin          802547 non-null  object
#  7   edvisit         781597 non-null  object
#  8   hospitalized    799217 non-null  object
#  9   died            802547 non-null  object
#  10  case_           802547 non-null  object
#  11  contact         802547 non-null  object
#  12  case1           802547 non-null  object
#  13  eventdate       802547 non-null  object
#  14  chartdate       802547 non-null  object
#  15  objectid        802547 non-null  object
# dtypes: object(16)
# memory usage: 104.1+ MB

# %%
line_list['date'] = pd.to_datetime(line_list.eventdate)
line_list.case1 = pd.to_datetime(line_list.case1).dt.date
line_list.chartdate = pd.to_datetime(line_list.chartdate).dt.date
line_list['week'] = line_list.date.dt.weekofyear
line_list['month'] = line_list.date.dt.month
line_list.date = line_list.date.dt.date
line_list_death = line_list.loc[line_list.died =='Yes']


#Creating Daily case counts
case_count = line_list.groupby(['county','date']).case_.value_counts().to_frame()
case_count.rename(columns={'case_':'case_count'},inplace=True)
case_count.reset_index(inplace=True)
case_count.drop(columns='case_',inplace=True)

#Creating Weekly Case Counts
case_count_week = line_list.groupby(['county','week']).case_.value_counts().to_frame()
case_count_week.rename(columns={'case_':'case_count'},inplace=True)
case_count_week.reset_index(inplace=True)
case_count_week.drop(columns='case_',inplace=True)

#Creating Daily Death Counts
death_count = line_list_death.groupby(['county','date']).case_.value_counts().to_frame()
death_count.rename(columns={'case_':'death_count'},inplace=True)
death_count.reset_index(inplace=True)
death_count.drop(columns='case_',inplace=True)

#Creating Weekly Death Counts
death_count_week = line_list_death.groupby(['county','week']).case_.value_counts().to_frame()
death_count_week.rename(columns={'case_':'death_count'},inplace=True)
death_count_week.reset_index(inplace=True)
death_count_week.drop(columns='case_',inplace=True)

# %%
line_list.head(50)

# %%
covid_daily = case_count.merge(death_count,on=['county','date'],how='outer')
covid_weekly = case_count_week.merge(death_count_week,on=['county','week'],how='outer')

# %%
fl_daily = covid_daily.groupby('date')[['case_count','death_count']].sum().reset_index()
fl_weekly = covid_weekly.groupby('week')[['case_count','death_count']].sum().reset_index()

# %%
fl_weekly

# %%
sns.lineplot(x='date', y='case_count', data=case_count,hue= 'county',legend=False)
plt.title('Florida COVID Daily Case Count by County (Line List Data)')

# %%
county = 'Hillsborough'
win=7
c = covid_daily.loc[covid_daily.county==county]
max_death = c.death_count.max() +10
ax = sns.lineplot(x='date', y='death_count', data=c,label=f'{county} County Death Count',c='black')
ax2 = ax.twinx()
ax.set_ylim(0,max_death)
sns.lineplot(x='date', y='case_count', data=c,label=f'{county} County Case Count')
mean_case = c.set_index('date').case_count.rolling(window=win).mean()
mean_case.plot(color='orange',label=f'{win}-day Mean Case Count')
plt.legend(loc='center right')
plt.title(f'Florida COVID Daily Case Count for {county} County (Line List Data)')

# %%
c = covid_daily.loc[covid_daily.county==county]
mean_death = c.set_index('date').death_count.rolling(window=win).mean()
mean_death.plot(color='green',label=f'{win}-day Mean Case Count')
sns.lineplot(x='date', y='death_count', data=c,label=f'{county} County Death Count',c='black')
plt.title(f'Florida COVID Daily Deaths Count for {county} County (Line List Data)')

# %%
fl_daily

# %%
# covid_daily.groupby('date').case_count.sum().plot()
sns.lineplot( x='date', y='case_count', data = fl_daily)
mean_case = fl_daily.set_index('date').case_count.rolling(window=win).mean()
mean_case.plot(color='orange',label=f'{win}-day Mean Case Count')
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.legend()
plt.ylabel('Total Case Count')
plt.title(f'Florida COVID Total Daily Case Count')

# %%
covid_daily.groupby('date').death_count.sum()

# %%
covid_daily.groupby('date').death_count.sum().plot()
sns.lineplot(  x='',c='black',data=covid_daily.groupby('date').death_count.sum(), label='Death Count')
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.legend()
plt.ylabel('Total Case Count')
plt.title(f'Florida COVID Total Daily Death Count')

# %%
line_list.shape

# %%
pop = pd.read_excel(f'{data_path}census/Florida Population Estimates 2020.xlsx')
pop.drop(columns='GrowthRate',inplace=True)
pop.county = pop.county.str.upper()

# %%
df['phase'] = 0
df.loc[df.date >= p1, 'phase'] = 1
df.loc[df.date >= p2, 'phase'] = 2
df.loc[df.date >= p3, 'phase'] = 3
df.sort_values(by=['county','date'],inplace=True)

# %%
df['phase1'] = 0
df['phase2'] = 0 
df['phase3'] = 0
df.loc[(df.date >= p1) & (df.date < p2),'phase1'] = 1
df.loc[(df.date >= p2) & (df.date < p3),'phase2'] = 1
df.loc[df.date >= p3 ,'phase3'] = 1

# %%
df.phase1.value_counts()

# %%
df.phase1.value_counts()

# %%
df[['daily_neg_count','daily_case_count','daily_test_count']] = df.groupby('county')[['negative','positive','total_tested']].apply(lambda x: x-x.shift(1))

# %%
df.date.max()

# %%
url = 'https://raw.githubusercontent.com/OxCGRT/USA-covid-policy/master/data/OxCGRT_US_subnational_05Aug2020.csv'
cont = pd.read_csv(url, index_col=0)
cont = stats_col_renamer(cont)

# %%
fl = cont.loc[cont.regionname == 'Florida'].copy()

# %%
flags = [x for x in fl.columns if x.find('flag') >= 0]
noflags = [x for x in fl.columns if x.find('flag') <= 0 and x.find('notes') <= 0]

# %%
flags
for flag in flags:
    fl[flag].fillna(0,inplace=True)
# or
# fl[['c1_flag', 'c2_flag', 'c3_flag', 'c4_flag', 'c6_flag', 'c7_flag']].fillna(0,inplace=True)

# %%
fl.reset_index(inplace=True)
fl.drop(columns=['e1_income_support','CountryName', 'countrycode','regioncode',
       'e1_flag', 'e1_notes', 'e2_debtcontract_relief', 'e2_notes',
       'e3_fiscal_measures', 'e3_notes', 'e4_international_support',
       'e4_notes', 'h1_public_information_campaigns', 'h1_flag', 'h1_notes',
       'h2_testing_policy', 'h2_notes', 'h3_contact_tracing', 'h3_notes',
       'h4_emergency_investment_in_healthcare', 'h4_notes',
       'h5_investment_in_vaccines', 'h5_notes', 'm1_wildcard', 'm1_notes',
       'confirmedcases', 'confirmeddeaths', 'stringencyindex',
       'stringencyindexfordisplay', 'stringencylegacyindex',
       'stringencylegacyindexfordisplay', 'governmentresponseindex',
       'governmentresponseindexfordisplay', 'containmenthealthindex',
       'containmenthealthindexfordisplay', 'economicsupportindex',
       'economicsupportindexfordisplay','jurisdiction'],inplace=True)
fl.dropna(axis=1,how='all',inplace=True)
fl.date = pd.to_datetime(fl.date,format= '%Y%m%d')

# %%
fl.columns

# %% [markdown]
# # this should take care of to do item 1

# %%
d1 = covid_daily.merge(fl,on='date',how='outer')

# %%
d1 = d1.merge(pop,on='county',how='outer')

# %%
d1.sort_values(by=['county','date'],inplace=True)

# %%
d1.columns

# %%
d1[[ 'c1_school_closing', 'c2_workplace_closing', 'c3_cancel_public_events', 'c4_restrictions_on_gatherings',
 'c5_close_public_transport',  'c6_stay_at_home_requirements', 'c7_restrictions_on_internal_movement',
 'c8_international_travel_controls']] = d1.groupby('county')[[ 'c1_school_closing', 'c2_workplace_closing', 'c3_cancel_public_events', 'c4_restrictions_on_gatherings',
 'c5_close_public_transport',  'c6_stay_at_home_requirements', 'c7_restrictions_on_internal_movement',
 'c8_international_travel_controls']].apply(lambda x: x.ffill())

# %%
d1[['s0101_c01_032e',
       's1501_c02_002e', 's1501_c02_009e', 's1901_c01_012e', 'dp05_0001e',
       'dp05_0037pe', 'dp05_0038pe', 'dp05_0039pe', 'dp05_0044pe',
       'dp05_0052pe']] = d1[['s0101_c01_032e',
       's1501_c02_002e', 's1501_c02_009e', 's1901_c01_012e', 'dp05_0001e',
       'dp05_0037pe', 'dp05_0038pe', 'dp05_0039pe', 'dp05_0044pe',
       'dp05_0052pe']].fillna(np.nan)

# %%
d1.drop(columns=['s0101_c01_032e',
       's1501_c02_002e', 's1501_c02_009e', 's1901_c01_012e', 'dp05_0001e',
       'dp05_0037pe', 'dp05_0038pe', 'dp05_0039pe', 'dp05_0044pe',
       'dp05_0052pe'],inplace=True)

# %%
d1.date = d1.date.dt.date

# %%
d1.to_excel(f'{data_path}NEW Data Set (Oxford Control Measures).xlsx')

# %% [markdown]
# # Trend Analysis

# %%
sns.lineplot(x = 'date', y ='daily_case_count', hue = 'county', data = d1,legend=False)
plt.title('Florida COVID-19 Daily Case Count by Country')

# %%
df_indexed = d1.set_index('date')

# %%
rolmean_case = df_indexed.daily_case_count.rolling(window=7).mean()
rolstd_case = df_indexed.daily_case_count.rolling(window=7).std()
rolmean_case.plot(label='Rolling Mean')
rolstd_case.plot( label='Rolling STD')
plt.legend(loc='best')
plt.title('Florida COVID-19 Daily 7-Day Rolling Mean & STD of Case Count')

# %%
rolmean_pos = df_indexed.percent_positive.rolling(window=7).mean()
rolstd_pos = df_indexed.percent_positive.rolling(window=7).std()
rolmean_pos.plot(label='Rolling Mean')
rolstd_pos.plot( label='Rolling STD')
plt.legend(loc='best')
plt.title('Florida COVID-19 Daily 7-Day Rolling Mean & STD of Positivity Ratio')

# %%
# Descriptive Analysis

# %%
sns.distplot(df.daily_case_count)
plt.title('Distribution of COVID-19 Case Counts')

# %%
sns.distplot(df.percent_positive)
plt.title('Distribution of COVID-19 Positivity Ratio')

# %%
d1[['daily_case_count','percent_positive']].describe()

# %%
d1.groupby('county')['positive'].sum()

# %%
most_case = d1.daily_case_count.max()
max_sum_case = d1.groupby('date')['daily_case_count'].sum().max()
daily_sum_case = d1.groupby('date')[['daily_neg_count', 'daily_case_count', 'daily_test_count']].sum()
daily_sum_case['pr'] = daily_sum_case.daily_case_count/daily_sum_case.daily_test_count

# %%
d1.columns

# %% [markdown]
# Peak in total daily case counts

# %%
daily_sum_case.loc[daily_sum_case.daily_case_count == max_sum_case]

# %%
d1.county.nunique()

# %%
d1.date.max(),d1.date.min()

# %%
rolmean_case.max()
rolmean_case.loc[rolmean_case==rolmean_case.max()]

# %%
d1.columns

# %%
d1.sort_values(by=['county','date'], inplace=True)

# %%
fl.c2_workplace_closing.value_counts()

# %%
dsc = daily_sum_case.reset_index()
dsc.date = pd.to_datetime(dsc.date)
dsc.daily_case_count = dsc.daily_case_count.astype(int)
dsc.info()

# %%
sns.distplot(dsc.daily_case_count)

# %%
dsc

# %%
sns.lineplot(x='date' ,y='pr',c='black', data=dsc, label='Positivity Ratio' )
ax2 = plt.twinx()
sns.lineplot(y='daily_case_count', x ='date' ,data=dsc, ax=ax2,label='COVID-19 Case Count')
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.title('Florida Daily COVID-19 Case Counts vs. Positivity Ratio')
plt.legend(loc='best')

# %%
sns.lineplot(x='date' ,y='c6_stay_at_home_requirements',c='black', data=fl, label='Stay at Home Requirement Level' )
ax2 = plt.twinx()
sns.lineplot(y='daily_case_count', x ='date' ,data=dsc, ax=ax2)
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.title('Florida Daily COVID-19 Case Counts & Stay at Home Requirement Level')
plt.legend(loc='best')

# %%
sns.lineplot(x='date' ,y='c1_school_closing', data=fl,c='brown', label='School Closure Requirement Level' )
plt.title('Florida Daily COVID-19 Case Counts & School Closure Requirement Level')
ax2 = plt.twinx()
sns.lineplot(y='daily_case_count', x ='date' ,data=dsc, ax=ax2)
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.legend(loc='best')

# %%
sns.lineplot(x='date' ,y='c2_workplace_closing', data=fl,c='brown', label='School Closure Requirement Level' )
plt.title('Florida Daily COVID-19 Case Counts & School Closure Requirement Level')
ax2 = plt.twinx()
sns.lineplot(y='daily_case_count', x ='date' ,data=dsc, ax=ax2)
plt.axvline(x=p1,label='Start of Phase 1', c='r',ls='--')
plt.axvline(x=p2,label='Start of Phase 2', c='y',ls='--')
plt.axvline(x=p3,label='Start of Phase 3', c='g',ls='--')
plt.legend(loc='best')

# %%
d1['nameoday']= pd.to_datetime(d1.date).dt.day_name()

# %%
d1[['day_of_week','nameoday']].head(50)

# %%
d1.clinical_care_rank.describe()

# %%
# The county with the worst Clinical Care Rating
d1.loc[d1.clinical_care_rank == 67]['county'].unique()

# %%
d1[['phase2','c6_stay_at_home_requirements']].corr(method ='spearman')

# %%
d1[['phase1','c6_stay_at_home_requirements']].corr(method ='spearman')

# %% [markdown]
# # Testing Area
#
# ## TODO:
# -[ ] The date format for the daily testing numbers seems to be ISO8601 [Datetime formats](https://www.php.net/manual/en/datetime.formats.date.php)
#
# Description 	Format 	Examples
# Eight digit year, month and day 	YY MM DD 	"15810726", "19780417", "18140517"

# %%
tests_url = r'https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/arcgis/rest/services/state_daily_testing/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'

# %%
test = requests.get(tests_url).json()

# %%
test.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'fields', 'features'])

# %%
test['features']
# Out:
# [{'attributes': {'Date': 1580187600000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2492}},
#  {'attributes': {'Date': 1580360400000,
#    'Negative': 3,
#    'Positive': 0,
#    'Total': 3,
#    'PercentPositive': 0,
#    'ObjectId': 2493}},
#  {'attributes': {'Date': 1580706000000,
#    'Negative': 2,
#    'Positive': 0,
#    'Total': 2,
#    'PercentPositive': 0,
#    'ObjectId': 2494}},
#  {'attributes': {'Date': 1581051600000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2495}},
#  {'attributes': {'Date': 1581310800000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2496}},
#  {'attributes': {'Date': 1581483600000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2497}},
#  {'attributes': {'Date': 1581656400000,
#    'Negative': 3,
#    'Positive': 0,
#    'Total': 3,
#    'PercentPositive': 0,
#    'ObjectId': 2498}},
#  {'attributes': {'Date': 1581829200000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2499}},
#  {'attributes': {'Date': 1582261200000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2500}},
#  {'attributes': {'Date': 1582520400000,
#    'Negative': 1,
#    'Positive': 0,
#    'Total': 1,
#    'PercentPositive': 0,
#    'ObjectId': 2501}},
#  {'attributes': {'Date': 1583125200000,
#    'Negative': 2,
#    'Positive': 2,
#    'Total': 4,
#    'PercentPositive': 50,
#    'ObjectId': 2502}},
#  {'attributes': {'Date': 1583211600000,
#    'Negative': 2,
#    'Positive': 1,
#    'Total': 3,
#    'PercentPositive': 33.33,
#    'ObjectId': 2503}},
#  {'attributes': {'Date': 1583298000000,
#    'Negative': 15,
#    'Positive': 4,
#    'Total': 19,
#    'PercentPositive': 21.05,
#    'ObjectId': 2504}},
#  {'attributes': {'Date': 1583384400000,
#    'Negative': 26,
#    'Positive': 1,
#    'Total': 27,
#    'PercentPositive': 3.7,
#    'ObjectId': 2505}},
#  {'attributes': {'Date': 1583470800000,
#    'Negative': 48,
#    'Positive': 0,
#    'Total': 48,
#    'PercentPositive': 0,
#    'ObjectId': 2506}},
#  {'attributes': {'Date': 1583557200000,
#    'Negative': 23,
#    'Positive': 4,
#    'Total': 27,
#    'PercentPositive': 14.81,
#    'ObjectId': 2507}},
#  {'attributes': {'Date': 1583643600000,
#    'Negative': 35,
#    'Positive': 1,
#    'Total': 36,
#    'PercentPositive': 2.78,
#    'ObjectId': 2508}},
#  {'attributes': {'Date': 1583730000000,
#    'Negative': 79,
#    'Positive': 5,
#    'Total': 84,
#    'PercentPositive': 5.95,
#    'ObjectId': 2509}},
#  {'attributes': {'Date': 1583816400000,
#    'Negative': 69,
#    'Positive': 2,
#    'Total': 71,
#    'PercentPositive': 2.82,
#    'ObjectId': 2510}},
#  {'attributes': {'Date': 1583902800000,
#    'Negative': 47,
#    'Positive': 6,
#    'Total': 53,
#    'PercentPositive': 11.32,
#    'ObjectId': 2511}},
#  {'attributes': {'Date': 1583989200000,
#    'Negative': 112,
#    'Positive': 5,
#    'Total': 117,
#    'PercentPositive': 4.27,
#    'ObjectId': 2512}},
#  {'attributes': {'Date': 1584075600000,
#    'Negative': 177,
#    'Positive': 20,
#    'Total': 197,
#    'PercentPositive': 10.15,
#    'ObjectId': 2513}},
#  {'attributes': {'Date': 1584162000000,
#    'Negative': 396,
#    'Positive': 40,
#    'Total': 436,
#    'PercentPositive': 9.17,
#    'ObjectId': 2514}},
#  {'attributes': {'Date': 1584248400000,
#    'Negative': 150,
#    'Positive': 31,
#    'Total': 181,
#    'PercentPositive': 17.13,
#    'ObjectId': 2515}},
#  {'attributes': {'Date': 1584334800000,
#    'Negative': 564,
#    'Positive': 27,
#    'Total': 591,
#    'PercentPositive': 4.57,
#    'ObjectId': 2516}},
#  {'attributes': {'Date': 1584421200000,
#    'Negative': 641,
#    'Positive': 62,
#    'Total': 703,
#    'PercentPositive': 8.82,
#    'ObjectId': 2517}},
#  {'attributes': {'Date': 1584507600000,
#    'Negative': 954,
#    'Positive': 99,
#    'Total': 1053,
#    'PercentPositive': 9.4,
#    'ObjectId': 2518}},
#  {'attributes': {'Date': 1584594000000,
#    'Negative': 1025,
#    'Positive': 76,
#    'Total': 1101,
#    'PercentPositive': 6.9,
#    'ObjectId': 2519}},
#  {'attributes': {'Date': 1584680400000,
#    'Negative': 1273,
#    'Positive': 142,
#    'Total': 1415,
#    'PercentPositive': 10.04,
#    'ObjectId': 2520}},
#  {'attributes': {'Date': 1584766800000,
#    'Negative': 2088,
#    'Positive': 203,
#    'Total': 2291,
#    'PercentPositive': 8.86,
#    'ObjectId': 2521}},
#  {'attributes': {'Date': 1584853200000,
#    'Negative': 2498,
#    'Positive': 298,
#    'Total': 2796,
#    'PercentPositive': 10.66,
#    'ObjectId': 2522}},
#  {'attributes': {'Date': 1584939600000,
#    'Negative': 1494,
#    'Positive': 176,
#    'Total': 1670,
#    'PercentPositive': 10.54,
#    'ObjectId': 2523}},
#  {'attributes': {'Date': 1585026000000,
#    'Negative': 2594,
#    'Positive': 283,
#    'Total': 2877,
#    'PercentPositive': 9.84,
#    'ObjectId': 2524}},
#  {'attributes': {'Date': 1585112400000,
#    'Negative': 6391,
#    'Positive': 497,
#    'Total': 6888,
#    'PercentPositive': 7.22,
#    'ObjectId': 2525}},
#  {'attributes': {'Date': 1585198800000,
#    'Negative': 5079,
#    'Positive': 535,
#    'Total': 5614,
#    'PercentPositive': 9.53,
#    'ObjectId': 2526}},
#  {'attributes': {'Date': 1585285200000,
#    'Negative': 5578,
#    'Positive': 659,
#    'Total': 6237,
#    'PercentPositive': 10.57,
#    'ObjectId': 2527}},
#  {'attributes': {'Date': 1585371600000,
#    'Negative': 5664,
#    'Positive': 705,
#    'Total': 6369,
#    'PercentPositive': 11.07,
#    'ObjectId': 2528}},
#  {'attributes': {'Date': 1585458000000,
#    'Negative': 6242,
#    'Positive': 876,
#    'Total': 7118,
#    'PercentPositive': 12.31,
#    'ObjectId': 2529}},
#  {'attributes': {'Date': 1585544400000,
#    'Negative': 6071,
#    'Positive': 852,
#    'Total': 6923,
#    'PercentPositive': 12.31,
#    'ObjectId': 2530}},
#  {'attributes': {'Date': 1585630800000,
#    'Negative': 7296,
#    'Positive': 904,
#    'Total': 8200,
#    'PercentPositive': 11.02,
#    'ObjectId': 2531}},
#  {'attributes': {'Date': 1585717200000,
#    'Negative': 7406,
#    'Positive': 1031,
#    'Total': 8437,
#    'PercentPositive': 12.22,
#    'ObjectId': 2532}},
#  {'attributes': {'Date': 1585803600000,
#    'Negative': 11403,
#    'Positive': 1268,
#    'Total': 12671,
#    'PercentPositive': 10.01,
#    'ObjectId': 2533}},
#  {'attributes': {'Date': 1585890000000,
#    'Negative': 9450,
#    'Positive': 1281,
#    'Total': 10731,
#    'PercentPositive': 11.94,
#    'ObjectId': 2534}},
#  {'attributes': {'Date': 1585976400000,
#    'Negative': 10981,
#    'Positive': 1148,
#    'Total': 12129,
#    'PercentPositive': 9.46,
#    'ObjectId': 2535}},
#  {'attributes': {'Date': 1586062800000,
#    'Negative': 6245,
#    'Positive': 763,
#    'Total': 7008,
#    'PercentPositive': 10.89,
#    'ObjectId': 2536}},
#  {'attributes': {'Date': 1586149200000,
#    'Negative': 9888,
#    'Positive': 1159,
#    'Total': 11047,
#    'PercentPositive': 10.49,
#    'ObjectId': 2537}},
#  {'attributes': {'Date': 1586235600000,
#    'Negative': 10493,
#    'Positive': 1006,
#    'Total': 11499,
#    'PercentPositive': 8.75,
#    'ObjectId': 2538}},
#  {'attributes': {'Date': 1586322000000,
#    'Negative': 5442,
#    'Positive': 1046,
#    'Total': 6488,
#    'PercentPositive': 16.12,
#    'ObjectId': 2539}},
#  {'attributes': {'Date': 1586408400000,
#    'Negative': 12963,
#    'Positive': 1033,
#    'Total': 13996,
#    'PercentPositive': 7.38,
#    'ObjectId': 2540}},
#  {'attributes': {'Date': 1586494800000,
#    'Negative': 8343,
#    'Positive': 1088,
#    'Total': 9431,
#    'PercentPositive': 11.54,
#    'ObjectId': 2541}},
#  {'attributes': {'Date': 1586581200000,
#    'Negative': 10175,
#    'Positive': 1064,
#    'Total': 11239,
#    'PercentPositive': 9.47,
#    'ObjectId': 2542}},
#  {'attributes': {'Date': 1586667600000,
#    'Negative': 7878,
#    'Positive': 809,
#    'Total': 8687,
#    'PercentPositive': 9.31,
#    'ObjectId': 2543}},
#  {'attributes': {'Date': 1586754000000,
#    'Negative': 7762,
#    'Positive': 922,
#    'Total': 8684,
#    'PercentPositive': 10.62,
#    'ObjectId': 2544}},
#  {'attributes': {'Date': 1586840400000,
#    'Negative': 5828,
#    'Positive': 592,
#    'Total': 6420,
#    'PercentPositive': 9.22,
#    'ObjectId': 2545}},
#  {'attributes': {'Date': 1586926800000,
#    'Negative': 8715,
#    'Positive': 897,
#    'Total': 9612,
#    'PercentPositive': 9.33,
#    'ObjectId': 2546}},
#  {'attributes': {'Date': 1587013200000,
#    'Negative': 14250,
#    'Positive': 1199,
#    'Total': 15449,
#    'PercentPositive': 7.76,
#    'ObjectId': 2547}},
#  {'attributes': {'Date': 1587099600000,
#    'Negative': 11702,
#    'Positive': 1083,
#    'Total': 12785,
#    'PercentPositive': 8.47,
#    'ObjectId': 2548}},
#  {'attributes': {'Date': 1587186000000,
#    'Negative': 8410,
#    'Positive': 741,
#    'Total': 9151,
#    'PercentPositive': 8.1,
#    'ObjectId': 2549}},
#  {'attributes': {'Date': 1587272400000,
#    'Negative': 8500,
#    'Positive': 713,
#    'Total': 9213,
#    'PercentPositive': 7.74,
#    'ObjectId': 2550}},
#  {'attributes': {'Date': 1587358800000,
#    'Negative': 9819,
#    'Positive': 746,
#    'Total': 10565,
#    'PercentPositive': 7.06,
#    'ObjectId': 2551}},
#  {'attributes': {'Date': 1587445200000,
#    'Negative': 11365,
#    'Positive': 859,
#    'Total': 12224,
#    'PercentPositive': 7.03,
#    'ObjectId': 2552}},
#  {'attributes': {'Date': 1587531600000,
#    'Negative': 10355,
#    'Positive': 696,
#    'Total': 11051,
#    'PercentPositive': 6.3,
#    'ObjectId': 2553}},
#  {'attributes': {'Date': 1587618000000,
#    'Negative': 17380,
#    'Positive': 1214,
#    'Total': 18594,
#    'PercentPositive': 6.53,
#    'ObjectId': 2554}},
#  {'attributes': {'Date': 1587704400000,
#    'Negative': 12659,
#    'Positive': 734,
#    'Total': 13393,
#    'PercentPositive': 5.48,
#    'ObjectId': 2555}},
#  {'attributes': {'Date': 1587790800000,
#    'Negative': 16091,
#    'Positive': 795,
#    'Total': 16886,
#    'PercentPositive': 4.71,
#    'ObjectId': 2556}},
#  {'attributes': {'Date': 1587877200000,
#    'Negative': 8343,
#    'Positive': 519,
#    'Total': 8862,
#    'PercentPositive': 5.86,
#    'ObjectId': 2557}},
#  {'attributes': {'Date': 1587963600000,
#    'Negative': 10997,
#    'Positive': 748,
#    'Total': 11745,
#    'PercentPositive': 6.37,
#    'ObjectId': 2558}},
#  {'attributes': {'Date': 1588050000000,
#    'Negative': 6665,
#    'Positive': 343,
#    'Total': 7008,
#    'PercentPositive': 4.89,
#    'ObjectId': 2559}},
#  {'attributes': {'Date': 1588136400000,
#    'Negative': 9143,
#    'Positive': 514,
#    'Total': 9657,
#    'PercentPositive': 5.32,
#    'ObjectId': 2560}},
#  {'attributes': {'Date': 1588222800000,
#    'Negative': 17225,
#    'Positive': 977,
#    'Total': 18202,
#    'PercentPositive': 5.37,
#    'ObjectId': 2561}},
#  {'attributes': {'Date': 1588309200000,
#    'Negative': 15667,
#    'Positive': 703,
#    'Total': 16370,
#    'PercentPositive': 4.29,
#    'ObjectId': 2562}},
#  {'attributes': {'Date': 1588395600000,
#    'Negative': 11749,
#    'Positive': 632,
#    'Total': 12381,
#    'PercentPositive': 5.1,
#    'ObjectId': 2563}},
#  {'attributes': {'Date': 1588482000000,
#    'Negative': 14584,
#    'Positive': 768,
#    'Total': 15352,
#    'PercentPositive': 5,
#    'ObjectId': 2564}},
#  {'attributes': {'Date': 1588568400000,
#    'Negative': 20471,
#    'Positive': 574,
#    'Total': 21045,
#    'PercentPositive': 2.73,
#    'ObjectId': 2565}},
#  {'attributes': {'Date': 1588654800000,
#    'Negative': 14209,
#    'Positive': 581,
#    'Total': 14790,
#    'PercentPositive': 3.93,
#    'ObjectId': 2566}},
#  {'attributes': {'Date': 1588741200000,
#    'Negative': 13168,
#    'Positive': 625,
#    'Total': 13793,
#    'PercentPositive': 4.53,
#    'ObjectId': 2567}},
#  {'attributes': {'Date': 1588827600000,
#    'Negative': 16939,
#    'Positive': 344,
#    'Total': 17283,
#    'PercentPositive': 1.99,
#    'ObjectId': 2568}},
#  {'attributes': {'Date': 1588914000000,
#    'Negative': 15956,
#    'Positive': 765,
#    'Total': 16721,
#    'PercentPositive': 4.58,
#    'ObjectId': 2569}},
#  {'attributes': {'Date': 1589000400000,
#    'Negative': 12992,
#    'Positive': 681,
#    'Total': 13673,
#    'PercentPositive': 4.98,
#    'ObjectId': 2570}},
#  {'attributes': {'Date': 1589086800000,
#    'Negative': 17388,
#    'Positive': 383,
#    'Total': 17771,
#    'PercentPositive': 2.16,
#    'ObjectId': 2571}},
#  {'attributes': {'Date': 1589173200000,
#    'Negative': 20533,
#    'Positive': 606,
#    'Total': 21139,
#    'PercentPositive': 2.87,
#    'ObjectId': 2572}},
#  {'attributes': {'Date': 1589259600000,
#    'Negative': 13745,
#    'Positive': 799,
#    'Total': 14544,
#    'PercentPositive': 5.49,
#    'ObjectId': 2573}},
#  {'attributes': {'Date': 1589346000000,
#    'Negative': 14894,
#    'Positive': 792,
#    'Total': 15686,
#    'PercentPositive': 5.05,
#    'ObjectId': 2574}},
#  {'attributes': {'Date': 1589432400000,
#    'Negative': 14728,
#    'Positive': 786,
#    'Total': 15514,
#    'PercentPositive': 5.07,
#    'ObjectId': 2575}},
#  {'attributes': {'Date': 1589518800000,
#    'Negative': 6120,
#    'Positive': 480,
#    'Total': 6600,
#    'PercentPositive': 7.27,
#    'ObjectId': 2576}},
#  {'attributes': {'Date': 1589605200000,
#    'Negative': 20386,
#    'Positive': 1136,
#    'Total': 21522,
#    'PercentPositive': 5.28,
#    'ObjectId': 2577}},
#  {'attributes': {'Date': 1589691600000,
#    'Negative': 18627,
#    'Positive': 654,
#    'Total': 19281,
#    'PercentPositive': 3.39,
#    'ObjectId': 2578}},
#  {'attributes': {'Date': 1589778000000,
#    'Negative': 29833,
#    'Positive': 612,
#    'Total': 30445,
#    'PercentPositive': 2.01,
#    'ObjectId': 2579}},
#  {'attributes': {'Date': 1589864400000,
#    'Negative': 70773,
#    'Positive': 475,
#    'Total': 71248,
#    'PercentPositive': 0.67,
#    'ObjectId': 2580}},
#  {'attributes': {'Date': 1589950800000,
#    'Negative': 43960,
#    'Positive': 1190,
#    'Total': 45150,
#    'PercentPositive': 2.64,
#    'ObjectId': 2581}},
#  {'attributes': {'Date': 1590037200000,
#    'Negative': 23098,
#    'Positive': 725,
#    'Total': 23823,
#    'PercentPositive': 3.04,
#    'ObjectId': 2582}},
#  {'attributes': {'Date': 1590123600000,
#    'Negative': 25071,
#    'Positive': 733,
#    'Total': 25804,
#    'PercentPositive': 2.84,
#    'ObjectId': 2583}},
#  {'attributes': {'Date': 1590210000000,
#    'Negative': 15144,
#    'Positive': 545,
#    'Total': 15689,
#    'PercentPositive': 3.47,
#    'ObjectId': 2584}},
#  {'attributes': {'Date': 1590296400000,
#    'Negative': 36467,
#    'Positive': 980,
#    'Total': 37447,
#    'PercentPositive': 2.62,
#    'ObjectId': 2585}},
#  {'attributes': {'Date': 1590382800000,
#    'Negative': 17546,
#    'Positive': 503,
#    'Total': 18049,
#    'PercentPositive': 2.79,
#    'ObjectId': 2586}},
#  {'attributes': {'Date': 1590469200000,
#    'Negative': 13479,
#    'Positive': 475,
#    'Total': 13954,
#    'PercentPositive': 3.4,
#    'ObjectId': 2587}},
#  {'attributes': {'Date': 1590555600000,
#    'Negative': 18859,
#    'Positive': 613,
#    'Total': 19472,
#    'PercentPositive': 3.15,
#    'ObjectId': 2588}},
#  {'attributes': {'Date': 1590642000000,
#    'Negative': 35485,
#    'Positive': 1221,
#    'Total': 36706,
#    'PercentPositive': 3.33,
#    'ObjectId': 2589}},
#  {'attributes': {'Date': 1590728400000,
#    'Negative': 13549,
#    'Positive': 752,
#    'Total': 14301,
#    'PercentPositive': 5.26,
#    'ObjectId': 2590}},
#  {'attributes': {'Date': 1590814800000,
#    'Negative': 25810,
#    'Positive': 870,
#    'Total': 26680,
#    'PercentPositive': 3.26,
#    'ObjectId': 2591}},
#  {'attributes': {'Date': 1590901200000,
#    'Negative': 23489,
#    'Positive': 700,
#    'Total': 24189,
#    'PercentPositive': 2.89,
#    'ObjectId': 2592}},
#  {'attributes': {'Date': 1590987600000,
#    'Negative': 9551,
#    'Positive': 602,
#    'Total': 10153,
#    'PercentPositive': 5.93,
#    'ObjectId': 2593}},
#  {'attributes': {'Date': 1591074000000,
#    'Negative': 24392,
#    'Positive': 1209,
#    'Total': 25601,
#    'PercentPositive': 4.72,
#    'ObjectId': 2594}},
#  {'attributes': {'Date': 1591160400000,
#    'Negative': 33264,
#    'Positive': 1265,
#    'Total': 34529,
#    'PercentPositive': 3.66,
#    'ObjectId': 2595}},
#  {'attributes': {'Date': 1591246800000,
#    'Negative': 27208,
#    'Positive': 1019,
#    'Total': 28227,
#    'PercentPositive': 3.61,
#    'ObjectId': 2596}},
#  {'attributes': {'Date': 1591333200000,
#    'Negative': 34549,
#    'Positive': 1244,
#    'Total': 35793,
#    'PercentPositive': 3.48,
#    'ObjectId': 2597}},
#  {'attributes': {'Date': 1591419600000,
#    'Negative': 49257,
#    'Positive': 1392,
#    'Total': 50649,
#    'PercentPositive': 2.75,
#    'ObjectId': 2598}},
#  {'attributes': {'Date': 1591506000000,
#    'Negative': 23883,
#    'Positive': 1029,
#    'Total': 24912,
#    'PercentPositive': 4.13,
#    'ObjectId': 2599}},
#  {'attributes': {'Date': 1591592400000,
#    'Negative': 27985,
#    'Positive': 1157,
#    'Total': 29142,
#    'PercentPositive': 3.97,
#    'ObjectId': 2600}},
#  {'attributes': {'Date': 1591678800000,
#    'Negative': 20065,
#    'Positive': 1242,
#    'Total': 21307,
#    'PercentPositive': 5.83,
#    'ObjectId': 2601}},
#  {'attributes': {'Date': 1591765200000,
#    'Negative': 26089,
#    'Positive': 1669,
#    'Total': 27758,
#    'PercentPositive': 6.01,
#    'ObjectId': 2602}},
#  {'attributes': {'Date': 1591851600000,
#    'Negative': 28830,
#    'Positive': 1634,
#    'Total': 30464,
#    'PercentPositive': 5.36,
#    'ObjectId': 2603}},
#  {'attributes': {'Date': 1591938000000,
#    'Negative': 32502,
#    'Positive': 2476,
#    'Total': 34978,
#    'PercentPositive': 7.08,
#    'ObjectId': 2604}},
#  {'attributes': {'Date': 1592024400000,
#    'Negative': 43601,
#    'Positive': 2133,
#    'Total': 45734,
#    'PercentPositive': 4.66,
#    'ObjectId': 2605}},
#  {'attributes': {'Date': 1592110800000,
#    'Negative': 29117,
#    'Positive': 1759,
#    'Total': 30876,
#    'PercentPositive': 5.7,
#    'ObjectId': 2606}},
#  {'attributes': {'Date': 1592197200000,
#    'Negative': 31674,
#    'Positive': 2691,
#    'Total': 34365,
#    'PercentPositive': 7.83,
#    'ObjectId': 2607}},
#  {'attributes': {'Date': 1592283600000,
#    'Negative': 20386,
#    'Positive': 2427,
#    'Total': 22813,
#    'PercentPositive': 10.64,
#    'ObjectId': 2608}},
#  {'attributes': {'Date': 1592370000000,
#    'Negative': 26358,
#    'Positive': 2693,
#    'Total': 29051,
#    'PercentPositive': 9.27,
#    'ObjectId': 2609}},
#  {'attributes': {'Date': 1592456400000,
#    'Negative': 28170,
#    'Positive': 3313,
#    'Total': 31483,
#    'PercentPositive': 10.52,
#    'ObjectId': 2610}},
#  {'attributes': {'Date': 1592542800000,
#    'Negative': 26927,
#    'Positive': 4002,
#    'Total': 30929,
#    'PercentPositive': 12.94,
#    'ObjectId': 2611}},
#  {'attributes': {'Date': 1592629200000,
#    'Negative': 32430,
#    'Positive': 4617,
#    'Total': 37047,
#    'PercentPositive': 12.46,
#    'ObjectId': 2612}},
#  {'attributes': {'Date': 1592715600000,
#    'Negative': 31206,
#    'Positive': 2751,
#    'Total': 33957,
#    'PercentPositive': 8.1,
#    'ObjectId': 2613}},
#  {'attributes': {'Date': 1592802000000,
#    'Negative': 29836,
#    'Positive': 3798,
#    'Total': 33634,
#    'PercentPositive': 11.29,
#    'ObjectId': 2614}},
#  {'attributes': {'Date': 1592888400000,
#    'Negative': 27092,
#    'Positive': 5472,
#    'Total': 32564,
#    'PercentPositive': 16.8,
#    'ObjectId': 2615}},
#  {'attributes': {'Date': 1592974800000,
#    'Negative': 47986,
#    'Positive': 4990,
#    'Total': 52976,
#    'PercentPositive': 9.42,
#    'ObjectId': 2616}},
#  {'attributes': {'Date': 1593061200000,
#    'Negative': 56103,
#    'Positive': 8814,
#    'Total': 64917,
#    'PercentPositive': 13.58,
#    'ObjectId': 2617}},
#  {'attributes': {'Date': 1593147600000,
#    'Negative': 61558,
#    'Positive': 9533,
#    'Total': 71091,
#    'PercentPositive': 13.41,
#    'ObjectId': 2618}},
#  {'attributes': {'Date': 1593234000000,
#    'Negative': 56352,
#    'Positive': 8354,
#    'Total': 64706,
#    'PercentPositive': 12.91,
#    'ObjectId': 2619}},
#  {'attributes': {'Date': 1593320400000,
#    'Negative': 32306,
#    'Positive': 5362,
#    'Total': 37668,
#    'PercentPositive': 14.23,
#    'ObjectId': 2620}},
#  {'attributes': {'Date': 1593406800000,
#    'Negative': 33367,
#    'Positive': 6028,
#    'Total': 39395,
#    'PercentPositive': 15.3,
#    'ObjectId': 2621}},
#  {'attributes': {'Date': 1593493200000,
#    'Negative': 35249,
#    'Positive': 6544,
#    'Total': 41793,
#    'PercentPositive': 15.66,
#    'ObjectId': 2622}},
#  {'attributes': {'Date': 1593579600000,
#    'Negative': 52975,
#    'Positive': 9441,
#    'Total': 62416,
#    'PercentPositive': 15.13,
#    'ObjectId': 2623}},
#  {'attributes': {'Date': 1593666000000,
#    'Negative': 51231,
#    'Positive': 9323,
#    'Total': 60554,
#    'PercentPositive': 15.4,
#    'ObjectId': 2624}},
#  {'attributes': {'Date': 1593752400000,
#    'Negative': 66407,
#    'Positive': 11331,
#    'Total': 77738,
#    'PercentPositive': 14.58,
#    'ObjectId': 2625}},
#  {'attributes': {'Date': 1593838800000,
#    'Negative': 53848,
#    'Positive': 9858,
#    'Total': 63706,
#    'PercentPositive': 15.47,
#    'ObjectId': 2626}},
#  {'attributes': {'Date': 1593925200000,
#    'Negative': 34208,
#    'Positive': 6237,
#    'Total': 40445,
#    'PercentPositive': 15.42,
#    'ObjectId': 2627}},
#  {'attributes': {'Date': 1594011600000,
#    'Negative': 36009,
#    'Positive': 7299,
#    'Total': 43308,
#    'PercentPositive': 16.85,
#    'ObjectId': 2628}},
#  {'attributes': {'Date': 1594098000000,
#    'Negative': 57392,
#    'Positive': 9949,
#    'Total': 67341,
#    'PercentPositive': 14.77,
#    'ObjectId': 2629}},
#  {'attributes': {'Date': 1594184400000,
#    'Negative': 37823,
#    'Positive': 8891,
#    'Total': 46714,
#    'PercentPositive': 19.03,
#    'ObjectId': 2630}},
#  {'attributes': {'Date': 1594270800000,
#    'Negative': 73578,
#    'Positive': 11251,
#    'Total': 84829,
#    'PercentPositive': 13.26,
#    'ObjectId': 2631}},
#  {'attributes': {'Date': 1594357200000,
#    'Negative': 67079,
#    'Positive': 10275,
#    'Total': 77354,
#    'PercentPositive': 13.28,
#    'ObjectId': 2632}},
#  {'attributes': {'Date': 1594443600000,
#    'Negative': 113796,
#    'Positive': 15148,
#    'Total': 128944,
#    'PercentPositive': 11.75,
#    'ObjectId': 2633}},
#  {'attributes': {'Date': 1594530000000,
#    'Negative': 88634,
#    'Positive': 12207,
#    'Total': 100841,
#    'PercentPositive': 12.11,
#    'ObjectId': 2634}},
#  {'attributes': {'Date': 1594616400000,
#    'Negative': 50219,
#    'Positive': 9183,
#    'Total': 59402,
#    'PercentPositive': 15.46,
#    'ObjectId': 2635}},
#  {'attributes': {'Date': 1594702800000,
#    'Negative': 60966,
#    'Positive': 9991,
#    'Total': 70957,
#    'PercentPositive': 14.08,
#    'ObjectId': 2636}},
#  {'attributes': {'Date': 1594789200000,
#    'Negative': 89195,
#    'Positive': 13758,
#    'Total': 102953,
#    'PercentPositive': 13.36,
#    'ObjectId': 2637}},
#  {'attributes': {'Date': 1594875600000,
#    'Negative': 80371,
#    'Positive': 11172,
#    'Total': 91543,
#    'PercentPositive': 12.2,
#    'ObjectId': 2638}},
#  {'attributes': {'Date': 1594962000000,
#    'Negative': 70373,
#    'Positive': 10173,
#    'Total': 80546,
#    'PercentPositive': 12.63,
#    'ObjectId': 2639}},
#  {'attributes': {'Date': 1595048400000,
#    'Negative': 89084,
#    'Positive': 12384,
#    'Total': 101468,
#    'PercentPositive': 12.2,
#    'ObjectId': 2640}},
#  {'attributes': {'Date': 1595134800000,
#    'Negative': 58420,
#    'Positive': 10404,
#    'Total': 68824,
#    'PercentPositive': 15.12,
#    'ObjectId': 2641}},
#  {'attributes': {'Date': 1595221200000,
#    'Negative': 57081,
#    'Positive': 9262,
#    'Total': 66343,
#    'PercentPositive': 13.96,
#    'ObjectId': 2642}},
#  {'attributes': {'Date': 1595307600000,
#    'Negative': 78818,
#    'Positive': 9664,
#    'Total': 88482,
#    'PercentPositive': 10.92,
#    'ObjectId': 2643}},
#  {'attributes': {'Date': 1595394000000,
#    'Negative': 69826,
#    'Positive': 10111,
#    'Total': 79937,
#    'PercentPositive': 12.65,
#    'ObjectId': 2644}},
#  {'attributes': {'Date': 1595480400000,
#    'Negative': 78230,
#    'Positive': 12319,
#    'Total': 90549,
#    'PercentPositive': 13.6,
#    'ObjectId': 2645}},
#  {'attributes': {'Date': 1595566800000,
#    'Negative': 90302,
#    'Positive': 12046,
#    'Total': 102348,
#    'PercentPositive': 11.77,
#    'ObjectId': 2646}},
#  {'attributes': {'Date': 1595653200000,
#    'Negative': 72141,
#    'Positive': 9246,
#    'Total': 81387,
#    'PercentPositive': 11.36,
#    'ObjectId': 2647}},
#  {'attributes': {'Date': 1595739600000,
#    'Negative': 66402,
#    'Positive': 8803,
#    'Total': 75205,
#    'PercentPositive': 11.71,
#    'ObjectId': 2648}},
#  {'attributes': {'Date': 1595826000000,
#    'Negative': 67158,
#    'Positive': 9138,
#    'Total': 76296,
#    'PercentPositive': 11.98,
#    'ObjectId': 2649}},
#  {'attributes': {'Date': 1595912400000,
#    'Negative': 65083,
#    'Positive': 9320,
#    'Total': 74403,
#    'PercentPositive': 12.53,
#    'ObjectId': 2650}},
#  {'attributes': {'Date': 1595998800000,
#    'Negative': 70141,
#    'Positive': 9834,
#    'Total': 79975,
#    'PercentPositive': 12.3,
#    'ObjectId': 2651}},
#  {'attributes': {'Date': 1596085200000,
#    'Negative': 73137,
#    'Positive': 8899,
#    'Total': 82036,
#    'PercentPositive': 10.85,
#    'ObjectId': 2652}},
#  {'attributes': {'Date': 1596171600000,
#    'Negative': 74821,
#    'Positive': 9500,
#    'Total': 84321,
#    'PercentPositive': 11.27,
#    'ObjectId': 2653}},
#  {'attributes': {'Date': 1596258000000,
#    'Negative': 67167,
#    'Positive': 7053,
#    'Total': 74220,
#    'PercentPositive': 9.5,
#    'ObjectId': 2654}},
#  {'attributes': {'Date': 1596344400000,
#    'Negative': 47037,
#    'Positive': 4812,
#    'Total': 51849,
#    'PercentPositive': 9.28,
#    'ObjectId': 2655}},
#  {'attributes': {'Date': 1596430800000,
#    'Negative': 42967,
#    'Positive': 5356,
#    'Total': 48323,
#    'PercentPositive': 11.08,
#    'ObjectId': 2656}},
#  {'attributes': {'Date': 1596517200000,
#    'Negative': 43452,
#    'Positive': 5423,
#    'Total': 48875,
#    'PercentPositive': 11.1,
#    'ObjectId': 2657}},
#  {'attributes': {'Date': 1596603600000,
#    'Negative': 80976,
#    'Positive': 7571,
#    'Total': 88547,
#    'PercentPositive': 8.55,
#    'ObjectId': 2658}},
#  {'attributes': {'Date': 1596690000000,
#    'Negative': 66096,
#    'Positive': 7541,
#    'Total': 73637,
#    'PercentPositive': 10.24,
#    'ObjectId': 2659}},
#  {'attributes': {'Date': 1596776400000,
#    'Negative': 74933,
#    'Positive': 8342,
#    'Total': 83275,
#    'PercentPositive': 10.02,
#    'ObjectId': 2660}},
#  {'attributes': {'Date': 1596862800000,
#    'Negative': 65326,
#    'Positive': 6137,
#    'Total': 71463,
#    'PercentPositive': 8.59,
#    'ObjectId': 2661}},
#  {'attributes': {'Date': 1596949200000,
#    'Negative': 43724,
#    'Positive': 4150,
#    'Total': 47874,
#    'PercentPositive': 8.67,
#    'ObjectId': 2662}},
#  {'attributes': {'Date': 1597035600000,
#    'Negative': 49641,
#    'Positive': 5762,
#    'Total': 55403,
#    'PercentPositive': 10.4,
#    'ObjectId': 2663}},
#  {'attributes': {'Date': 1597122000000,
#    'Negative': 58791,
#    'Positive': 8092,
#    'Total': 66883,
#    'PercentPositive': 12.1,
#    'ObjectId': 2664}},
#  {'attributes': {'Date': 1597208400000,
#    'Negative': 58122,
#    'Positive': 6226,
#    'Total': 64348,
#    'PercentPositive': 9.68,
#    'ObjectId': 2665}},
#  {'attributes': {'Date': 1597294800000,
#    'Negative': 68498,
#    'Positive': 6104,
#    'Total': 74602,
#    'PercentPositive': 8.18,
#    'ObjectId': 2666}},
#  {'attributes': {'Date': 1597381200000,
#    'Negative': 74356,
#    'Positive': 6275,
#    'Total': 80631,
#    'PercentPositive': 7.78,
#    'ObjectId': 2667}},
#  {'attributes': {'Date': 1597467600000,
#    'Negative': 44850,
#    'Positive': 3805,
#    'Total': 48655,
#    'PercentPositive': 7.82,
#    'ObjectId': 2668}},
#  {'attributes': {'Date': 1597554000000,
#    'Negative': 29849,
#    'Positive': 2675,
#    'Total': 32524,
#    'PercentPositive': 8.22,
#    'ObjectId': 2669}},
#  {'attributes': {'Date': 1597640400000,
#    'Negative': 44298,
#    'Positive': 3863,
#    'Total': 48161,
#    'PercentPositive': 8.02,
#    'ObjectId': 2670}},
#  {'attributes': {'Date': 1597726800000,
#    'Negative': 53595,
#    'Positive': 4118,
#    'Total': 57713,
#    'PercentPositive': 7.14,
#    'ObjectId': 2671}},
#  {'attributes': {'Date': 1597813200000,
#    'Negative': 61558,
#    'Positive': 4536,
#    'Total': 66094,
#    'PercentPositive': 6.86,
#    'ObjectId': 2672}},
#  {'attributes': {'Date': 1597899600000,
#    'Negative': 62637,
#    'Positive': 4629,
#    'Total': 67266,
#    'PercentPositive': 6.88,
#    'ObjectId': 2673}},
#  {'attributes': {'Date': 1597986000000,
#    'Negative': 80648,
#    'Positive': 4298,
#    'Total': 84946,
#    'PercentPositive': 5.06,
#    'ObjectId': 2674}},
#  {'attributes': {'Date': 1598072400000,
#    'Negative': 49306,
#    'Positive': 2999,
#    'Total': 52305,
#    'PercentPositive': 5.73,
#    'ObjectId': 2675}},
#  {'attributes': {'Date': 1598158800000,
#    'Negative': 37027,
#    'Positive': 2045,
#    'Total': 39072,
#    'PercentPositive': 5.23,
#    'ObjectId': 2676}},
#  {'attributes': {'Date': 1598245200000,
#    'Negative': 33436,
#    'Positive': 2728,
#    'Total': 36164,
#    'PercentPositive': 7.54,
#    'ObjectId': 2677}},
#  {'attributes': {'Date': 1598331600000,
#    'Negative': 53148,
#    'Positive': 3249,
#    'Total': 56397,
#    'PercentPositive': 5.76,
#    'ObjectId': 2678}},
#  {'attributes': {'Date': 1598418000000,
#    'Negative': 47392,
#    'Positive': 3168,
#    'Total': 50560,
#    'PercentPositive': 6.27,
#    'ObjectId': 2679}},
#  {'attributes': {'Date': 1598504400000,
#    'Negative': 61531,
#    'Positive': 3570,
#    'Total': 65101,
#    'PercentPositive': 5.48,
#    'ObjectId': 2680}},
#  {'attributes': {'Date': 1598590800000,
#    'Negative': 59700,
#    'Positive': 3101,
#    'Total': 62801,
#    'PercentPositive': 4.94,
#    'ObjectId': 2681}},
#  {'attributes': {'Date': 1598677200000,
#    'Negative': 49223,
#    'Positive': 2604,
#    'Total': 51827,
#    'PercentPositive': 5.02,
#    'ObjectId': 2682}},
#  {'attributes': {'Date': 1598763600000,
#    'Negative': 31819,
#    'Positive': 1682,
#    'Total': 33501,
#    'PercentPositive': 5.02,
#    'ObjectId': 2683}},
#  {'attributes': {'Date': 1598850000000,
#    'Negative': 102702,
#    'Positive': 7415,
#    'Total': 110117,
#    'PercentPositive': 6.73,
#    'ObjectId': 2684}},
#  {'attributes': {'Date': 1598936400000,
#    'Negative': 41425,
#    'Positive': 2496,
#    'Total': 43921,
#    'PercentPositive': 5.68,
#    'ObjectId': 2685}},
#  {'attributes': {'Date': 1599022800000,
#    'Negative': 53709,
#    'Positive': 3585,
#    'Total': 57294,
#    'PercentPositive': 6.26,
#    'ObjectId': 2686}},
#  {'attributes': {'Date': 1599109200000,
#    'Negative': 59150,
#    'Positive': 3211,
#    'Total': 62361,
#    'PercentPositive': 5.15,
#    'ObjectId': 2687}},
#  {'attributes': {'Date': 1599195600000,
#    'Negative': 57720,
#    'Positive': 3672,
#    'Total': 61392,
#    'PercentPositive': 5.98,
#    'ObjectId': 2688}},
#  {'attributes': {'Date': 1599282000000,
#    'Negative': 47429,
#    'Positive': 2467,
#    'Total': 49896,
#    'PercentPositive': 4.94,
#    'ObjectId': 2689}},
#  {'attributes': {'Date': 1599368400000,
#    'Negative': 38866,
#    'Positive': 1866,
#    'Total': 40732,
#    'PercentPositive': 4.58,
#    'ObjectId': 2690}},
#  {'attributes': {'Date': 1599454800000,
#    'Negative': 34470,
#    'Positive': 1800,
#    'Total': 36270,
#    'PercentPositive': 4.96,
#    'ObjectId': 2691}},
#  {'attributes': {'Date': 1599541200000,
#    'Negative': 36480,
#    'Positive': 2325,
#    'Total': 38805,
#    'PercentPositive': 5.99,
#    'ObjectId': 2692}},
#  {'attributes': {'Date': 1599627600000,
#    'Negative': 43226,
#    'Positive': 2528,
#    'Total': 45754,
#    'PercentPositive': 5.53,
#    'ObjectId': 2693}},
#  {'attributes': {'Date': 1599714000000,
#    'Negative': 62306,
#    'Positive': 3650,
#    'Total': 65956,
#    'PercentPositive': 5.53,
#    'ObjectId': 2694}},
#  {'attributes': {'Date': 1599800400000,
#    'Negative': 68053,
#    'Positive': 3159,
#    'Total': 71212,
#    'PercentPositive': 4.44,
#    'ObjectId': 2695}},
#  {'attributes': {'Date': 1599886800000,
#    'Negative': 53553,
#    'Positive': 2374,
#    'Total': 55927,
#    'PercentPositive': 4.24,
#    'ObjectId': 2696}},
#  {'attributes': {'Date': 1599973200000,
#    'Negative': 44162,
#    'Positive': 1778,
#    'Total': 45940,
#    'PercentPositive': 3.87,
#    'ObjectId': 2697}},
#  {'attributes': {'Date': 1600059600000,
#    'Negative': 60350,
#    'Positive': 2648,
#    'Total': 62998,
#    'PercentPositive': 4.2,
#    'ObjectId': 2698}},
#  {'attributes': {'Date': 1600146000000,
#    'Negative': 49187,
#    'Positive': 2301,
#    'Total': 51488,
#    'PercentPositive': 4.47,
#    'ObjectId': 2699}},
#  {'attributes': {'Date': 1600232400000,
#    'Negative': 69791,
#    'Positive': 3265,
#    'Total': 73056,
#    'PercentPositive': 4.47,
#    'ObjectId': 2700}},
#  {'attributes': {'Date': 1600318800000,
#    'Negative': 72781,
#    'Positive': 3187,
#    'Total': 75968,
#    'PercentPositive': 4.2,
#    'ObjectId': 2701}},
#  {'attributes': {'Date': 1600405200000,
#    'Negative': 74481,
#    'Positive': 3554,
#    'Total': 78035,
#    'PercentPositive': 4.55,
#    'ObjectId': 2702}},
#  {'attributes': {'Date': 1600491600000,
#    'Negative': 50868,
#    'Positive': 2495,
#    'Total': 53363,
#    'PercentPositive': 4.68,
#    'ObjectId': 2703}},
#  {'attributes': {'Date': 1600578000000,
#    'Negative': 36560,
#    'Positive': 1653,
#    'Total': 38213,
#    'PercentPositive': 4.33,
#    'ObjectId': 2704}},
#  {'attributes': {'Date': 1600664400000,
#    'Negative': 38082,
#    'Positive': 2387,
#    'Total': 40469,
#    'PercentPositive': 5.9,
#    'ObjectId': 2705}},
#  {'attributes': {'Date': 1600750800000,
#    'Negative': 46249,
#    'Positive': 2590,
#    'Total': 48839,
#    'PercentPositive': 5.3,
#    'ObjectId': 2706}},
#  {'attributes': {'Date': 1600837200000,
#    'Negative': 55371,
#    'Positive': 2590,
#    'Total': 57961,
#    'PercentPositive': 4.47,
#    'ObjectId': 2707}},
#  {'attributes': {'Date': 1600923600000,
#    'Negative': 62643,
#    'Positive': 2807,
#    'Total': 65450,
#    'PercentPositive': 4.29,
#    'ObjectId': 2708}},
#  {'attributes': {'Date': 1601010000000,
#    'Negative': 63539,
#    'Positive': 2765,
#    'Total': 66304,
#    'PercentPositive': 4.17,
#    'ObjectId': 2709}},
#  {'attributes': {'Date': 1601096400000,
#    'Negative': 43338,
#    'Positive': 1839,
#    'Total': 45177,
#    'PercentPositive': 4.07,
#    'ObjectId': 2710}},
#  {'attributes': {'Date': 1601182800000,
#    'Negative': 18169,
#    'Positive': 808,
#    'Total': 18977,
#    'PercentPositive': 4.26,
#    'ObjectId': 2711}},
#  {'attributes': {'Date': 1601269200000,
#    'Negative': 60922,
#    'Positive': 3184,
#    'Total': 64106,
#    'PercentPositive': 4.97,
#    'ObjectId': 2712}},
#  {'attributes': {'Date': 1601355600000,
#    'Negative': 38602,
#    'Positive': 2051,
#    'Total': 40653,
#    'PercentPositive': 5.05,
#    'ObjectId': 2713}},
#  {'attributes': {'Date': 1601442000000,
#    'Negative': 57002,
#    'Positive': 2798,
#    'Total': 59800,
#    'PercentPositive': 4.68,
#    'ObjectId': 2714}},
#  {'attributes': {'Date': 1601528400000,
#    'Negative': 67775,
#    'Positive': 2663,
#    'Total': 70438,
#    'PercentPositive': 3.78,
#    'ObjectId': 2715}},
#  {'attributes': {'Date': 1601614800000,
#    'Negative': 55372,
#    'Positive': 2768,
#    'Total': 58140,
#    'PercentPositive': 4.76,
#    'ObjectId': 2716}},
#  {'attributes': {'Date': 1601701200000,
#    'Negative': 47474,
#    'Positive': 1857,
#    'Total': 49331,
#    'PercentPositive': 3.76,
#    'ObjectId': 2717}},
#  {'attributes': {'Date': 1601787600000,
#    'Negative': 33923,
#    'Positive': 1380,
#    'Total': 35303,
#    'PercentPositive': 3.91,
#    'ObjectId': 2718}},
#  {'attributes': {'Date': 1601874000000,
#    'Negative': 40665,
#    'Positive': 2261,
#    'Total': 42926,
#    'PercentPositive': 5.27,
#    'ObjectId': 2719}},
#  {'attributes': {'Date': 1601960400000,
#    'Negative': 58210,
#    'Positive': 2501,
#    'Total': 60711,
#    'PercentPositive': 4.12,
#    'ObjectId': 2720}},
#  {'attributes': {'Date': 1602046800000,
#    'Negative': 68019,
#    'Positive': 3258,
#    'Total': 71277,
#    'PercentPositive': 4.57,
#    'ObjectId': 2721}},
#  {'attributes': {'Date': 1602133200000,
#    'Negative': 66609,
#    'Positive': 2866,
#    'Total': 69475,
#    'PercentPositive': 4.13,
#    'ObjectId': 2722}},
#  {'attributes': {'Date': 1602219600000,
#    'Negative': 20692,
#    'Positive': 1779,
#    'Total': 22471,
#    'PercentPositive': 7.92,
#    'ObjectId': 2723}},
#  {'attributes': {'Date': 1602306000000,
#    'Negative': 101970,
#    'Positive': 3633,
#    'Total': 105603,
#    'PercentPositive': 3.44,
#    'ObjectId': 2724}},
#  {'attributes': {'Date': 1602392400000,
#    'Negative': 35177,
#    'Positive': 1564,
#    'Total': 36741,
#    'PercentPositive': 4.26,
#    'ObjectId': 2725}},
#  {'attributes': {'Date': 1602478800000,
#    'Negative': 50977,
#    'Positive': 2678,
#    'Total': 53655,
#    'PercentPositive': 4.99,
#    'ObjectId': 2726}},
#  {'attributes': {'Date': 1602565200000,
#    'Negative': 49678,
#    'Positive': 2835,
#    'Total': 52513,
#    'PercentPositive': 5.4,
#    'ObjectId': 2727}},
#  {'attributes': {'Date': 1602651600000,
#    'Negative': 60120,
#    'Positive': 3288,
#    'Total': 63408,
#    'PercentPositive': 5.19,
#    'ObjectId': 2728}},
#  {'attributes': {'Date': 1602738000000,
#    'Negative': 74040,
#    'Positive': 3380,
#    'Total': 77420,
#    'PercentPositive': 4.37,
#    'ObjectId': 2729}},
#  {'attributes': {'Date': 1602824400000,
#    'Negative': 72598,
#    'Positive': 3976,
#    'Total': 76574,
#    'PercentPositive': 5.19,
#    'ObjectId': 2730}},
#  {'attributes': {'Date': 1602910800000,
#    'Negative': 50540,
#    'Positive': 2462,
#    'Total': 53002,
#    'PercentPositive': 4.65,
#    'ObjectId': 2731}},
#  {'attributes': {'Date': 1602997200000,
#    'Negative': 34221,
#    'Positive': 1743,
#    'Total': 35964,
#    'PercentPositive': 4.85,
#    'ObjectId': 2732}},
#  {'attributes': {'Date': 1603083600000,
#    'Negative': 54538,
#    'Positive': 3580,
#    'Total': 58118,
#    'PercentPositive': 6.16,
#    'ObjectId': 2733}},
#  {'attributes': {'Date': 1603170000000,
#    'Negative': 29657,
#    'Positive': 2138,
#    'Total': 31795,
#    'PercentPositive': 6.72,
#    'ObjectId': 2734}},
#  {'attributes': {'Date': 1603256400000,
#    'Negative': 91563,
#    'Positive': 5430,
#    'Total': 96993,
#    'PercentPositive': 5.6,
#    'ObjectId': 2735}},
#  {'attributes': {'Date': 1603342800000,
#    'Negative': 88719,
#    'Positive': 3694,
#    'Total': 92413,
#    'PercentPositive': 4,
#    'ObjectId': 2736}},
#  {'attributes': {'Date': 1603429200000,
#    'Negative': 115707,
#    'Positive': 4390,
#    'Total': 120097,
#    'PercentPositive': 3.66,
#    'ObjectId': 2737}},
#  {'attributes': {'Date': 1603515600000,
#    'Negative': 47694,
#    'Positive': 2341,
#    'Total': 50035,
#    'PercentPositive': 4.68,
#    'ObjectId': 2738}},
#  {'attributes': {'Date': 1603602000000,
#    'Negative': 52940,
#    'Positive': 3323,
#    'Total': 56263,
#    'PercentPositive': 5.91,
#    'ObjectId': 2739}},
#  {'attributes': {'Date': 1603688400000,
#    'Negative': 63391,
#    'Positive': 4256,
#    'Total': 67647,
#    'PercentPositive': 6.29,
#    'ObjectId': 2740}},
#  {'attributes': {'Date': 1603774800000,
#    'Negative': 70711,
#    'Positive': 4039,
#    'Total': 74750,
#    'PercentPositive': 5.4,
#    'ObjectId': 2741}},
#  {'attributes': {'Date': 1603861200000,
#    'Negative': 81096,
#    'Positive': 4150,
#    'Total': 85246,
#    'PercentPositive': 4.87,
#    'ObjectId': 2742}},
#  {'attributes': {'Date': 1603947600000,
#    'Negative': 87004,
#    'Positive': 5419,
#    'Total': 92423,
#    'PercentPositive': 5.86,
#    'ObjectId': 2743}},
#  {'attributes': {'Date': 1604034000000,
#    'Negative': 34698,
#    'Positive': 2340,
#    'Total': 37038,
#    'PercentPositive': 6.32,
#    'ObjectId': 2744}}]

# %%
test_num = pd.DataFrame.from_dict(test['features'][0])

# %%
test_num = test_num.T

# %%
test_num
# Out:
#                      Date  Negative  ObjectId  PercentPositive  Positive  \
# attributes  1580187600000         1      2492                0         0
#
#             Total
# attributes      1

# %%
for rows in range(1,len(test['features'])):
    row_df = pd.DataFrame.from_dict(test['features'][rows])
    row_df = row_df.T
    test_num = pd.concat([test_num,row_df])

# %%
from datetime import datetime, timedelta

# %%
pd.to_datetime(test_num.Date, unit='ms')
# Out:
# attributes   2020-01-28 05:00:00
# attributes   2020-01-30 05:00:00
# attributes   2020-02-03 05:00:00
# attributes   2020-02-07 05:00:00
# attributes   2020-02-10 05:00:00
#                      ...
# attributes   2020-10-26 05:00:00
# attributes   2020-10-27 05:00:00
# attributes   2020-10-28 05:00:00
# attributes   2020-10-29 05:00:00
# attributes   2020-10-30 05:00:00
# Name: Date, Length: 253, dtype: datetime64[ns]

# %%
start = datetime(1970, 1, 1)

# %%
test_num['date1'] = test_num.Date.apply(lambda x: start + timedelta(seconds=x))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-97-23bbcb9a37a9> in <module>
# ----> 1 test_num['date1'] = test_num.Date.apply(lambda x: start + timedelta(seconds=x))
#
# E:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-97-23bbcb9a37a9> in <lambda>(x)
# ----> 1 test_num['date1'] = test_num.Date.apply(lambda x: start + timedelta(seconds=x))
#
# OverflowError: date value out of range

# %%
test_num.Positive.plot()
