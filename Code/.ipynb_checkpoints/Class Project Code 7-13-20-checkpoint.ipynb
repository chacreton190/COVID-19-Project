# %% [markdown]
# # Downloading COVID Data From FloridaDisaster.ORG

# %% [markdown]
# ### To Do
# - [ ] Turn all of the processes into functions
# - [ ] **IMPORTANT**: THE LARGE NEGATIVE NUMBERS FOR DADE DO NOT SEEM TO BE CORRECT. FIND OUT WHAT IS GOING ON THERE
# - [ ] **IMPORTANT**: Something happens to the data at 7/6 after this point everything is wrong, why???
# - [ ] Figure out why 3-19-20(PM) PDF returns null in the html file
# - [ ] Revise the code that imports the html data so that it reads the column headers withou t (Consider using a list with all of the possible values of col head then if found append the list value to header.)
# - [ ]
# - [ ]

# %% [markdown]
# ### Completed
# - [X] **IMPORTANT**: Fix this error '5-31-2020('
# - [X] Fix the problem where before doh reported 0 as 0 and not missing, I can't use the data
# - [X] Clean the changing column names at the text export stage
# - [X] Figure out my headers are messed up
# - [X] Why are there so many obs for 3/18
# - [X] Extract the page range 12-25
# - [X] Find the pages that contain the words "Coronavirus: All persons tested"
# - [X] Extract just those two pages pdf
# - [X] Export individual files to txt for storage
# - [X] Fix/find out why reports 3/19 - 3/24 are only 1kb and hold no data (There were 3 different page titles not 2)

# %%
from selenium import webdriver
import os
import wget
import PyPDF2 as pdf
from PyPDF2 import PdfFileReader, PdfFileWriter
import time
import textract
from pathlib import Path
import re
import pandas as pd
import datetime

# %%
chrome_path = r"chromedriver.exe"

# %% [markdown]
# ## Initializing driver element and finding

# %%
driver = webdriver.Chrome(chrome_path)

# %%
driver.get('https://floridadisaster.org/covid19/covid-19-data-reports/')
title = driver.title
time.sleep(3)
result = driver.find_elements_by_xpath("//a[@href]")
report_months= ['June Reports', 'May Reports', 'April Reports', 'March Reports']
expanded = 0
if expanded == 0:
    for item in result:
        for months in report_months:
            if item.text.find(months) >= 0:
                item.click()
                expanded = 1
time.sleep(3)
result_full = driver.find_elements_by_xpath("//a[@href]")

# %% [markdown]
# Initializing the output paths

# %%
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\PDF')
pdf_output_path= output_path.resolve()
pdf_extract_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\Unclean PDF')
pdf_extract_path = pdf_extract_path.resolve()

# %%
pdf_output_path
# Out:
# WindowsPath('C:/Users/chacr/OneDrive/Documents/Coding/Python/USF/COVID-19 Project/Data/PDF')

# %% [markdown]
# ## Downloads the PDF Files from FloridaDisaster.ORG

# %%
print('Starting Data Download')
link_counter = 0
download_counter = 0 
link_n = len(result_full) -152
download_list = []
for links in result_full:
    if links.text.find('Data Report') > 0:
        link_url = links.get_attribute('href')
        filename = wget.filename_from_url(link_url)
        if not os.path.exists(f'{pdf_output_path}/{filename}'):
            wget.download(link_url, out = f'{pdf_output_path}')
            download_counter += 1
            download_list.append
            print("Downloading", links.text)
        link_counter +=1
        print (f'{round((link_counter)*100/link_n,2)}% Complete')
print('Download of New Files Complete')
print(f'{download_counter} Files Created')
# Out:
# Starting Data Download
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3aafa377b505> in <module>
#       2 link_counter = 0
#       3 download_counter = 0
# ----> 4 link_n = len(result_full) -152
#       5 download_list = []
#       6 for links in result_full:
#
# NameError: name 'result_full' is not defined

# %%
driver.close()

# %% [markdown]
# ### Extracting the min and max page range for the COVID-19 Daily County Data

# %%
#turn into a function
def PdfPageExtract(input_path, output_path, page_num):
    import time
    import os
    import PyPDF2 as pdf
    from PyPDF2 import PdfFileReader, PdfFileWriter
    import textract
    import re
    pdf_extract_list = []
    date_fmt = r'(^.+\D)_(\d+)_(\d+)(\.pdf\Z)'
    print('Program Started')
    page_counter = 0
    today = datetime.date.today()
    file_num = len(os.listdir(input_path))
    file_exist_n =0
    progress = 0
    for files in os.listdir(input_path):
        if re.search(date_fmt, files ):
#             print(files) 
            mod_files = re.sub(date_fmt, r'\1 \2-\3-2020.pdf', files )
#             print(mod_files)    
            output = f'{output_path}/(7-11-20) Unclean Extract from {mod_files}'
        else:
            output = f'{output_path}/(7-11-20) Unclean Extract from {files}'
        progress += 1
        if os.path.exists(output):
            file_exist_n +=1
            print(f'{round((progress/file_num)* 100,2)}%', 'Complete', 'File exists')
            continue
        else:
            print('Creating the file', output)
            pdf_writer = PdfFileWriter()
            pdf_file = open(f'{input_path}/{files}','rb')
            pdfreader = PdfFileReader(pdf_file)
            num_pages = pdfreader.numPages
            if num_pages < page_num:
                up_limit = num_pages
            else:
                up_limit = page_num
            for pages in range(3, up_limit):
                page =  pdfreader.getPage(pages)  
                if page.extractText().find('COVID-19: All persons with tests reported') > 0 or page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All persons tested') > 0 or page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All') > 0:
                    pdf_writer.addPage(page) 
            
            with open(output, 'wb') as output_pdf:
                pdf_writer.write(output_pdf)
            pdf_extract_list.append(files)
            print(f'{round((progress/file_num)* 100,2)}% ', 'Complete' , 'File created')
    
    if file_exist_n == file_num:
        print('All Files Previously Created')
    else:
        print(f'{file_num -file_exist_n} New Files Created')
    return pdf_extract_list

page_limit = 26

PdfPageExtract(pdf_output_path, pdf_extract_path, page_limit)
# Out:
# Program Started
# 0.65% Complete File exists
# 1.3% Complete File exists
# 1.95% Complete File exists
# 2.6% Complete File exists
# 3.25% Complete File exists
# 3.9% Complete File exists
# 4.55% Complete File exists
# 5.19% Complete File exists
# 5.84% Complete File exists
# 6.49% Complete File exists
# 7.14% Complete File exists
# 7.79% Complete File exists
# 8.44% Complete File exists
# 9.09% Complete File exists
# 9.74% Complete File exists
# 10.39% Complete File exists
# 11.04% Complete File exists
# 11.69% Complete File exists
# 12.34% Complete File exists
# 12.99% Complete File exists
# 13.64% Complete File exists
# 14.29% Complete File exists
# 14.94% Complete File exists
# 15.58% Complete File exists
# 16.23% Complete File exists
# 16.88% Complete File exists
# 17.53% Complete File exists
# 18.18% Complete File exists
# 18.83% Complete File exists
# 19.48% Complete File exists
# 20.13% Complete File exists
# 20.78% Complete File exists
# 21.43% Complete File exists
# 22.08% Complete File exists
# 22.73% Complete File exists
# 23.38% Complete File exists
# 24.03% Complete File exists
# 24.68% Complete File exists
# 25.32% Complete File exists
# 25.97% Complete File exists
# 26.62% Complete File exists
# 27.27% Complete File exists
# 27.92% Complete File exists
# 28.57% Complete File exists
# 29.22% Complete File exists
# 29.87% Complete File exists
# 30.52% Complete File exists
# 31.17% Complete File exists
# 31.82% Complete File exists
# 32.47% Complete File exists
# 33.12% Complete File exists
# 33.77% Complete File exists
# 34.42% Complete File exists
# 35.06% Complete File exists
# 35.71% Complete File exists
# 36.36% Complete File exists
# 37.01% Complete File exists
# 37.66% Complete File exists
# 38.31% Complete File exists
# 38.96% Complete File exists
# 39.61% Complete File exists
# 40.26% Complete File exists
# 40.91% Complete File exists
# 41.56% Complete File exists
# 42.21% Complete File exists
# 42.86% Complete File exists
# 43.51% Complete File exists
# 44.16% Complete File exists
# 44.81% Complete File exists
# 45.45% Complete File exists
# 46.1% Complete File exists
# 46.75% Complete File exists
# 47.4% Complete File exists
# 48.05% Complete File exists
# 48.7% Complete File exists
# 49.35% Complete File exists
# 50.0% Complete File exists
# 50.65% Complete File exists
# 51.3% Complete File exists
# 51.95% Complete File exists
# 52.6% Complete File exists
# 53.25% Complete File exists
# 53.9% Complete File exists
# 54.55% Complete File exists
# 55.19% Complete File exists
# 55.84% Complete File exists
# 56.49% Complete File exists
# 57.14% Complete File exists
# 57.79% Complete File exists
# 58.44% Complete File exists
# 59.09% Complete File exists
# 59.74% Complete File exists
# 60.39% Complete File exists
# 61.04% Complete File exists
# 61.69% Complete File exists
# 62.34% Complete File exists
# 62.99% Complete File exists
# 63.64% Complete File exists
# 64.29% Complete File exists
# 64.94% Complete File exists
# 65.58% Complete File exists
# 66.23% Complete File exists
# 66.88% Complete File exists
# 67.53% Complete File exists
# 68.18% Complete File exists
# 68.83% Complete File exists
# 69.48% Complete File exists
# 70.13% Complete File exists
# 70.78% Complete File exists
# 71.43% Complete File exists
# 72.08% Complete File exists
# 72.73% Complete File exists
# 73.38% Complete File exists
# 74.03% Complete File exists
# 74.68% Complete File exists
# 75.32% Complete File exists
# 75.97% Complete File exists
# 76.62% Complete File exists
# 77.27% Complete File exists
# 77.92% Complete File exists
# 78.57% Complete File exists
# 79.22% Complete File exists
# 79.87% Complete File exists
# 80.52% Complete File exists
# 81.17% Complete File exists
# 81.82% Complete File exists
# 82.47% Complete File exists
# 83.12% Complete File exists
# 83.77% Complete File exists
# 84.42% Complete File exists
# 85.06% Complete File exists
# 85.71% Complete File exists
# 86.36% Complete File exists
# 87.01% Complete File exists
# 87.66% Complete File exists
# 88.31% Complete File exists
# 88.96% Complete File exists
# 89.61% Complete File exists
# 90.26% Complete File exists
# 90.91% Complete File exists
# 91.56% Complete File exists
# 92.21% Complete File exists
# 92.86% Complete File exists
# 93.51% Complete File exists
# 94.16% Complete File exists
# 94.81% Complete File exists
# 95.45% Complete File exists
# 96.1% Complete File exists
# 96.75% Complete File exists
# 97.4% Complete File exists
# 98.05% Complete File exists
# 98.7% Complete File exists
# 99.35% Complete File exists
# 100.0% Complete File exists
# All Files Previously Created
# []

# %%
today = datetime.date.today()
file_list = PdfPageExtract(pdf_output_path, pdf_extract_path, page_limit)
print(f'List of PDF file extracts created {today}')
print('_'*100)
for files in file_list:
    print(files)
# Out:
# Program Started
# 0.65% Complete File exists
# 1.3% Complete File exists
# 1.95% Complete File exists
# 2.6% Complete File exists
# 3.25% Complete File exists
# 3.9% Complete File exists
# 4.55% Complete File exists
# 5.19% Complete File exists
# 5.84% Complete File exists
# 6.49% Complete File exists
# 7.14% Complete File exists
# 7.79% Complete File exists
# 8.44% Complete File exists
# 9.09% Complete File exists
# 9.74% Complete File exists
# 10.39% Complete File exists
# 11.04% Complete File exists
# 11.69% Complete File exists
# 12.34% Complete File exists
# 12.99% Complete File exists
# 13.64% Complete File exists
# 14.29% Complete File exists
# 14.94% Complete File exists
# 15.58% Complete File exists
# 16.23% Complete File exists
# 16.88% Complete File exists
# 17.53% Complete File exists
# 18.18% Complete File exists
# 18.83% Complete File exists
# 19.48% Complete File exists
# 20.13% Complete File exists
# 20.78% Complete File exists
# 21.43% Complete File exists
# 22.08% Complete File exists
# 22.73% Complete File exists
# 23.38% Complete File exists
# 24.03% Complete File exists
# 24.68% Complete File exists
# 25.32% Complete File exists
# 25.97% Complete File exists
# 26.62% Complete File exists
# 27.27% Complete File exists
# 27.92% Complete File exists
# 28.57% Complete File exists
# 29.22% Complete File exists
# 29.87% Complete File exists
# 30.52% Complete File exists
# 31.17% Complete File exists
# 31.82% Complete File exists
# 32.47% Complete File exists
# 33.12% Complete File exists
# 33.77% Complete File exists
# 34.42% Complete File exists
# 35.06% Complete File exists
# 35.71% Complete File exists
# 36.36% Complete File exists
# 37.01% Complete File exists
# 37.66% Complete File exists
# 38.31% Complete File exists
# 38.96% Complete File exists
# 39.61% Complete File exists
# 40.26% Complete File exists
# 40.91% Complete File exists
# 41.56% Complete File exists
# 42.21% Complete File exists
# 42.86% Complete File exists
# 43.51% Complete File exists
# 44.16% Complete File exists
# 44.81% Complete File exists
# 45.45% Complete File exists
# 46.1% Complete File exists
# 46.75% Complete File exists
# 47.4% Complete File exists
# 48.05% Complete File exists
# 48.7% Complete File exists
# 49.35% Complete File exists
# 50.0% Complete File exists
# 50.65% Complete File exists
# 51.3% Complete File exists
# 51.95% Complete File exists
# 52.6% Complete File exists
# 53.25% Complete File exists
# 53.9% Complete File exists
# 54.55% Complete File exists
# 55.19% Complete File exists
# 55.84% Complete File exists
# 56.49% Complete File exists
# 57.14% Complete File exists
# 57.79% Complete File exists
# 58.44% Complete File exists
# 59.09% Complete File exists
# 59.74% Complete File exists
# 60.39% Complete File exists
# 61.04% Complete File exists
# 61.69% Complete File exists
# 62.34% Complete File exists
# 62.99% Complete File exists
# 63.64% Complete File exists
# 64.29% Complete File exists
# 64.94% Complete File exists
# 65.58% Complete File exists
# 66.23% Complete File exists
# 66.88% Complete File exists
# 67.53% Complete File exists
# 68.18% Complete File exists
# 68.83% Complete File exists
# 69.48% Complete File exists
# 70.13% Complete File exists
# 70.78% Complete File exists
# 71.43% Complete File exists
# 72.08% Complete File exists
# 72.73% Complete File exists
# 73.38% Complete File exists
# 74.03% Complete File exists
# 74.68% Complete File exists
# 75.32% Complete File exists
# 75.97% Complete File exists
# 76.62% Complete File exists
# 77.27% Complete File exists
# 77.92% Complete File exists
# 78.57% Complete File exists
# 79.22% Complete File exists
# 79.87% Complete File exists
# 80.52% Complete File exists
# 81.17% Complete File exists
# 81.82% Complete File exists
# 82.47% Complete File exists
# 83.12% Complete File exists
# 83.77% Complete File exists
# 84.42% Complete File exists
# 85.06% Complete File exists
# 85.71% Complete File exists
# 86.36% Complete File exists
# 87.01% Complete File exists
# 87.66% Complete File exists
# 88.31% Complete File exists
# 88.96% Complete File exists
# 89.61% Complete File exists
# 90.26% Complete File exists
# 90.91% Complete File exists
# 91.56% Complete File exists
# 92.21% Complete File exists
# 92.86% Complete File exists
# 93.51% Complete File exists
# 94.16% Complete File exists
# 94.81% Complete File exists
# 95.45% Complete File exists
# 96.1% Complete File exists
# 96.75% Complete File exists
# 97.4% Complete File exists
# 98.05% Complete File exists
# 98.7% Complete File exists
# 99.35% Complete File exists
# 100.0% Complete File exists
# All Files Previously Created
# List of PDF file extracts created 2020-07-13
# ____________________________________________________________________________________________________

# %% [markdown]
# # Converting the PDFs to html files

# %%
from pathlib import Path

input_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\Unclean PDF')
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html')
ip = input_path.resolve()
op = output_path.resolve()

# %%
import os
import pdftotree
import re
import sys
print('Program started')
html_created_list= []
file_n = len(os.listdir(ip))
file_ct = 0
file_exist_n =0
error_list = []
date1 = r'^.*(\d{2})-*(\d{2})-*(\d{4}).*\Z'
date2 = r'^.*(\d+)_(\d+)_(\d+).*\Z'
date3 = r'^.*(\d{4})-*(\d{2})-*(\d{2}).*\Z'
date4 = r'^.*\D(\d)\.(\d+)\.(\d+).*\Z'
date5 = r'^.*(\d{2})_(\d{2})\Z'
date6 = r'^.*-(\d{1})(\d{2})(\d{2})_.*\Z'
# date_format = r'(^.+)\D(\d-)(.*\Z)'
last_file_name = ''
for files in os.listdir(ip):
    file_ct += 1
    if re.search(date3,files):
#     test_name = re.sub(date3, r'html version of FL COVID Rep \2-\3-\1.html',files)
#     if 
        match = 1
        new_file_name = re.sub(date3, r'html version of FL COVID Rep \2-\3-\1.html',files)    
    elif re.search(date1,files):
        match = 2
        new_file_name = re.sub(date1, r'html version of FL COVID Rep \1-\2-\3.html',files)
    elif re.search(date2,files):
        match = 3        
        new_file_name = re.sub(date2, r'html version of FL COVID Rep 0\1-\2-\3.html',files)
    elif re.search(date4,files):        
        match = 4
        new_file_name = re.sub(date4, r'html version of FL COVID Rep 0\1-\2-2020.html',files)
    elif re.search(date5,files):
        match = 5
        new_file_name = re.sub(date5, r'html version of FL COVID Rep \1-\2-2020.html',files)
    elif re.search(date6,files):
        match = 6
        new_file_name = re.sub(date6, r'html version of FL COVID Rep 0\1-\2-2020.html',files)
        match = 7
    else:
        print("!" *36,'ERROR: Date Not found in File name',"!" *36)
        print('_'*100)
        print('Infile path:', ip)
        print('Outfile path:',op)
        print('Current File Path:',files)
        print('Current File name:',new_file_name)
        print('Prevous File name:',last_file_name)
        sys.exit()
        
    
    new_file_name = re.sub('20-20-0606', '06-06-2020', new_file_name)  
#     new_file_name = re.sub(date_format, r'\1-0\2\3', new_file_name)


    if last_file_name == new_file_name and new_file_name.find('PM') < 0:
        new_file_name = new_file_name.replace('.html', '(PM).html')
    in_file_path = f'{ip}/{files}'
    
    output_file_path = f'{op}\\{new_file_name}.html'
    if os.path.exists(output_file_path):
        file_exist_n +=1
        last_file_name = new_file_name
    else:
        html_created_list.append(output_file_path)
#         print('The infile path is:', in_file_path)
#         print('Creating the html file:', new_file_name, match)
        html = pdftotree.parse(in_file_path)
        with open(output_file_path,'w') as f:
            f.write(html)
        last_file_name = new_file_name

    print(f'{round((file_ct/file_n)*100)}% Complete') 
if file_exist_n == file_n:
    print('All Files Previously Created')
    print('Program Completed')
else:
    print(f'{file_n - file_exist_n} New Files Created')
    print('Files Created List')
    print('-'*100)
    for files in html_created_list:
        print(files)
    print('Program Completed')
# Out:
# Program started
# 1% Complete
# 1% Complete
# 2% Complete
# 3% Complete
# 3% Complete
# 4% Complete
# 5% Complete
# 5% Complete
# 6% Complete
# 6% Complete
# 7% Complete
# 8% Complete
# 8% Complete
# 9% Complete
# 10% Complete
# 10% Complete
# 11% Complete
# 12% Complete
# 12% Complete
# 13% Complete
# 14% Complete
# 14% Complete
# 15% Complete
# 16% Complete
# 16% Complete
# 17% Complete
# 18% Complete
# 18% Complete
# 19% Complete
# 19% Complete
# 20% Complete
# 21% Complete
# 21% Complete
# 22% Complete
# 23% Complete
# 23% Complete
# 24% Complete
# 25% Complete
# 25% Complete
# 26% Complete
# 27% Complete
# 27% Complete
# 28% Complete
# 29% Complete
# 29% Complete
# 30% Complete
# 31% Complete
# 31% Complete
# 32% Complete
# 32% Complete
# 33% Complete
# 34% Complete
# 34% Complete
# 35% Complete
# 36% Complete
# 36% Complete
# 37% Complete
# 38% Complete
# 38% Complete
# 39% Complete
# 40% Complete
# 40% Complete
# 41% Complete
# 42% Complete
# 42% Complete
# 43% Complete
# 44% Complete
# 44% Complete
# 45% Complete
# 45% Complete
# 46% Complete
# 47% Complete
# 47% Complete
# 48% Complete
# 49% Complete
# 49% Complete
# 50% Complete
# 51% Complete
# 51% Complete
# 52% Complete
# 53% Complete
# 53% Complete
# 54% Complete
# 55% Complete
# 55% Complete
# 56% Complete
# 56% Complete
# 57% Complete
# 58% Complete
# 58% Complete
# 59% Complete
# 60% Complete
# 60% Complete
# 61% Complete
# 62% Complete
# 62% Complete
# 63% Complete
# 64% Complete
# 64% Complete
# 65% Complete
# 66% Complete
# 66% Complete
# 67% Complete
# 68% Complete
# 68% Complete
# 69% Complete
# 69% Complete
# 70% Complete
# (7-11-20) Unclean Extract from covid-daily-report-5.30.20_compressed.pdf
# (7-11-20) Unclean Extract from covid-daily-report-5.31.20_compressed.pdf
# (7-11-20) Unclean Extract from covid-daily-report-51620_compressed.pdf
# (7-11-20) Unclean Extract from covid-daily-report-6.1.20_comprimido.pdf
# (7-11-20) Unclean Extract from covid-daily-report-6.2.20_comprimido.pdf
# (7-11-20) Unclean Extract from covid-daily-report_5.19.20_.pdf
# (7-11-20) Unclean Extract from covid-daily-report_compressed-2020-05-20.pdf
# (7-11-20) Unclean Extract from covid-daily-report_compressed_1_2020-05-21.pdf
# (7-11-20) Unclean Extract from covid-daily-report_compressed_2_2020-05-22.pdf
# (7-11-20) Unclean Extract from state_reports_20200603.pdf
# (7-11-20) Unclean Extract from state_reports_20200604.pdf
# (7-11-20) Unclean Extract from state_reports_20200605.pdf
# (7-11-20) Unclean Extract from state_reports_20200607.pdf
# (7-11-20) Unclean Extract from state_reports_20200608.pdf
# (7-11-20) Unclean Extract from state_reports_20200609.pdf
# (7-11-20) Unclean Extract from state_reports_20200610.pdf
# (7-11-20) Unclean Extract from state_reports_20200611.pdf
# (7-11-20) Unclean Extract from state_reports_20200614.pdf
# (7-11-20) Unclean Extract from state_reports_20200615.pdf
# (7-11-20) Unclean Extract from state_reports_20200616.pdf
# (7-11-20) Unclean Extract from state_reports_20200617.pdf
# (7-11-20) Unclean Extract from state_reports_20200618.pdf
# (7-11-20) Unclean Extract from state_reports_20200619.pdf
# (7-11-20) Unclean Extract from state_reports_20200621.pdf
# (7-11-20) Unclean Extract from state_reports_20200622.pdf
# (7-11-20) Unclean Extract from state_reports_20200623.pdf
# (7-11-20) Unclean Extract from state_reports_20200624.pdf
# (7-11-20) Unclean Extract from state_reports_20200625.pdf
# (7-11-20) Unclean Extract from state_reports_20200626.pdf
# (7-11-20) Unclean Extract from state_reports_20200628.pdf
# (7-11-20) Unclean Extract from state_reports_20200629.pdf
# (7-11-20) Unclean Extract from state_reports_20200630.pdf
# (7-11-20) Unclean Extract from state_reports_20200701.pdf
# (7-11-20) Unclean Extract from state_reports_20200702.pdf
# (7-11-20) Unclean Extract from state_reports_20200703.pdf
# (7-11-20) Unclean Extract from state_reports_20200705.pdf
# (7-11-20) Unclean Extract from state_reports_20200706.pdf
# (7-11-20) Unclean Extract from state_reports_20200707.pdf
# (7-11-20) Unclean Extract from state_reports_20200708.pdf
# (7-11-20) Unclean Extract from state_reports_20200709.pdf
# (7-11-20) Unclean Extract from state_reports_20200710.pdf
# (7-11-20) Unclean Extract from state_reports_20200712.pdf
# (7-11-20) Unclean Extract from state_reports_latest 06-20-2020.pdf
# (7-11-20) Unclean Extract from state_reports_latest 06-27-2020.pdf
# (7-11-20) Unclean Extract from state_reports_latest 07-04-2020.pdf
# (7-11-20) Unclean Extract from state_reports_latest 07-11-2020.pdf
# (7-11-20) Unclean Extract from state_reports_latest_6_12_2020.pdf

# %% [markdown]
# ## List of html Files

# %%
for files in os.listdir(op):
    print(files)
# Out:
# html version of FL COVID Rep 03-16-2020.html.html
# html version of FL COVID Rep 06-15-2020.html.html
# html version of FL COVID Rep 06-16-2020.html.html
# html version of FL COVID Rep 06-17-2020.html.html
# html version of FL COVID Rep 06-18-2020.html.html
# html version of FL COVID Rep 06-19-2020.html.html
# html version of FL COVID Rep 06-2-2020.html.html
# html version of FL COVID Rep 06-20-2020.html.html
# html version of FL COVID Rep 06-21-2020.html.html
# html version of FL COVID Rep 06-22-2020.html.html
# html version of FL COVID Rep 06-23-2020.html.html
# html version of FL COVID Rep 06-24-2020.html.html
# html version of FL COVID Rep 06-25-2020.html.html
# html version of FL COVID Rep 06-26-2020.html.html
# html version of FL COVID Rep 06-27-2020.html.html
# html version of FL COVID Rep 06-28-2020.html.html
# html version of FL COVID Rep 06-29-2020.html.html
# html version of FL COVID Rep 06-30-2020.html.html
# html version of FL COVID Rep 07-01-2020.html.html
# html version of FL COVID Rep 07-02-2020.html.html
# html version of FL COVID Rep 07-03-2020.html.html
# html version of FL COVID Rep 07-04-2020.html.html
# html version of FL COVID Rep 07-05-2020.html.html
# html version of FL COVID Rep 07-06-2020.html.html
# html version of FL COVID Rep 07-07-2020.html.html
# html version of FL COVID Rep 07-08-2020.html.html
# html version of FL COVID Rep 07-09-2020.html.html
# html version of FL COVID Rep 07-10-2020.html.html
# html version of FL COVID Rep 07-11-2020.html.html
# html version of FL COVID Rep 07-12-2020.html.html
# html version of FL COVID Rep 07-13-2020.html.html

# %% [markdown]
# ### Need to fix at some point
# >This code currentlyt does not work converting it to a function will allow for easier reuse

# %%
# def HtmlMaker(input_path, output_path, output_name):
#     import os
#     import pdftotree
#     import re
#     print('Program started')
#     file_n = len(os.listdir(input_path))
#     file_ct = 0
#     error_list = []
#     search_list = [r'^.*(\d+)-*(\d{2})-*(\d{4}).*\Z', r'^.*(\d+)_(\d+)_(\d+).*\Z', r'^.*(\d{4})-*(\d{2})-*(\d{2}).*\Z', r'^.*(\d)\.(\d{2})\.(\d+).*\Z', r'^.*(\d{2})_(\d{2})\Z']
#     result_list = [fr'html version of {output_name} \2-\3-\1.html', fr'html version of {output_name} \2-\3-\1.html', fr'html version of {output_name} \1-\2-\3.html', fr'html version of {output_name} \1-\2-\3.html', fr'html version of {output_name} \1-\2-2020.html']
#     last_file_name = ''

#     file_exist_n = 0
#     for files in os.listdir(input_path):
#         looking = 1
#         file_ct += 1
#         for searches in search_list:
#             counter = 0
#             while looking == 1:
#                 if re.search(searches,files):
#                     new_file_name = re.sub(searches, result_list[counter],files).replace('-20.html','-2020.html')
#                     looking = 0
#                     print(files, 'found it at', counter)
#                 counter += 1
#                 if counter  > 20:
#                     break
#         if last_file_name == new_file_name:
#             new_file_name = new_file_name.replace('.html', '(PM).html')
#         in_file_path = f'{input_path}/{files}'
#         try:
#             html = pdftotree.parse(in_file_path)
#             output_file_path = f'{output_path}\\{new_file_name}.html'
#             print(output_file_path)
#             if os.path.exists(output_file_path):
#                 file_exist_n +=1
#                 continue
#             else:
#                 print('I\'LL SEE YOU IN HELL!!!!')
#                 with open(output_file_path,'w') as f:
pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 18-0941-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 42% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-18-1639.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 18-1639-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 42% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-19-0937.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-0937-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 43% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-19-1644.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-1644-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 44% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-20-0938.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 20-0938-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 44% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-20-1640.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 20-1640-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 45% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-21-0949.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-0949-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 46% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-21-1637.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-1637-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 46% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-22-0959.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-0959-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 47% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-22-1637.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-1637-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 48% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-23-0942.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-0942-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 48% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-23-1638.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-1638-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 49% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-24-0950.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-0950-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 50% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-24-1640.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-1640-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 50% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-25-0956.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 25-0956-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 51% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-26-0939.pdf found it at 0
# 52% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-27-0949.pdf found it at 0
# 52% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-28-1004.pdf found it at 0

# %% [markdown]
# ## Importing the html files

# %%
import pandas as pd
import time
from bs4 import BeautifulSoup as soup
import os
from pathlib import Path
import datetime

# %%
today = datetime.date.today()
html_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html').resolve()
txt_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\TXT2').resolve()

# %% [markdown]
# ## Converting html to text and storing data

# %% [markdown]
# **NEED** To fix the promblem where 3-21 is being written with 3-19 & 3-20 included

# %%
import sys

header1 = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME']
header1a = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE',  'TOTAL_TESTED','PERCENT_POSITIVE', 'FILE_NAME']
header2 = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE', 'INCONCLUSIVE',  'TOTAL_TESTED', 'PERCENT_POSITIVE','FILE_NAME']
header3 = ['COUNTY', 'AWAITING_TESTING', 'INCONCLUSIVE', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED','FILE_NAME']
files_w2 =[]
final_df = pd.DataFrame(columns=header1)
file_counter = 0
file_len_error = []
for files in os.listdir(html_path):
    file_path = f'{html_path}/{files}'
    file =open(file_path,'r')
    df = pd.DataFrame()
    file_n = len(os.listdir(html_path))
    page_soup = soup(file, 'lxml')
    table_soup = page_soup.findAll("table")
    row_counter = 0
    head_use = 999
    for tables in range(0, len(table_soup)):
        table_html = table_soup[tables]
#         print(files)
        for row in table_html.findAll('tr'):
            data_written = 0
            row_length = len(row)
            counter = 1
            data_list = []
            for col in row.findAll('td'):
                
                if row_counter == 0:
                    data_list.append(col.text.replace(' ', '_').upper())
                
                else:
                    data_list.append(col.text.replace(',','').replace('%',''))
                
                if len(data_list) == row_length:     
                    data_list.append(files.replace('.html','').strip('\n'))     
                    if len(data_list) == 7:
                        if row_counter == 0 and file_counter < 4:
                            if files.find("03-20-2020") >= 0:
                                df = pd.DataFrame(columns=header1a)
                            else:
                                df = pd.DataFrame(columns=header1)
                            head_use = 1
                        
                        elif data_written == 0 and row_counter > 0 and data_list[0] != 'County' and len(data_list[0]) != 0 and data_list[0].find('or by mai') < 0:
                            if files.find("03-20-2020") >= 0:
                                data = pd.DataFrame([data_list], columns = header1a)
                            else:
                                data = pd.DataFrame([data_list], columns = header1)
                            df = pd.concat([df,data])
                            data_written = 1

                    elif len(data_list) > 7:
                        if row_counter == 0 and file_counter < 13 and file_counter > 3:
                            df = pd.DataFrame(columns=header2)
                            files_w2.append(files)
                            head_use = 2             
                        elif row_counter == 0:
                            df = pd.DataFrame(columns=header3)
                            head_use = 3
                            
                
                            
                        if data_written == 0 and row_counter > 0 and data_list[0] != 'County' and len(data_list[0]) != 0 and data_list[0].find('or by mai') < 0:
                            if files.replace('.html','').strip('\n').find('html version of FL COVID Rep 03-24-2020') >= 0 and len(data_list) == 9:
                                
                                data_list.pop(4)
                                
                                if head_use == 2:
                                    data = pd.DataFrame([data_list], columns = header2)
                                    df = pd.concat([df,data])
                                    data_written = 1
                                else:
                                    data = pd.DataFrame([data_list], columns = header3)
                                    df = pd.concat([df,data])
                                    data_written = 1

                            else:
    
                                if len(data_list)== 9 and file_counter > 10 and file_counter <36:
                                    data_list.pop(3) # This is needed because the hmtl adds a column before inconclusive for files 12-35
                                if data_written == 0 and head_use == 2:
                                    data = pd.DataFrame([data_list], columns = header2)
                                    df = pd.concat([df,data])
                                    data_written = 1
                                elif data_written == 0 :
    #                                     print(file_counter, data_list)
                                    data = pd.DataFrame([data_list], columns = header3)
                                    df = pd.concat([df,data])
                                    data_written = 1
                                else:
                                    print('No data written Data lines =', data_list)
                    
        
            row_counter += 1
#     outfile = f'{txt_path}/{files.replace("html.html", "txt").replace("html version", "txt version")}'
    outfile1 = f'{txt_path}/{files.replace("html.html", "csv").replace("html version", "txt version")}'
    file_counter +=1
#     df.to_csv(outfile,sep='\t', index = False)
    
    try:
        if df['COUNTY'].count() > 69 or df['COUNTY'].count() < 57 :
            n = df['COUNTY'].count()
            file_len_error.append(file)
            print('\n'*5)
            print('ERORR '*10)
            print('df OBS Count Flag!!!', files)
            print(f'There are {n} observations in this file')
            print('ERORR '*10)
            print('\n'*5)
        else:
            final_df = final_df.append(df, ignore_index=True)
            df.to_csv(outfile1,sep=',', index = False)
    except KeyError:
        print('\n'*5)
        print('ERORR '*10)
        print('file', files, 'has no data.')
        print('ERORR '*10)
        print('\n'*5)
        file_len_error.append(file)
    print(f'{round((file_counter/file_n)*100,3)}% Complete')
# Out:
# 0.649% Complete
# 1.299% Complete
#
#
#
#
#
#
# ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR
# file html version of FL COVID Rep 03-19-2020(PM).html.html has no data.
# ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR
#
#
#
#
#
#
# 1.948% Complete
# 2.597% Complete
# 3.247% Complete
# 3.896% Complete
#
#
#
#
#
#
# ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR
# df OBS Count Flag!!! html version of FL COVID Rep 03-21-2020.html.html
# There are 18 observations in this file
# ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR ERORR
#
#
#
#
#
#
# 4.545% Complete
# 5.195% Complete
# 5.844% Complete
# 6.494% Complete
# 7.143% Complete
# 7.792% Complete
# 8.442% Complete
# 9.091% Complete
# 9.74% Complete
# 10.39% Complete
# 11.039% Complete
# 11.688% Complete
# 12.338% Complete
# 12.987% Complete
# 13.636% Complete
# 14.286% Complete
# 14.935% Complete
# 15.584% Complete
# 16.234% Complete
# 16.883% Complete
# 17.532% Complete
# 18.182% Complete
# 18.831% Complete
# 19.481% Complete
# 20.13% Complete
# 20.779% Complete
# 21.429% Complete
# 22.078% Complete
# 22.727% Complete
# 23.377% Complete
# 24.026% Complete
# 24.675% Complete
# 25.325% Complete
# 25.974% Complete
# 26.623% Complete
# 27.273% Complete
# 27.922% Complete
# 28.571% Complete
# 29.221% Complete
# 29.87% Complete
# 30.519% Complete
# 31.169% Complete
# 31.818% Complete
# 32.468% Complete
# 33.117% Complete
# 33.766% Complete
# 34.416% Complete
# 35.065% Complete
# 35.714% Complete
# 36.364% Complete
# 37.013% Complete
# 37.662% Complete
# 38.312% Complete
# 38.961% Complete
# 39.61% Complete
# 40.26% Complete
# 40.909% Complete
# 41.558% Complete
# 42.208% Complete
# 42.857% Complete
# 43.506% Complete
# 44.156% Complete
# 44.805% Complete
# 45.455% Complete
# 46.104% Complete
# 46.753% Complete
# 47.403% Complete
# 48.052% Complete
# 48.701% Complete
# 49.351% Complete
# 50.0% Complete
# 50.649% Complete
# 51.299% Complete
# 51.948% Complete
# 52.597% Complete
# 53.247% Complete
# 53.896% Complete
# 54.545% Complete
# 55.195% Complete
# 55.844% Complete
# 56.494% Complete
# 57.143% Complete
# 57.792% Complete
# 58.442% Complete
# 59.091% Complete
# 59.74% Complete
# 60.39% Complete
# 61.039% Complete
# 61.688% Complete
# 62.338% Complete
# 62.987% Complete
# 63.636% Complete
# 64.286% Complete
# 64.935% Complete
# 65.584% Complete
# 66.234% Complete
# 66.883% Complete
# 67.532% Complete
# 68.182% Complete
# 68.831% Complete
# 69.481% Complete
# 70.13% Complete
# 70.779% Complete
# 71.429% Complete
# 72.078% Complete
# 72.727% Complete
# 73.377% Complete
# 74.026% Complete
# 74.675% Complete
# 75.325% Complete
# 75.974% Complete
# 76.623% Complete
# 77.273% Complete
# 77.922% Complete
# 78.571% Complete
# 79.221% Complete
# 79.87% Complete
# 80.519% Complete
# 81.169% Complete
# 81.818% Complete
# 82.468% Complete
# 83.117% Complete
# 83.766% Complete
# 84.416% Complete
# 85.065% Complete
# 85.714% Complete
# 86.364% Complete
# 87.013% Complete
# 87.662% Complete
# 88.312% Complete
# 88.961% Complete
# 89.61% Complete
# 90.26% Complete
# 90.909% Complete
# 91.558% Complete
# 92.208% Complete
# 92.857% Complete
# 93.506% Complete
# 94.156% Complete
# 94.805% Complete
# 95.455% Complete
# 96.104% Complete
# 96.753% Complete
# 97.403% Complete
# 98.052% Complete
# 98.701% Complete
# 99.351% Complete
# 100.0% Complete

# %%
for files in files_w2:
    print(files)
# Out:
# html version of FL COVID Rep 03-21-2020(PM).html.html
# html version of FL COVID Rep 03-22-2020(PM).html.html
# html version of FL COVID Rep 03-22-2020.html.html
# html version of FL COVID Rep 03-23-2020(PM).html.html
# html version of FL COVID Rep 03-23-2020.html.html
# html version of FL COVID Rep 03-24-2020(PM).html.html
# html version of FL COVID Rep 03-24-2020.html.html

# %% [markdown]
# ## QA Check on Data Import Process

# %%
print(f'There are {len(file_len_error)} html files with too few or too many observations')
print('File Names:')
print('-'*92)
for files in file_len_error:
    print(files.name)
print('NOTE: Files listed here will not appear in the final dataset')
# Out:
# There are 2 html files with too few or too many observations
# File Names:
# --------------------------------------------------------------------------------------------
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html/html version of FL COVID Rep 03-19-2020(PM).html.html
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html/html version of FL COVID Rep 03-21-2020.html.html
# NOTE: Files listed here will not appear in the final dataset

# %% [markdown]
# Exporting the COVID Dataset

# %% [markdown]
# Setting Paths for output

# %%
qa_path = '../data/QA Checks/'
graphics_path = '../Graphics/'
data_path = '../data/'

# %%
final_df.to_csv(f'{data_path}Final COVID Only Dataset (Pre-Manipulation) 7-13-20.csv',  sep=',', index=False)

# %% [markdown]
# Importing the COVID Dataset

# %%
import pandas as pd
mod_df = final_df.loc[~final_df['COUNTY'].str.contains('Total')].copy()

# %%
mod_df = pd.read_csv(f'{data_path}Final COVID Only Dataset (Pre-Manipulation) 7-13-20.csv',  sep=',')
mod_df = mod_df.loc[~mod_df['COUNTY'].str.contains('Total')]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-131-0b3d47e8a69d> in <module>
# ----> 1 mod_df = pd.read_csv(f'{data_path}Final COVID Only Dataset (Pre-Manipulation) 7-12-20.csv',  sep=',')
#       2 mod_df = mod_df.loc[~mod_df['COUNTY'].str.contains('Total')]
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../data/Final COVID Only Dataset (Pre-Manipulation) 7-12-20.csv does not exist: '../data/Final COVID Only Dataset (Pre-Manipulation) 7-12-20.csv'

# %%
mod_df = mod_df.loc[~mod_df['COUNTY'].str.contains('Total')]
mod_df[mod_df['COUNTY']=='Total']
# Out:
# Empty DataFrame
# Columns: [COUNTY, AWAITING_TESTING, NEGATIVE, POSITIVE, PERCENT_POSITIVE, TOTAL_TESTED, FILE_NAME, INCONCLUSIVE]
# Index: []

# %% [markdown]
# Number of times COUNTY contained 'Sumter'

# %%
pd.value_counts(mod_df['COUNTY'].str.contains('Sumter')).to_frame()
# Out:
#        COUNTY
# False   10141
# True      152

# %% [markdown]
# # Data Manipulation

# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %%
mod_df['NEGATIVE'] = pd.to_numeric(mod_df['NEGATIVE'])
mod_df['POSITIVE'] = pd.to_numeric(mod_df['POSITIVE'])
mod_df['PERCENT_POSITIVE'] = pd.to_numeric(mod_df['PERCENT_POSITIVE'])
mod_df['TOTAL_TESTED'] = pd.to_numeric(mod_df['TOTAL_TESTED'])
mod_df['INCONCLUSIVE'] = pd.to_numeric(mod_df['INCONCLUSIVE'])
mod_df['AWAITING_TESTING'] = pd.to_numeric(mod_df['AWAITING_TESTING'])

# %%
mod_df = mod_df.fillna(0)
mod_df['FILE_NAME'] =  mod_df['FILE_NAME'].str.strip('\n')
mod_df['DATE'] = pd.to_datetime(mod_df['FILE_NAME'].str[29:39], errors='ignore')
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10293 entries, 0 to 10443
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   COUNTY            10293 non-null  object
#  1   AWAITING_TESTING  10293 non-null  float64
#  2   NEGATIVE          10293 non-null  int64
#  3   POSITIVE          10293 non-null  float64
#  4   PERCENT_POSITIVE  10293 non-null  float64
#  5   TOTAL_TESTED      10293 non-null  int64
#  6   FILE_NAME         10293 non-null  object
#  7   INCONCLUSIVE      10293 non-null  float64
#  8   DATE              10293 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(2)
# memory usage: 804.1+ KB

# %%
mod_df['DAY_OF_WEEK'] = mod_df['DATE'].dt.weekday

# %%
print(pd.value_counts(mod_df['DATE']).to_frame(name='Frequency of Each Date in the Data set').head(10))
print(pd.value_counts(mod_df['DATE']).to_frame(name='Frequency of Each Date in the Data set').tail(10))
print('NOTE: Each Date should only appear max = 136 times min = 57 times')
# Out:
#             Frequency of Each Date in the Data set
# 2020-03-27                                     136
# 2020-04-10                                     136
# 2020-03-24                                     136
# 2020-04-07                                     136
# 2020-04-20                                     136
# 2020-04-24                                     136
# 2020-04-02                                     136
# 2020-03-29                                     136
# 2020-04-15                                     136
# 2020-03-28                                     136
#             Frequency of Each Date in the Data set
# 2020-05-11                                      68
# 2020-06-24                                      68
# 2020-04-28                                      68
# 2020-06-11                                      68
# 2020-05-29                                      68
# 2020-03-21                                      66
# 2020-03-20                                      66
# 2020-03-19                                      58
# 2020-03-18                                      58
# 2020-03-16                                      57
# NOTE: Each Date should only appear max = 136 times min = 57 times

# %% [markdown]
# ### Frequency of county n

# %%
print(pd.value_counts(mod_df['COUNTY']).to_frame(name='Frequency of County Name Head').head(10))
print(pd.value_counts(mod_df['COUNTY']).to_frame(name='Frequency of County Name Tail').tail(10))
# Out:
#               Frequency of County Name Head
# Union                                   152
# Volusia                                 152
# Okeechobee                              152
# Hillsborough                            152
# Desoto                                  152
# St. Johns                               152
# Alachua                                 152
# Columbia                                152
# Sarasota                                152
# Monroe                                  152
#            Frequency of County Name Tail
# Madison                              149
# Wakulla                              149
# Taylor                               149
# Hamilton                             149
# Jefferson                            149
# Highlands                            149
# Holmes                               149
# Calhoun                              149
# Liberty                              143
# Glades                               143

# %%
county_n = mod_df['COUNTY'].value_counts()
print(county_n.value_counts().to_frame(name='Distribution of County Frequency'))
county_n.to_csv('Number of Obs Per County 7-11-20.txt', sep='\t')
# Out:
#      Distribution of County Frequency
# 152                                57
# 149                                 8
# 143                                 2
# 151                                 1

# %% [markdown]
# comparing the number of different lengths for filename there are

# %% [markdown]
# ## Data Quality Check

# %%
mod_df['len_file_name'] = pd.value_counts(mod_df['FILE_NAME'].apply(len))
pd.value_counts(mod_df['FILE_NAME'].apply(len)).to_frame(name='Freq of File Lengths')
# Out:
#     Freq of File Lengths
# 39                  7851
# 43                  2306
# 38                   136

# %%
pd.value_counts(mod_df['FILE_NAME'].str.contains('PM')).to_frame()
# Out:
#        FILE_NAME
# False       7987
# True        2306

# %%
mod_df['FILE_NAME_LEN'] = mod_df.FILE_NAME.apply(len)

# %%
mod_df.sort_values(by=['FILE_NAME_LEN'], inplace=True)

# %%
mod_df[["FILE_NAME", 'FILE_NAME_LEN']].head(10)
# Out:
#                                    FILE_NAME  FILE_NAME_LEN
# 8784  html version of FL COVID Rep 06-2-2020             38
# 7996  html version of FL COVID Rep 06-1-2020             38
# 7997  html version of FL COVID Rep 06-1-2020             38
# 7998  html version of FL COVID Rep 06-1-2020             38
# 7999  html version of FL COVID Rep 06-1-2020             38
# 8000  html version of FL COVID Rep 06-1-2020             38
# 8001  html version of FL COVID Rep 06-1-2020             38
# 8002  html version of FL COVID Rep 06-1-2020             38
# 8003  html version of FL COVID Rep 06-1-2020             38
# 8004  html version of FL COVID Rep 06-1-2020             38

# %%
mod_df[["FILE_NAME", 'FILE_NAME_LEN']].tail(10)
# Out:
#                                         FILE_NAME  FILE_NAME_LEN
# 2092  html version of FL COVID Rep 04-04-2020(PM)             43
# 2091  html version of FL COVID Rep 04-04-2020(PM)             43
# 2090  html version of FL COVID Rep 04-04-2020(PM)             43
# 2089  html version of FL COVID Rep 04-04-2020(PM)             43
# 2088  html version of FL COVID Rep 04-04-2020(PM)             43
# 2087  html version of FL COVID Rep 04-04-2020(PM)             43
# 2086  html version of FL COVID Rep 04-04-2020(PM)             43
# 2085  html version of FL COVID Rep 04-04-2020(PM)             43
# 4016  html version of FL COVID Rep 04-18-2020(PM)             43
# 2610  html version of FL COVID Rep 04-08-2020(PM)             43

# %%
mod_df[mod_df['FILE_NAME_LEN']== 39].filter(['FILE_NAME_LEN','FILE_NAME']).head(10)
# Out:
#       FILE_NAME_LEN                                FILE_NAME
# 6881             39  html version of FL COVID Rep 05-23-2020
# 6878             39  html version of FL COVID Rep 05-23-2020
# 6904             39  html version of FL COVID Rep 05-23-2020
# 6903             39  html version of FL COVID Rep 05-23-2020
# 6902             39  html version of FL COVID Rep 05-23-2020
# 6901             39  html version of FL COVID Rep 05-23-2020
# 6900             39  html version of FL COVID Rep 05-23-2020
# 6899             39  html version of FL COVID Rep 05-23-2020
# 6898             39  html version of FL COVID Rep 05-23-2020
# 6897             39  html version of FL COVID Rep 05-23-2020

# %%
mod_df[mod_df['FILE_NAME_LEN']== 39].filter(['FILE_NAME_LEN','FILE_NAME']).tail(10)
# Out:
#       FILE_NAME_LEN                                FILE_NAME
# 5188             39  html version of FL COVID Rep 04-28-2020
# 5185             39  html version of FL COVID Rep 04-28-2020
# 5186             39  html version of FL COVID Rep 04-28-2020
# 5189             39  html version of FL COVID Rep 04-28-2020
# 5190             39  html version of FL COVID Rep 04-28-2020
# 5191             39  html version of FL COVID Rep 04-28-2020
# 5192             39  html version of FL COVID Rep 04-28-2020
# 5193             39  html version of FL COVID Rep 04-28-2020
# 5194             39  html version of FL COVID Rep 04-28-2020
# 5195             39  html version of FL COVID Rep 04-28-2020

# %% [markdown]
# ## Creating the New Case And Negative Variables

# %%
mod_df.sort_values(by=["COUNTY", "DATE"], inplace=True)

# %%
mod_df['LAST_POS_COUNT'] = mod_df['POSITIVE'].shift(1)
mod_df['LAST_COUNTY'] = mod_df['COUNTY'].shift(1)
mod_df['LAST_NEG_COUNT'] = mod_df['NEGATIVE'].shift(1)
mod_df['NEW_NEGATIVES'] = mod_df['NEGATIVE'] - mod_df['LAST_NEG_COUNT']
mod_df['NEW_CASES'] = mod_df['POSITIVE'] - mod_df['LAST_POS_COUNT']
mod_df.loc[mod_df['COUNTY'] != mod_df["LAST_COUNTY"], 'NEW_CASES' ] = ''
mod_df.loc[mod_df['COUNTY'] != mod_df["LAST_COUNTY"], 'NEW_NEGATIVES' ] = ''

mod_df['NEW_CASES'] = pd.to_numeric(mod_df['NEW_CASES'])
mod_df['NEW_NEGATIVES'] = pd.to_numeric(mod_df['NEW_NEGATIVES'])
# mod_df.drop(labels=['LAST_POS_COUNT', 'LAST_COUNTY','LAST_NEG_COUNT'], inplace=True, axis=1)

# %%
dade = mod_df.loc[mod_df['COUNTY']=='Dade']
dade.to_csv(f'{qa_path}Dade data.csv', index=False)
sumter = mod_df.loc[mod_df['COUNTY']=='Broward']
sumter.to_csv(f'{qa_path}Broward data.csv', index=False)
print(dade[['NEW_CASES', 'LAST_POS_COUNT', 'POSITIVE', 'DATE']].head(30))
print(dade[['NEW_CASES', 'LAST_POS_COUNT', 'POSITIVE', 'DATE']].tail(30))
# for cases in dade['NEW_CASES']:
#     print(cases, )
# Out:
#       NEW_CASES  LAST_POS_COUNT  POSITIVE       DATE
# 1           NaN           589.0      25.0 2020-03-16
# 59         51.0            25.0      76.0 2020-03-18
# 118        10.0            76.0      86.0 2020-03-19
# 177        37.0            86.0     123.0 2020-03-20
# 243        46.0           123.0     169.0 2020-03-21
# 378         8.0           169.0     177.0 2020-03-22
# 310        51.0           177.0     228.0 2020-03-22
# 511        39.0           228.0     267.0 2020-03-23
# 444        11.0           267.0     278.0 2020-03-23
# 647        60.0           278.0     338.0 2020-03-24
# 578        29.0           338.0     367.0 2020-03-24
# 785        33.0           367.0     400.0 2020-03-25
#  'USF Storage for the Python Code.lnk',
#  'Written Summaries']

# %%
mod_df['TOTAL_TESTED'].hist(bins=[0,500,501,1000,1001,5000,5001,20000])

# %%
mod_df.columns
# Out:
# Index(['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE',
#        'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME', 'INCONCLUSIVE', 'DATE',
#        'DAY_OF_WEEK', 'len_file_name', 'FILE_NAME_LEN', 'LAST_POS_COUNT',
#        'LAST_COUNTY', 'LAST_NEG_COUNT', 'NEW_NEGATIVES', 'NEW_CASES'],
#       dtype='object')

# %%
mod_df.drop(labels=['len_file_name', 'FILE_NAME_LEN', 'LAST_POS_COUNT', 'LAST_NEG_COUNT', 'LAST_COUNTY',], axis = 1, inplace = True)

# %%
today.day
# Out:
# 13

# %%
mod_df.to_csv(f'{data_path}Final COVID Only Dataset {today.month}-{today.day}-{today.year} (CLEAN).txt', sep='\t', index=False)
mod_df.to_csv(f'{data_path}Final COVID Only Dataset {today.month}-{today.day}-{today.year} (CLEAN).csv', sep=',', index=False)

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-muted')
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_CASES'],'bo', label='New Cases')
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_NEGATIVES'], color='#332244',marker='o', linestyle='' , label= 'Negatives', alpha=0.2)
plt.title('Scatter Plot of number of Total Daily Test (X) and Number of New Cases (Y)')
plt.xlabel('Number of Tests')
plt.ylabel('Number of New Cases')
plt.legend()
plt.show()

# %%
mod_df['NEW_CASES'].hist(bins=[0,199,200,399, 400,1000,1001,5000,5001,10000])

# %%
mod_df[['TOTAL_TESTED','COUNTY']].describe()
# Out:
#         TOTAL_TESTED
# count   10293.000000
# mean    10368.242592
# std     29143.664789
# min         1.000000
# 25%       266.000000
# 50%      1621.000000
# 75%      6677.000000
# max    434159.000000

# %% [markdown]
# ### Verifying that the shift worked correctly

# %%
mod_df[['NEGATIVE']].sum().to_frame()
# Out:
#                  0
# NEGATIVE  98350362

# %%
mod_df[['NEW_CASES']].sum().to_frame()
# Out:
#                   0
# NEW_CASES  282275.0

# %%
mod_df.columns
# Out:
# Index(['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE',
#        'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME', 'INCONCLUSIVE', 'DATE',
#        'DAY_OF_WEEK', 'NEW_NEGATIVES', 'NEW_CASES'],
#       dtype='object')

# %%
mod_df['NEW_CASES'].describe().to_frame()
# Out:
#           NEW_CASES
# count  10225.000000
# mean      27.606357
# std      129.898135
# min      -49.000000
# 25%        0.000000
# 50%        2.000000
# 75%        9.000000
# max     3576.000000

# %%
mod_df.filter(items=['NEW_CASES','COUNTY'], axis=1)
# Out:
#        NEW_CASES      COUNTY
# 10           NaN     Alachua
# 70           3.0     Alachua
# 126          3.0     Alachua
# 184          5.0     Alachua
# 250         10.0     Alachua
# ...          ...         ...
# 10155        4.0  Washington
# 10224        7.0  Washington
# 10295        4.0  Washington
# 10363       12.0  Washington
# 10431       28.0  Washington
#
# [10293 rows x 2 columns]

# %% [markdown]
# ## Observations where the number of new cases is less than 0

# %%
# Getting Counties with over 1000 cases reported in one day
high_case = mod_df[mod_df['NEW_CASES']> 1000]
high_case.sort_values(by='NEW_CASES', inplace=True, ascending =False)
print(high_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(100))
top_100 = pd.DataFrame(high_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(100))
# Out:
#              COUNTY  NEW_CASES       DATE
# 10307          Dade     3576.0 2020-07-12
# 10376          Dade     3269.0 2020-07-13
# 10031          Dade     2916.0 2020-07-08
# 10238          Dade     2527.0 2020-07-11
# 9755           Dade     2418.0 2020-07-04
# 10169          Dade     2380.0 2020-07-10
# 9617           Dade     2304.0 2020-07-02
# 9824           Dade     2282.0 2020-07-05
# 9341           Dade     2152.0 2020-06-28
# 9962           Dade     2066.0 2020-07-07
# 9686           Dade     2046.0 2020-07-03
# 10100          Dade     1987.0 2020-07-09
# 9893           Dade     1981.0 2020-07-06
# 10308       Broward     1772.0 2020-07-12
# 9825        Broward     1664.0 2020-07-05
# 10170       Broward     1603.0 2020-07-10
# 9479           Dade     1598.0 2020-06-30
# 10239       Broward     1548.0 2020-07-11
# 9203           Dade     1532.0 2020-06-26
# 9410           Dade     1508.0 2020-06-29
# 10377       Broward     1459.0 2020-07-13
# 10311        Orange     1371.0 2020-07-12
# 9272           Dade     1366.0 2020-06-27
# 9756        Broward     1346.0 2020-07-04
# 10101       Broward     1321.0 2020-07-09
# 10314           Lee     1275.0 2020-07-12
# 10032       Broward     1186.0 2020-07-08
# 9759         Orange     1184.0 2020-07-04
# 10309    Palm Beach     1171.0 2020-07-12
# 9548           Dade     1141.0 2020-07-01
# 9687        Broward     1113.0 2020-07-03
# 9275   Hillsborough     1112.0 2020-06-27
# 9207         Orange     1062.0 2020-06-26
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# County
pd.value_counts(high_case['COUNTY'].head(100)).to_frame(name="County")
# Out:
#               County
# Dade              18
# Broward            9
# Orange             3
# Hillsborough       1
# Palm Beach         1
# Lee                1

# %%
neg_case = mod_df[mod_df['NEW_CASES']< 0].copy()
neg_case.sort_values(by='NEW_CASES', inplace=True)
print(neg_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(20))
print(neg_case[['COUNTY', 'NEW_CASES' ,'DATE']].tail(20))
neg_case.to_csv(f'{qa_path}Observation With Negative.csv' ,sep=',')
# Out:
#           COUNTY  NEW_CASES       DATE
# 9381   Highlands      -49.0 2020-06-28
# 3354     Alachua      -32.0 2020-04-13
# 2028     Broward      -27.0 2020-04-04
# 6205     Jackson      -25.0 2020-05-13
# 8963    Suwannee      -20.0 2020-06-22
# 2217     Unknown      -20.0 2020-04-05
# 9122     Calhoun      -18.0 2020-06-24
# 1407     Broward      -15.0 2020-03-30
# 10433    Calhoun      -12.0 2020-07-13
# 6281     Unknown      -12.0 2020-05-14
# 9602      Glades      -11.0 2020-07-01
# 9021        Clay       -8.0 2020-06-23
# 5690       Duval       -7.0 2020-05-06
# 9331     Calhoun       -7.0 2020-06-27
# 4861       Duval       -6.0 2020-04-24
# 4051        Leon       -5.0 2020-04-18
# 9464     Unknown       -5.0 2020-06-29
# 8426     Unknown       -5.0 2020-06-15
# 9815     Calhoun       -4.0 2020-07-04
# 4647     Unknown       -4.0 2020-04-22
#             COUNTY  NEW_CASES       DATE
# 6844     Jefferson       -1.0 2020-05-22
# 6275       Jackson       -1.0 2020-05-14
# 2330  Indian River       -1.0 2020-04-06
# 9808        Holmes       -1.0 2020-07-04
# 5191        Glades       -1.0 2020-04-28
# 6436        Glades       -1.0 2020-05-16
# 7855      Hamilton       -1.0 2020-06-08
# 6884        Hendry       -1.0 2020-05-23
# 401       Hernando       -1.0 2020-03-22
# 4406      Hernando       -1.0 2020-04-21
# 7887     Gilchrist       -1.0 2020-06-08
# 4544      Hernando       -1.0 2020-04-22
# 6621      Hernando       -1.0 2020-05-19
# 6900      Hernando       -1.0 2020-05-23
# 5516     Highlands       -1.0 2020-05-03
# 5723     Highlands       -1.0 2020-05-06
# 2637        Holmes       -1.0 2020-04-08
# 6435        Holmes       -1.0 2020-05-16
# 5028      Hernando       -1.0 2020-04-26
# 9603    Washington       -1.0 2020-07-01

# %%
pd.value_counts(neg_case.COUNTY)
# Out:
# Unknown         15
# Calhoun         10
# Alachua          7
# Hernando         7
# Washington       7
#                 ..
# Palm Beach       1
# Manatee          1
# Desoto           1
# Hillsborough     1
# Orange           1
# Name: COUNTY, Length: 68, dtype: int64

# %%
neg_c_freq = pd.DataFrame(neg_case.groupby('DATE')['COUNTY'].count())
neg_c_freq['COUNTY']
neg_c_freq['DATE'] = neg_c_freq.index
sns.barplot(x='DATE', y ='COUNTY',data =neg_c_freq )
plt.title('Number of Daily Negative Case By Date')
plt.ylabel('Frequency of Negative Values')
# Out:
# Text(0, 0.5, 'Frequency of Negative Values')

# %%
mod_df
# Out:
#            COUNTY  AWAITING_TESTING  NEGATIVE  POSITIVE  PERCENT_POSITIVE  \
# 10        Alachua              38.0        34       4.0               5.0
# 70        Alachua              46.0        63       7.0               6.0
# 126       Alachua              34.0        96      10.0               7.0
# 184       Alachua              50.0       273      15.0               5.0
# 250       Alachua              27.0       393      25.0               6.0
# ...           ...               ...       ...       ...               ...
# 10155  Washington               3.0      1915     140.0               7.0
# 10224  Washington               3.0      1960     147.0               7.0
# 10295  Washington               3.0      1983     151.0               7.0
# 10363  Washington               3.0      2004     163.0               8.0
# 10431  Washington               3.0      2113     191.0               8.0
#
#        TOTAL_TESTED                                    FILE_NAME  \
# 10             76.0      html version of FL COVID Rep 03-16-2020
# 70            116.0      html version of FL COVID Rep 03-18-2020
# 126           140.0      html version of FL COVID Rep 03-19-2020
# 184           338.0      html version of FL COVID Rep 03-20-2020
# 250           445.0  html version of FL COVID Rep 03-21-2020(PM)
# ...             ...                                          ...
# 10155        2059.0      html version of FL COVID Rep 07-09-2020
# 10224        2111.0      html version of FL COVID Rep 07-10-2020
# 10295        2138.0      html version of FL COVID Rep 07-11-2020
# 10363        2171.0      html version of FL COVID Rep 07-12-2020
# 10431        2308.0      html version of FL COVID Rep 07-13-2020
#
#        INCONCLUSIVE       DATE  DAY_OF_WEEK  NEW_NEGATIVES  NEW_CASES
# 10              0.0 2020-03-16            0            NaN        NaN
# 70              0.0 2020-03-18            2           29.0        3.0
# 126             0.0 2020-03-19            3           33.0        3.0
# 184             0.0 2020-03-20            4          177.0        5.0
# 250             0.0 2020-03-21            5          120.0       10.0
# ...             ...        ...          ...            ...        ...
# 10155           1.0 2020-07-09            3           15.0        4.0
# 10224           1.0 2020-07-10            4           45.0        7.0
# 10295           1.0 2020-07-11            5           23.0        4.0
# 10363           1.0 2020-07-12            6           21.0       12.0
# 10431           1.0 2020-07-13            0          109.0       28.0
#
# [10293 rows x 12 columns]

# %%
mod_df[mod_df['NEW_CASES']< 0].describe()
# Out:
#        AWAITING_TESTING      NEGATIVE     POSITIVE  PERCENT_POSITIVE  \
# count        172.000000    172.000000   172.000000        172.000000
# mean          14.488372   2617.209302   152.767442          6.337209
# std           32.271779   3874.724997   221.170156          3.849844
# min            0.000000      5.000000     0.000000          0.000000
# 25%            0.000000    537.750000    28.750000          4.000000
# 50%            1.000000   1242.000000    88.000000          6.000000
# 75%           10.250000   2654.750000   193.500000          8.000000
# max          223.000000  28293.000000  1765.000000         31.000000
#
#        TOTAL_TESTED  INCONCLUSIVE  DAY_OF_WEEK  NEW_NEGATIVES   NEW_CASES
# count    172.000000    172.000000   172.000000     172.000000  172.000000
# mean    2787.127907      2.662791     2.825581      55.936047   -2.843023
# std     4070.111622      4.579666     2.112020     123.145763    5.807216
# min        7.000000      0.000000     0.000000      -7.000000  -49.000000
# 25%      581.500000      0.000000     1.000000       4.000000   -2.000000
# 50%     1368.500000      1.000000     2.000000      14.500000   -1.000000
# 75%     2828.250000      2.250000     5.000000      42.250000   -1.000000
# max    29460.000000     22.000000     6.000000    1025.000000   -1.000000

# %%
# mod_df.drop('FILE_NAME1', axis = 1, inplace=True)
mod_df.columns
# Out:
# Index(['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE',
#        'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME', 'INCONCLUSIVE', 'DATE',
#        'DAY_OF_WEEK', 'NEW_NEGATIVES', 'NEW_CASES'],
#       dtype='object')

# %% [markdown]
# # Messing around with matplotlib

# %%
# plt.xkcd()
# plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_CASES'],'bo', label='New Cases')
# plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_NEGATIVES'], color='#332244',marker='o', linestyle='' , label= 'Negatives', alpha=0.2)
# plt.title('Scatter Plot of number of Total Daily Test (X) and Number of New Cases (Y)')
# plt.xlabel('Number of Tests')
# plt.ylabel('Number of New Cases')
# plt.legend()
# plt.savefig('plot.png')
# plt.show()

# %%
fig,ax = plt.subplots()
mod_df['TOTAL_TESTED'].value_counts().plot(ax=ax, kind='bar')
plt.plot()
# Out:
# []
