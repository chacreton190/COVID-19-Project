# %% [markdown]
# # Downloading COVID Data From FloridaDisaster.ORG

# %% [markdown]
# ### To Do
# - [ ] Turn all of the processes into functions
# - [X] Fix/find out why reports 3/19 - 3/24 are only 1kb and hold no data (There were 3 different page titles not 2)
# - [X] Clean the changing column names at the text export stage
# - [X] Figure out my headers are messed up
# - [ ] Why are there so many obs for 3/18
# - [ ] **IMPORTANT**: THE LARGE NEGATIVE NUMBERS FOR DADE DO NOT SEEM TO BE CORRECT. FIND OUT WHAT IS GOING ON THERE
# - [ ] **IMPORTANT**: Something happens to the data at 7/6 after this point everything is wrong, whyy???
# - [ ] **IMPORTANT**: Fix this error '5-31-2020('
# - [X] Fix the problem where before doh reported 0 as 0 and not missing, I can't use the data
# - [X] Extract the page range 12-25
# - [X] Find the pages that contain the words "Coronavirus: All persons tested"
# - [X] Extract just those two pages pdf
# - [X] Export individual files to txt for storage

# %%
from selenium import webdriver
import os
import wget
import PyPDF2 as pdf
from PyPDF2 import PdfFileReader, PdfFileWriter
import time
import textract
from pathlib import Path
import re
import pandas as pd
import datetime

# %%
chrome_path = r"chromedriver.exe"

# %% [markdown]
# ## Initializing driver element and finding

# %%
driver = webdriver.Chrome(chrome_path)

# %%
driver.get('https://floridadisaster.org/covid19/covid-19-data-reports/')
title = driver.title
time.sleep(3)
result = driver.find_elements_by_xpath("//a[@href]")

# %% [markdown]
# Initializing the output paths

# %%
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\PDF')
pdf_output_path= output_path.resolve()
pdf_extract_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\Unclean PDF')
pdf_extract_path = pdf_extract_path.resolve()

# %%
pdf_output_path
# Out:
# WindowsPath('C:/Users/chacr/OneDrive/Documents/Coding/Python/USF/COVID-19 Project/Data/PDF')

# %% [markdown]
# ## Downloads the PDF Files from the FDEM Website

# %%
link_counter = 0
len_result = len(result)
for links in result:
    if links.text.find('Data Report') > 0:
        link_url = links.get_attribute('href')
        filename = wget.filename_from_url(link_url)
        if not os.path.exists(f'{pdf_output_path}/{filename}'):
            wget.download(link_url, out = f'{pdf_output_path}')
        link_counter +=1
        print (f'{round((link_counter * 2)/len_result,3)*100}% Complete',end='\r')
# Out:
# 26.3% Complete0002% Complete

# %%
driver.close()

# %% [markdown]
# ### Extracting the min and max page range for the COVID-19 Daily County Data

# %%
#turn into a function
def PdfPageExtract(input_path, output_path, page_num):
    import time
    import os
    import PyPDF2 as pdf
    from PyPDF2 import PdfFileReader, PdfFileWriter
    import textract
    print('Program Started')
    page_counter = 0
    today = datetime.date.today()
    file_num = len(os.listdir(input_path))
    file_exist_n =0
    progress = 0
    for files in os.listdir(input_path):
        output = f'{output_path}/(7-11-20) Unclean Extract from {files}'
        progress += 1
        if os.path.exists(output):
            file_exist_n +=1
            print(f'{round((progress/file_num)* 100,3)}% Complete')
            continue
        else:

            pdf_writer = PdfFileWriter()
            pdf_file = open(f'{input_path}/{files}','rb')
            pdfreader = PdfFileReader(pdf_file)
            num_pages = pdfreader.numPages
            if num_pages < page_num:
                up_limit = num_pages
            else:
                up_limit = page_num
            for pages in range(3, up_limit):
                page =  pdfreader.getPage(pages)  
                if page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All persons tested') > 0 or page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All') > 0:
                    pdf_writer.addPage(page)          
            with open(output, 'wb') as output_pdf:
                pdf_writer.write(output_pdf)
            print(f'{round((progress/file_num)* 100,3)}% Complete')
    
    if file_exist_n == file_num:
        print('All Files Previously Created')
    else:
        print(f'{file_num -file_exist_n} New Files Created')

page_limit = 23

PdfPageExtract(pdf_output_path, pdf_extract_path, page_limit)
# Out:
# Program Started
# 0.662% Complete
# 1.325% Complete
# 1.987% Complete
# 2.649% Complete
# 3.311% Complete
# 3.974% Complete
# 4.636% Complete
# 5.298% Complete
# 5.96% Complete
# 6.623% Complete
# 7.285% Complete
# 7.947% Complete
# 8.609% Complete
# 9.272% Complete
# 9.934% Complete
# 10.596% Complete
# 11.258% Complete
# 11.921% Complete
# 12.583% Complete
# 13.245% Complete
# 13.907% Complete
# 14.57% Complete
# 15.232% Complete
# 15.894% Complete
# 16.556% Complete
# 17.219% Complete
# 17.881% Complete
# 18.543% Complete
# 19.205% Complete
# 19.868% Complete
# 20.53% Complete
# 21.192% Complete
# 21.854% Complete
# 22.517% Complete
# 23.179% Complete
# 23.841% Complete
# 24.503% Complete
# 25.166% Complete
# 25.828% Complete
# 26.49% Complete
# 27.152% Complete
# 27.815% Complete
# 28.477% Complete
# 29.139% Complete
# 29.801% Complete
# 30.464% Complete
# 31.126% Complete
# 31.788% Complete
# 32.45% Complete
# 33.113% Complete
# 33.775% Complete
# 34.437% Complete
# 35.099% Complete
# 35.762% Complete
# 36.424% Complete
# 37.086% Complete
# 37.748% Complete
# 38.411% Complete
# 39.073% Complete
# 39.735% Complete
# 40.397% Complete
# 41.06% Complete
# 41.722% Complete
# 42.384% Complete
# 43.046% Complete
# 43.709% Complete
# 44.371% Complete
# 45.033% Complete
# 45.695% Complete
# 46.358% Complete
# 47.02% Complete
# 47.682% Complete
# 48.344% Complete
# 49.007% Complete
# 49.669% Complete
# 50.331% Complete
# 50.993% Complete
# 51.656% Complete
# 52.318% Complete
# 52.98% Complete
# 53.642% Complete
# 54.305% Complete
# 54.967% Complete
# 55.629% Complete
# 56.291% Complete
# 56.954% Complete
# 57.616% Complete
# 58.278% Complete
# 58.94% Complete
# 59.603% Complete
# 60.265% Complete
# 60.927% Complete
# 61.589% Complete
# 62.252% Complete
# 62.914% Complete
# 63.576% Complete
# 64.238% Complete
# 64.901% Complete
# 65.563% Complete
# 66.225% Complete
# 66.887% Complete
# 67.55% Complete
# 68.212% Complete
# 68.874% Complete
# 69.536% Complete
# 70.199% Complete
# 70.861% Complete
# 71.523% Complete
# 72.185% Complete
# 72.848% Complete
# 73.51% Complete
# 74.172% Complete
# 74.834% Complete
# 75.497% Complete
# 76.159% Complete
# 76.821% Complete
# 77.483% Complete
# 78.146% Complete
# 78.808% Complete
# 79.47% Complete
# 80.132% Complete
# 80.795% Complete
# 81.457% Complete
# 82.119% Complete
# 82.781% Complete
# 83.444% Complete
# 84.106% Complete
# 84.768% Complete
# 85.43% Complete
# 86.093% Complete
# 86.755% Complete
# 87.417% Complete
# 88.079% Complete
# 88.742% Complete
# 89.404% Complete
# 90.066% Complete
# 90.728% Complete
# 91.391% Complete
# 92.053% Complete
# 92.715% Complete
# 93.377% Complete
# 94.04% Complete
# 94.702% Complete
# 95.364% Complete
# 96.026% Complete
# 96.689% Complete
# 97.351% Complete
# 98.013% Complete
# 98.675% Complete
# 99.338% Complete
# 100.0% Complete
# 6 New Files Created

# %% [markdown]
# # Converting the PDFs to html files

# %%
from pathlib import Path

input_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\Unclean PDF')
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html')
ip = input_path.resolve()
op = output_path.resolve()

# %%
print(re.sub(r'(.+\D)(\d)(.*\Z)', '\1'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9493b960a417> in <module>
# ----> 1 print(re.sub(r'(.+\D)(\d)(.*\Z)', '\1'))
#
# NameError: name 're' is not defined

# %%
import os
import pdftotree
import re
import sys
print('Program started')
file_n = len(os.listdir(ip))
file_ct = 0
file_exist_n =0
error_list = []
date1 = r'^.*(\d+)-*(\d{2})-*(\d{4}).*\Z'
date2 = r'^.*(\d+)_(\d+)_(\d+).*\Z'
date3 = r'^.*(\d{4})-*(\d{2})-*(\d{2}).*\Z'
date4 = r'^.*(\d)\.(\d{2})\.(\d+).*\Z'
date5 = r'^.*(\d{2})_(\d{2})\Z'
date_format = r'(^.+)\D(\d-)(.*\Z)'
last_file_name = ''
for files in os.listdir(ip):
    file_ct += 1
    if re.search(date3,files):
        new_file_name = re.sub(date3, r'html version of FL COVID Rep \2-\3-\1.html',files)    
    elif re.search(date1,files):
        new_file_name = re.sub(date1, r'html version of FL COVID Rep \1-\2-\3.html',files)
    elif re.search(date2,files):
        new_file_name = re.sub(date2, r'html version of FL COVID Rep \1-\2-\3.html',files)
    elif re.search(date4,files):
        new_file_name = re.sub(date4, r'html version of FL COVID Rep \1-\2-\3.html',files).replace('-20.html','-2020.html')
    elif re.search(date5,files):
        new_file_name = re.sub(date5, r'html version of FL COVID Rep \1-\2-2020.html',files)
    
    new_file_name = re.sub('20-20-0606', '06-06-2020', new_file_name)  
    new_file_name = re.sub(date_format, r'\1 0\2\3', new_file_name)


    if last_file_name == new_file_name:
        new_file_name = new_file_name.replace('.html', '(PM).html')
    in_file_path = f'{ip}/{files}'       
    try:
      
        output_file_path = f'{op}\\{new_file_name}.html'
        if os.path.exists(output_file_path):
            file_exist_n +=1
            continue
        else:
            html = pdftotree.parse(in_file_path)
            with open(output_file_path,'w') as f:
                f.write(html)
            last_file_name = new_file_name
    except: 
        error_list.append(files)
    print(f'{round((file_ct/file_n)*100)}% Complete') 
if file_exist_n == file_n:
    print('All Files Previously Created')
else:
    print(f'{file_n - file_exist_n} New Files Created')
# Out:
# Program started
# 1% Complete
# 1% Complete
# 2% Complete
# 3% Complete
# 3% Complete
# 4% Complete
# 5% Complete
# 5% Complete
# 6% Complete
# 7% Complete
# 7% Complete
# 8% Complete
# 9% Complete
# 9% Complete
# 10% Complete
# 11% Complete
# 11% Complete
# 12% Complete
# 13% Complete
# 13% Complete
# 14% Complete
# 15% Complete
# 15% Complete
# 16% Complete
# 17% Complete
# 17% Complete
# 18% Complete
# 19% Complete
# 19% Complete
# 20% Complete
# 21% Complete
# 21% Complete
# 22% Complete
# 23% Complete
# 23% Complete
# 24% Complete
# 25% Complete
# 25% Complete
# 26% Complete
# 26% Complete
# 27% Complete
# 28% Complete
# 28% Complete
# 29% Complete
# 30% Complete
# 30% Complete
# 31% Complete
# 32% Complete
# 32% Complete
# 33% Complete
# 34% Complete
# 34% Complete
# 35% Complete
# 36% Complete
# 36% Complete
# 37% Complete
# 38% Complete
# 38% Complete
# 39% Complete
# 40% Complete
# 40% Complete
# 41% Complete
# 42% Complete

# %% [markdown]
# ### Need to fix at some point

# %%
def HtmlMaker(input_path, output_path, output_name):
    import os
    import pdftotree
    import re
    print('Program started')
    file_n = len(os.listdir(input_path))
    file_ct = 0
    error_list = []
    search_list = [r'^.*(\d+)-*(\d{2})-*(\d{4}).*\Z', r'^.*(\d+)_(\d+)_(\d+).*\Z', r'^.*(\d{4})-*(\d{2})-*(\d{2}).*\Z', r'^.*(\d)\.(\d{2})\.(\d+).*\Z', r'^.*(\d{2})_(\d{2})\Z']
    result_list = [fr'html version of {output_name} \2-\3-\1.html', fr'html version of {output_name} \2-\3-\1.html', fr'html version of {output_name} \1-\2-\3.html', fr'html version of {output_name} \1-\2-\3.html', fr'html version of {output_name} \1-\2-2020.html']
    last_file_name = ''

    file_exist_n = 0
    for files in os.listdir(input_path):
        looking = 1
        file_ct += 1
        for searches in search_list:
            counter = 0
            while looking == 1:
                if re.search(searches,files):
                    new_file_name = re.sub(searches, result_list[counter],files).replace('-20.html','-2020.html')
                    looking = 0
                    print(files, 'found it at', counter)
                counter += 1
                if counter  > 20:
                    break
        if last_file_name == new_file_name:
            new_file_name = new_file_name.replace('.html', '(PM).html')
        in_file_path = f'{input_path}/{files}'
        try:
            html = pdftotree.parse(in_file_path)
            output_file_path = f'{output_path}\\{new_file_name}.html'
            print(output_file_path)
            if os.path.exists(output_file_path):
                file_exist_n +=1
                continue
            else:
                print('I\'LL SEE YOU IN HELL!!!!')
                with open(output_file_path,'w') as f:
                    f.write(html)
                last_file_name = new_file_name
        except: 
            error_list.append(files)
        print(f'{round((file_ct/file_n)*100)}% Complete')
    if file_exist_n == file_num:
        print('All Files Previously Created')
    else:
        print(f'{file_n -file_exist_n} New Files Created')
            
            
file_name = 'FL COVID Rep'
HtmlMaker(ip, op, file_name)
# Out:
# Program started
# (7-11-20) Unclean Extract from 06062020state_reports_latest.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 06-2020-6.html.html
# I'LL SEE YOU IN HELL!!!!
# 1% Complete
# (7-11-20) Unclean Extract from 06_13_2020state_reports_latest.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 13-2020-6.html.html
# I'LL SEE YOU IN HELL!!!!
# 1% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-16-1815.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 16-1815-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 2% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-18-0955.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 18-0955-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 3% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-19-0954.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-0954-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 3% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-19-1653.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-1653-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 4% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-20-1740-modified.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 20-1740-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 5% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-21-1008.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-1008-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 5% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-21-1731.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-1731-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 6% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-22-0951.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-0951-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 7% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-22-1828.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-1828-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 7% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-23-0949.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-0949-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 8% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-23-1709.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-1709-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 9% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-24-1012.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-1012-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 9% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-24-1657.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-1657-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 10% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-25-1007.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 25-1007-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 11% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-25-1745.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 25-1745-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 11% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-26-1107.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 26-1107-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 12% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-26-1659.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 26-1659-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 13% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-27-1026.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 27-1026-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 13% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-27-1819.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 27-1819-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 14% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-28-1015.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 28-1015-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 15% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-28-1747.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 28-1747-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 15% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-29-1002.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 29-1002-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 16% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-29-1732.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 29-1732-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 17% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-30-1013.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 30-1013-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 17% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-30-1733.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 30-1733-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 18% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-31-1055.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 31-1055-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 19% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-03-31-1742.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 31-1742-3.html.html
# I'LL SEE YOU IN HELL!!!!
# 19% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-01-1037.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 01-1037-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 20% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-02-1021.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 02-1021-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 21% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-02-1715.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 02-1715-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 21% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-03-0955.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 03-0955-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 22% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-03-1725.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 03-1725-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 23% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-04-0949.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 04-0949-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 23% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-04-1653.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 04-1653-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 24% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-05-0945.pdf found it at 0
# 25% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-05-1648.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 05-1648-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 25% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-06-0943.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 06-0943-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 26% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-06-1657.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 06-1657-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 26% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-07-1022.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 07-1022-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 27% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-07-1643.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 07-1643-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 28% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-08-0954.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 08-0954-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 28% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-08-1702.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 08-1702-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 29% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-09-1004.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 09-1004-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 30% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-09-1654.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 09-1654-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 30% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-10-0956-modified.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 10-0956-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 31% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-10-1712.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 10-1712-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 32% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-11-1002.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 11-1002-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 32% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-11-1725.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 11-1725-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 33% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-12-1001.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 12-1001-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 34% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-12-1637.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 12-1637-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 34% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-13-0936.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 13-0936-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 35% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-13-1650.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 13-1650-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 36% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-14-0943.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 14-0943-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 36% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-14-1723.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 14-1723-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 37% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-15-0938.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 15-0938-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 38% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-15-1700.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 15-1700-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 38% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-16-0942.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 16-0942-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 39% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-16-1638.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 16-1638-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 40% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-17-0943.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 17-0943-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 40% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-17-1639.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 17-1639-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 41% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-18-0941.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 18-0941-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 42% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-18-1639.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 18-1639-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 42% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-19-0937.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-0937-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 43% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-19-1644.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 19-1644-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 44% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-20-0938.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 20-0938-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 44% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-20-1640.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 20-1640-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 45% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-21-0949.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-0949-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 46% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-21-1637.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 21-1637-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 46% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-22-0959.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-0959-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 47% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-22-1637.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 22-1637-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 48% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-23-0942.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-0942-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 48% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-23-1638.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 23-1638-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 49% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-24-0950.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-0950-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 50% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-24-1640.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 24-1640-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 50% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-25-0956.pdf found it at 0
# C:\Users\chacr\OneDrive\Documents\Coding\Python\USF\COVID-19 Project\Data\html\html version of FL COVID Rep 25-0956-4.html.html
# I'LL SEE YOU IN HELL!!!!
# 51% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-26-0939.pdf found it at 0
# 52% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-27-0949.pdf found it at 0
# 52% Complete
# (7-11-20) Unclean Extract from covid-19-data---daily-report-2020-04-28-1004.pdf found it at 0

# %% [markdown]
# ## Importing the html files

# %%
import pandas as pd
import time
from bs4 import BeautifulSoup as soup
import os
from pathlib import Path
import datetime

# %%
today = datetime.date.today()
html_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html').resolve()
txt_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\TXT2').resolve()

# %% [markdown]
# ## Converting html to text and storing data

# %%
import sys

header1 = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME']
header2 = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE', 'INCONCLUSIVE',  'TOTAL_TESTED', 'PERCENT_POSITIVE','FILE_NAME']
header3 = ['COUNTY', 'AWAITING_TESTING', 'INCONCLUSIVE', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED','FILE_NAME']

final_df = pd.DataFrame(columns=header1)

file_counter = 0
for files in os.listdir(html_path):
    file_path = f'{html_path}/{files}'
    file =open(file_path,'r')
    file_n = len(os.listdir(html_path))
    page_soup = soup(file, 'lxml')
    table_soup = page_soup.findAll("table")
    row_counter = 0
    head_use = 999
    for tables in range(0, len(table_soup)):
        table_html = table_soup[tables]
        for row in table_html.findAll('tr'):
            row_length = len(row)
            counter = 1
            data_list = []
            for col in row.findAll('td'):

                if row_counter == 0:
                    data_list.append(col.text.replace(' ', '_').upper())
                
                else:
                    data_list.append(col.text.replace(',','').replace('%',''))
                
                if len(data_list) == row_length:  
                     
                    data_list.append(files.replace('.html','').strip('\n'))
                    
                    if len(data_list) == 7:
                        if row_counter == 0 and file_counter < 4:
                            df = pd.DataFrame(columns=header1)
                            head_use = 1
                        
                        elif row_counter > 0 and data_list[0] != 'County' and len(data_list[0]) != 0 and data_list[0].find('or by mai') < 0:
                            data = pd.DataFrame([data_list], columns = header1)
                            df = pd.concat([df,data])

                    elif len(data_list) > 7:
                        if row_counter == 0 and file_counter < 12 and file_counter > 3:
                            df = pd.DataFrame(columns=header2)
                            head_use = 2             
                        elif row_counter == 0:
                            df = pd.DataFrame(columns=header3)
                            head_use = 3
                            print(file_counter, files)
                            
                        if row_counter > 0 and data_list[0] != 'County' and len(data_list[0]) != 0 and data_list[0].find('or by mai') < 0:
                            if files.replace('.html','').strip('\n').find('html version of FL COVID Rep 03-24-2020') >= 0 and len(data_list) == 9:
                                data_list.pop(4)
                                if head_use == 2:
                                    data = pd.DataFrame([data_list], columns = header2)
                                    df = pd.concat([df,data])
                                else:
                                    data = pd.DataFrame([data_list], columns = header3)
                                    df = pd.concat([df,data])                                    

                            else:
                                if len(data_list)== 9 and file_counter > 11 and file_counter <35:
                                    data_list.pop(3)
                                if head_use == 2:
                                    data = pd.DataFrame([data_list], columns = header2)
                                    df = pd.concat([df,data])
                                else:
                                    data = pd.DataFrame([data_list], columns = header3)
                                    df = pd.concat([df,data])  
            row_counter += 1
#     outfile = f'{txt_path}/{files.replace("html.html", "txt").replace("html version", "txt version")}'
    outfile1 = f'{txt_path}/{files.replace("html.html", "csv").replace("html version", "txt version")}'
    file_counter +=1
#     df.to_csv(outfile,sep='\t', index = False)
    df.to_csv(outfile1,sep=',', index = False)
    print(f'{round((file_counter/file_n)*100,3)}% complete')
    final_df = final_df.append(df, ignore_index=True)
# Out:
# 0.68% complete
# 1.361% complete
# 2.041% complete
# 2.721% complete
# 3.401% complete
# 4.082% complete
# 4.762% complete
# 5.442% complete
# 6.122% complete
# 6.803% complete
# 7.483% complete
# 8.163% complete
# 12 html version of FL COVID Rep 03-25-2020(PM).html.html
# 8.844% complete
# 13 html version of FL COVID Rep 03-25-2020.html.html
# 9.524% complete
# 14 html version of FL COVID Rep 03-26-2020(PM).html.html
# 10.204% complete
# 15 html version of FL COVID Rep 03-26-2020.html.html
# 10.884% complete
# 16 html version of FL COVID Rep 03-27-2020(PM).html.html
# 11.565% complete
# 17 html version of FL COVID Rep 03-27-2020.html.html
# 12.245% complete
# 18 html version of FL COVID Rep 03-28-2020(PM).html.html
# 12.925% complete
# 19 html version of FL COVID Rep 03-28-2020.html.html
# 13.605% complete
# 20 html version of FL COVID Rep 03-29-2020(PM).html.html
# 14.286% complete
# 21 html version of FL COVID Rep 03-29-2020.html.html
# 14.966% complete
# 22 html version of FL COVID Rep 03-30-2020(PM).html.html
# 15.646% complete
# 23 html version of FL COVID Rep 03-30-2020.html.html
# 16.327% complete
# 24 html version of FL COVID Rep 03-31-2020(PM).html.html
# 17.007% complete
# 25 html version of FL COVID Rep 03-31-2020.html.html
# 17.687% complete
# 26 html version of FL COVID Rep 04-01-2020.html.html
# 18.367% complete
# 27 html version of FL COVID Rep 04-02-2020(PM).html.html
# 19.048% complete
# 28 html version of FL COVID Rep 04-02-2020.html.html
# 19.728% complete
# 29 html version of FL COVID Rep 04-03-2020(PM).html.html
# 20.408% complete
# 30 html version of FL COVID Rep 04-03-2020.html.html
# 21.088% complete
# 31 html version of FL COVID Rep 04-04-2020(PM).html.html
# 21.769% complete
# 32 html version of FL COVID Rep 04-04-2020.html.html
# 22.449% complete
# 33 html version of FL COVID Rep 04-05-2020(PM).html.html
# 23.129% complete
# 34 html version of FL COVID Rep 04-05-2020.html.html
# 23.81% complete
# 35 html version of FL COVID Rep 04-06-2020(PM).html.html
# 24.49% complete
# 36 html version of FL COVID Rep 04-06-2020.html.html
# 25.17% complete
# 37 html version of FL COVID Rep 04-07-2020(PM).html.html
# 25.85% complete
# 38 html version of FL COVID Rep 04-07-2020.html.html
# 26.531% complete
# 39 html version of FL COVID Rep 04-08-2020(PM).html.html
# 27.211% complete
# 40 html version of FL COVID Rep 04-08-2020.html.html
# 27.891% complete
# 41 html version of FL COVID Rep 04-09-2020(PM).html.html
# 28.571% complete
# 42 html version of FL COVID Rep 04-09-2020.html.html
# 29.252% complete
# 43 html version of FL COVID Rep 04-10-2020(PM).html.html
# 29.932% complete
# 44 html version of FL COVID Rep 04-10-2020.html.html
# 30.612% complete
# 45 html version of FL COVID Rep 04-11-2020(PM).html.html
# 31.293% complete
# 46 html version of FL COVID Rep 04-11-2020.html.html
# 31.973% complete
# 47 html version of FL COVID Rep 04-12-2020(PM).html.html
# 32.653% complete
# 48 html version of FL COVID Rep 04-12-2020.html.html
# 33.333% complete
# 49 html version of FL COVID Rep 04-13-2020(PM).html.html
# 34.014% complete
# 50 html version of FL COVID Rep 04-13-2020.html.html
# 34.694% complete
# 51 html version of FL COVID Rep 04-14-2020(PM).html.html
# 35.374% complete
# 52 html version of FL COVID Rep 04-14-2020.html.html
# 36.054% complete
# 53 html version of FL COVID Rep 04-15-2020(PM).html.html
# 36.735% complete
# 54 html version of FL COVID Rep 04-15-2020.html.html
# 37.415% complete
# 55 html version of FL COVID Rep 04-16-2020(PM).html.html
# 38.095% complete
# 56 html version of FL COVID Rep 04-16-2020.html.html
# 38.776% complete
# 57 html version of FL COVID Rep 04-17-2020(PM).html.html
# 39.456% complete
# 58 html version of FL COVID Rep 04-17-2020.html.html
# 40.136% complete
# 59 html version of FL COVID Rep 04-18-2020(PM).html.html
# 40.816% complete
# 60 html version of FL COVID Rep 04-18-2020.html.html
# 41.497% complete
# 61 html version of FL COVID Rep 04-19-2020(PM).html.html
# 42.177% complete
# 62 html version of FL COVID Rep 04-19-2020.html.html
# 42.857% complete
# 63 html version of FL COVID Rep 04-20-2020(PM).html.html
# 43.537% complete
# 64 html version of FL COVID Rep 04-20-2020.html.html
# 44.218% complete
# 65 html version of FL COVID Rep 04-21-2020(PM).html.html
# 44.898% complete
# 66 html version of FL COVID Rep 04-21-2020.html.html
# 45.578% complete
# 67 html version of FL COVID Rep 04-22-2020(PM).html.html
# 46.259% complete
# 68 html version of FL COVID Rep 04-22-2020.html.html
# 46.939% complete
# 69 html version of FL COVID Rep 04-23-2020(PM).html.html
# 47.619% complete
# 70 html version of FL COVID Rep 04-23-2020.html.html
# 48.299% complete
# 71 html version of FL COVID Rep 04-24-2020(PM).html.html
# 48.98% complete
# 72 html version of FL COVID Rep 04-24-2020.html.html
# 49.66% complete
# 73 html version of FL COVID Rep 04-25-2020.html.html
# 50.34% complete
# 74 html version of FL COVID Rep 04-26-2020.html.html
# 51.02% complete
# 75 html version of FL COVID Rep 04-27-2020.html.html
# 51.701% complete
# 76 html version of FL COVID Rep 04-28-2020.html.html
# 52.381% complete
# 77 html version of FL COVID Rep 04-29-2020.html.html
# 53.061% complete
# 78 html version of FL COVID Rep 04-30-2020.html.html
# 53.741% complete
# 79 html version of FL COVID Rep 05-01-2020.html.html
# 54.422% complete
# 80 html version of FL COVID Rep 05-02-2020.html.html
# 55.102% complete
# 81 html version of FL COVID Rep 05-03-2020.html.html
# 55.782% complete
# 82 html version of FL COVID Rep 05-04-2020.html.html
# 56.463% complete
# 83 html version of FL COVID Rep 05-05-2020.html.html
# 57.143% complete
# 84 html version of FL COVID Rep 05-06-2020.html.html
# 57.823% complete
# 85 html version of FL COVID Rep 05-07-2020.html.html
# 58.503% complete
# 86 html version of FL COVID Rep 05-08-2020.html.html
# 59.184% complete
# 87 html version of FL COVID Rep 05-09-2020.html.html
# 59.864% complete
# 88 html version of FL COVID Rep 05-10-2020.html.html
# 60.544% complete
# 89 html version of FL COVID Rep 05-11-2020.html.html
# 61.224% complete
# 90 html version of FL COVID Rep 05-12-2020.html.html
# 61.905% complete
# 91 html version of FL COVID Rep 05-13-2020.html.html
# 62.585% complete
# 92 html version of FL COVID Rep 05-14-2020.html.html
# 63.265% complete
# 93 html version of FL COVID Rep 05-20-2020.html.html
# 63.946% complete
# 94 html version of FL COVID Rep 05-21-2020.html.html
# 64.626% complete
# 95 html version of FL COVID Rep 05-22-2020.html.html
# 65.306% complete
# 96 html version of FL COVID Rep 05-23-2020.html.html
# 65.986% complete
# 97 html version of FL COVID Rep 05-24-2020.html.html
# 66.667% complete
# 98 html version of FL COVID Rep 05-25-2020.html.html
# 67.347% complete
# 99 html version of FL COVID Rep 06-03-2020.html.html
# 68.027% complete
# 100 html version of FL COVID Rep 06-04-2020.html.html
# 68.707% complete
# 101 html version of FL COVID Rep 06-05-2020.html.html
# 69.388% complete
# 102 html version of FL COVID Rep 06-07-2020.html.html
# 70.068% complete
# 103 html version of FL COVID Rep 06-08-2020.html.html
# 70.748% complete
# 104 html version of FL COVID Rep 06-09-2020.html.html
# 71.429% complete
# 105 html version of FL COVID Rep 06-10-2020.html.html
# 72.109% complete
# 106 html version of FL COVID Rep 06-11-2020.html.html
# 72.789% complete
# 107 html version of FL COVID Rep 06-14-2020.html.html
# 73.469% complete
# 108 html version of FL COVID Rep 06-15-2020.html.html
# 74.15% complete
# 109 html version of FL COVID Rep 06-16-2020.html.html
# 74.83% complete
# 110 html version of FL COVID Rep 06-17-2020.html.html
# 75.51% complete
# 111 html version of FL COVID Rep 06-18-2020.html.html
# 76.19% complete
# 112 html version of FL COVID Rep 06-19-2020.html.html
# 76.871% complete
# 113 html version of FL COVID Rep 06-21-2020.html.html
# 77.551% complete
# 114 html version of FL COVID Rep 06-22-2020.html.html
# 78.231% complete
# 115 html version of FL COVID Rep 06-23-2020.html.html
# 78.912% complete
# 116 html version of FL COVID Rep 06-24-2020.html.html
# 79.592% complete
# 117 html version of FL COVID Rep 06-25-2020.html.html
# 80.272% complete
# 118 html version of FL COVID Rep 06-26-2020.html.html
# 80.952% complete
# 119 html version of FL COVID Rep 06-28-2020.html.html
# 81.633% complete
# 120 html version of FL COVID Rep 06-29-2020.html.html
# 82.313% complete
# 121 html version of FL COVID Rep 06-30-2020.html.html
# 82.993% complete
# 122 html version of FL COVID Rep 07-01-2020.html.html
# 83.673% complete
# 123 html version of FL COVID Rep 07-02-2020.html.html
# 84.354% complete
# 124 html version of FL COVID Rep 07-03-2020.html.html
# 85.034% complete
# 125 html version of FL COVID Rep 07-05-2020.html.html
# 85.714% complete
# 126 html version of FL COVID Rep 07-06-2020(PM).html.html
# 86.395% complete
# 127 html version of FL COVID Rep 07-06-2020.html.html
# 87.075% complete
# 128 html version of FL COVID Rep 07-07-2020.html.html
# 87.755% complete
# 129 html version of FL COVID Rep 07-08-2020.html.html
# 88.435% complete
# 130 html version of FL COVID Rep 07-09-2020.html.html
# 89.116% complete
# 131 html version of FL COVID Rep 07-10-2020(PM).html.html
# 89.796% complete
# 132 html version of FL COVID Rep 07-10-2020.html.html
# 90.476% complete
# 133 html version of FL COVID Rep 20-20-0606.html.html
# 91.156% complete
# 134 html version of FL COVID Rep 5-15-2020.html.html
# 91.837% complete
# 135 html version of FL COVID Rep 5-17-2020.html.html
# 92.517% complete
# 136 html version of FL COVID Rep 5-18-2020.html.html
# 93.197% complete
# 137 html version of FL COVID Rep 5-19-2020.html.html
# 93.878% complete
# 138 html version of FL COVID Rep 5-26-2020.html.html
# 94.558% complete
# 139 html version of FL COVID Rep 5-27-2020.html.html
# 95.238% complete
# 140 html version of FL COVID Rep 5-28-2020.html.html
# 95.918% complete
# 141 html version of FL COVID Rep 5-29-2020.html.html
# 96.599% complete
# 142 html version of FL COVID Rep 5-30-2020.html.html
# 97.279% complete
# 143 html version of FL COVID Rep 5-31-2020(PM).html.html
# 97.959% complete
# 144 html version of FL COVID Rep 5-31-2020.html.html
# 98.639% complete
# 145 html version of FL COVID Rep 6-12-2020.html.html
# 99.32% complete
# 146 html version of FL COVID Rep 6-13-2020.html.html
# 100.0% complete

# %% [markdown]
# > This is **outdated** code

# %%
header = ['COUNTY', 'AWAITING_TESTING', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME']
header1 = ['COUNTY', 'AWAITING_TESTING', 'INCONCLUSIVE', 'NEGATIVE', 'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED','FILE_NAME']

final_df = pd.DataFrame(columns=[header1])

file_counter = 0
for files in os.listdir(html_path):
    file_path = f'{html_path}/{files}'
    file =open(file_path,'r')
    file_n = len(os.listdir(html_path))
    page_soup = soup(file, 'lxml')
    table_soup = page_soup.findAll("table")
    row_counter = 0
    for tables in range(0, len(table_soup)):
        table_html = table_soup[tables]
        for row in table_html.findAll('tr'):
            row_length = len(row) -1
            counter = 1
            data_list = []
            for col in row.findAll('td'):

                if row_counter == 0:
                    data_list.append(col.text.replace(' ', '_').upper())
                
                else:
                    data_list.append(col.text.replace(',','').replace('%',''))
                
                if counter == row_length and row_counter == 0:
                    if row_length == 5:
                        df = pd.DataFrame(columns=[header])
                    elif row_length == 7 or row_length == 6: 
                        df = pd.DataFrame(columns=[header1])
                    else:
                        print('ERROR: Header Length Not Correct')
                        break                
                print(counter, len(header) , len(data_list))
                if counter == (len(header)-1) and row_counter > 0 and data_list[0] != 'County' and len(data_list[0]) != 0 and data_list[0].find('or by mai') < 0:
                    print('Data Row Met')                   
                    data_list.append(files.replace('.html','').strip('\n'))
                    print(counter, len(header) , len(data_list))
                    if row_length == 5:
                        print('Row length 5')
                        data = pd.DataFrame([data_list], columns = header)
                        print('Row length 5')
                    elif row_length == 7 or row_length == 6:
                        print('Row length 7 & 6')
                        data = pd.DataFrame([data_list], columns = [header1])
                        
                        print(df)
                    df = pd.concat([df,data])
 
                counter += 1
            row_counter += 1
    outfile = f'{txt_path}/{files.replace("html.html", "txt").replace("html version", "txt version")}'
    file_counter +=1
    df.to_csv(outfile,sep='\t', index = False)
    print(f'{round((file_counter/file_n)*100,3)}% complete')
    final_df = final_df.append(df, ignore_index=True)
# Out:
# 1 7 1
# 2 7 2
# 3 7 3
# 4 7 4
# 5 7 5
# 6 7 6
# 1 7 1
# 2 7 2
# 3 7 3
# 4 7 4
# 5 7 5
# 6 7 6
# Data Row Met
# 6 7 7
# Row length 5
# Row length 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-369-cf30bfe966c4> in <module>
#      48
#      49                         print(df)
# ---> 50                     df = pd.concat([df,data])
#      51
#      52                 counter += 1
#
# E:\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# E:\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2014                 values = values.view()
#    2015             b = b.make_block_same_class(values, placement=placement)
# -> 2016         elif is_uniform_join_units(join_units):
#    2017             b = join_units[0].block.concat_same_type(
#    2018                 [ju.block for ju in join_units], placement=placement
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\concat.py in is_uniform_join_units(join_units)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\concat.py in <genexpr>(.0)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# AttributeError: 'NoneType' object has no attribute 'is_extension'

# %%
import pandas as pd
try:
    mod_df = final_df.loc[~final_df['COUNTY'].str.contains('Total')].copy()
except:
    mod_df = pd.read_csv('Final COVID Only Dataset.txt',  sep='\t')

# %%
mod_df = mod_df.loc[~mod_df['COUNTY'].str.contains('Total')]
mod_df[mod_df['COUNTY']=='Total']
# Out:
# Empty DataFrame
# Columns: [COUNTY, AWAITING_TESTING, NEGATIVE, POSITIVE, PERCENT_POSITIVE, TOTAL_TESTED, FILE_NAME, INCONCLUSIVE]
# Index: []

# %% [markdown]
# Number of times COUNTY contained 'Sumter'

# %%
pd.value_counts(mod_df['COUNTY'].str.contains('Sumter')).to_frame()
# Out:
#        COUNTY
# False    9519
# True      140

# %% [markdown]
# # Data Manipulation

# %%
import numpy as np
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Cleaning

# %%
mod_df['NEGATIVE'] = pd.to_numeric(mod_df['NEGATIVE'])
mod_df['POSITIVE'] = pd.to_numeric(mod_df['POSITIVE'])
mod_df['PERCENT_POSITIVE'] = pd.to_numeric(mod_df['PERCENT_POSITIVE'])
mod_df['TOTAL_TESTED'] = pd.to_numeric(mod_df['TOTAL_TESTED'])
mod_df['INCONCLUSIVE'] = pd.to_numeric(mod_df['INCONCLUSIVE'])
mod_df['AWAITING_TESTING'] = pd.to_numeric(mod_df['AWAITING_TESTING'])

# %%
mod_df = mod_df.fillna(0)
mod_df['FILE_NAME'] =  mod_df['FILE_NAME'].str.strip('\n')
mod_df['DATE'] = mod_df['FILE_NAME'].str[29:39]
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 9802
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   COUNTY            9659 non-null   object
#  1   AWAITING_TESTING  9659 non-null   float64
#  2   NEGATIVE          9659 non-null   int64
#  3   POSITIVE          9659 non-null   float64
#  4   PERCENT_POSITIVE  9659 non-null   float64
#  5   TOTAL_TESTED      9659 non-null   float64
#  6   FILE_NAME         9659 non-null   object
#  7   INCONCLUSIVE      9659 non-null   float64
#  8   DATE              9659 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 754.6+ KB

# %% [markdown]
# Correcting an error in the regex process of reading and creating the report date observation.
# This problem originates in the code step where the html file are written

# %%
pd.value_counts(mod_df['DATE'].loc[mod_df['DATE'] == '20-20-0606']).to_frame()
# Out:
#             DATE
# 20-20-0606    67

# %%
pd.value_counts(mod_df['DATE'].loc[mod_df['DATE'].str.contains('20-')]).to_frame()
# Out:
#             DATE
# 04-20-2020   130
# 20-20-0606    67
# 03-20-2020    66
# 05-20-2020    65

# %%
# replacing the date observation '20-20-0606' with the corrected '06-06-2020'
mod_df.loc[mod_df['DATE'] == '20-20-0606', 'DATE'] = '06-06-2020'

# %% [markdown]
# ### Frequency of county n

# %%
county_n = mod_df['COUNTY'].value_counts()
print(county_n.value_counts().to_frame())
county_n.to_csv('Number of Obs Per County 7-11-20.txt', sep='\t')
# Out:
#      COUNTY
# 147      12
# 145       8
# 146       6
# 144       6
# 143       5
# 148       5
# 140       4
# 142       4
# 135       3
# 137       3
# 127       3
# 141       3
# 139       2
# 138       1
# 126       1
# 121       1
# 129       1

# %% [markdown]
# comparing the number of different lengths for filename there are

# %%
mod_df['len_file_name'] = pd.value_counts(mod_df['FILE_NAME'].apply(len))
pd.value_counts(mod_df['FILE_NAME'].apply(len)).to_frame(name='Freq of File Lengths')
# Out:
#     Freq of File Lengths
# 39                  6329
# 43                  2446
# 38                   816
# 42                    68

# %%
pd.value_counts(mod_df['FILE_NAME'].str.contains('PM')).to_frame()
# Out:
#        FILE_NAME
# False       7145
# True        2514

# %%
mod_df.sort_values(by=["COUNTY", "DATE", "FILE_NAME"], inplace=True)

# %%
mod_df["FILE_NAME"].head(20)
# Out:
# 10          html version of FL COVID Rep 03-16-2020
# 69          html version of FL COVID Rep 03-18-2020
# 122         html version of FL COVID Rep 03-19-2020
# 180         html version of FL COVID Rep 03-20-2020
# 374         html version of FL COVID Rep 03-21-2020
# 246     html version of FL COVID Rep 03-21-2020(PM)
# 313     html version of FL COVID Rep 03-21-2020(PM)
# 464         html version of FL COVID Rep 03-22-2020
# 397     html version of FL COVID Rep 03-22-2020(PM)
# 599         html version of FL COVID Rep 03-23-2020
# 533     html version of FL COVID Rep 03-23-2020(PM)
# 736         html version of FL COVID Rep 03-24-2020
# 667     html version of FL COVID Rep 03-24-2020(PM)
# 869         html version of FL COVID Rep 03-25-2020
# 805     html version of FL COVID Rep 03-25-2020(PM)
# 1001        html version of FL COVID Rep 03-26-2020
# 935     html version of FL COVID Rep 03-26-2020(PM)
# 1134        html version of FL COVID Rep 03-27-2020
# 1068    html version of FL COVID Rep 03-27-2020(PM)
# 1266        html version of FL COVID Rep 03-28-2020
# Name: FILE_NAME, dtype: object

# %%
pd.value_counts(mod_df['DATE'])
# Out:
# 03-21-2020    150
# 03-24-2020    136
# 04-11-2020    136
# 03-29-2020    134
# 04-04-2020    134
#              ...
# 06-03-2020     65
# 03-19-2020     58
# 03-16-2020     57
# 03-18-2020     54
# 07-09-2020     48
# Name: DATE, Length: 111, dtype: int64

# %%
mod_df['LAST_POS_COUNT'] = mod_df['POSITIVE'].shift(1)
mod_df['LAST_COUNTY'] = mod_df['COUNTY'].shift(1)
mod_df['LAST_NEG_COUNT'] = mod_df['NEGATIVE'].shift(1)
mod_df['NEW_NEGATIVES'] = mod_df['NEGATIVE'] - mod_df['LAST_NEG_COUNT']
mod_df['NEW_CASES'] = mod_df['POSITIVE'] - mod_df['LAST_POS_COUNT']
mod_df.loc[mod_df['COUNTY'] != mod_df["LAST_COUNTY"], 'NEW_CASES' ] = ''
mod_df.loc[mod_df['COUNTY'] != mod_df["LAST_COUNTY"], 'NEW_NEGATIVES' ] = ''

mod_df['NEW_CASES'] = pd.to_numeric(mod_df['NEW_CASES'])
mod_df['NEW_NEGATIVES'] = pd.to_numeric(mod_df['NEW_NEGATIVES'])
# mod_df.drop(labels=['LAST_POS_COUNT', 'LAST_COUNTY','LAST_NEG_COUNT'], inplace=True, axis=1)

# %%
dade = mod_df.loc[mod_df['COUNTY']=='Dade']
dade.to_csv('dade data.csv')
sumter = mod_df.loc[mod_df['COUNTY']=='Broward']
sumter.to_csv('Broward data.csv')
dade[['NEW_CASES', 'LAST_POS_COUNT', 'POSITIVE', 'DATE']].head(50)
# for cases in dade['NEW_CASES']:
#     print(cases, )
# Out:
#       NEW_CASES  LAST_POS_COUNT  POSITIVE        DATE
# 1           NaN           177.0      25.0  03-16-2020
# 58         51.0            25.0      76.0  03-18-2020
# 114        10.0            76.0      86.0  03-19-2020
# 173        37.0            86.0     123.0  03-20-2020
# 239        46.0           123.0     169.0  03-21-2020
# 306         0.0           169.0     169.0  03-21-2020
# 459         8.0           169.0     177.0  03-22-2020
# 391        51.0           177.0     228.0  03-22-2020
# 592        39.0           228.0     267.0  03-23-2020
# 525        11.0           267.0     278.0  03-23-2020
# 728        60.0           278.0     338.0  03-24-2020
# 659        29.0           338.0     367.0  03-24-2020
# 993       249.0           367.0     616.0  03-26-2020
# 927        38.0           616.0     654.0  03-26-2020
# 1059      215.0           654.0     869.0  03-27-2020
# 1257      134.0           869.0    1003.0  03-28-2020
# 1191      118.0          1003.0    1121.0  03-28-2020
# 1392       71.0          1121.0    1192.0  03-29-2020
# 1324      282.0          1192.0    1474.0  03-29-2020
# 1526      158.0          1474.0    1632.0  03-30-2020
# 1460       69.0          1632.0    1701.0  03-30-2020
# 1658      225.0          1701.0    1926.0  03-31-2020
# 1592      197.0          1926.0    2123.0  03-31-2020
# 1724       79.0          2123.0    2202.0  04-01-2020
# 1858      246.0          2202.0    2448.0  04-02-2020
# 1792      438.0          2448.0    2886.0  04-02-2020
# 1992      143.0          2886.0    3029.0  04-03-2020
# 1924      335.0          3029.0    3364.0  04-03-2020
# 2128      303.0          3364.0    3667.0  04-04-2020
# 2060      223.0          3667.0    3890.0  04-04-2020
# 2262      171.0          3890.0    4061.0  04-05-2020
# 2196       85.0          4061.0    4146.0  04-05-2020
# 2394      335.0          4146.0    4481.0  04-06-2020
# 2328      190.0          4481.0    4671.0  04-06-2020
# 2526      326.0          4671.0    4997.0  04-07-2020
# 2460      129.0          4997.0    5126.0  04-07-2020
# 2658      228.0          5126.0    5354.0  04-08-2020
# 2592      107.0          5354.0    5461.0  04-08-2020
# 2795      284.0          5461.0    5745.0  04-09-2020
# 2727      153.0          5745.0    5898.0  04-09-2020
# 2929      221.0          5898.0    6119.0  04-10-2020
# 2861      181.0          6119.0    6300.0  04-10-2020
# 3064      187.0          6300.0    6487.0  04-11-2020
# 2995      271.0          6487.0    6758.0  04-11-2020
# 3199       68.0          6758.0    6826.0  04-12-2020
# 3133      232.0          6826.0    7058.0  04-12-2020
# 3331      183.0          7058.0    7241.0  04-13-2020
# 3265      218.0          7241.0    7459.0  04-13-2020
# 3466       96.0          7459.0    7555.0  04-14-2020
# 3397      157.0          7555.0    7712.0  04-14-2020

# %%
fig,ax = plt.subplots()
mod_df['TOTAL_TESTED'].value_counts().plot(ax=ax, kind='bar')
plt.plot()
# Out:
# []

# %%
mod_df['TOTAL_TESTED'] = mod_df['NEGATIVE']  +  mod_df['POSITIVE']  + mod_df['INCONCLUSIVE'] + mod_df['AWAITING_TESTING']

# %%
mod_df['TOTAL_TESTED'].hist(bins=[0,500,501,1000,1001,5000,5001,20000])

# %%
mod_df.to_csv('Final COVID Only Dataset 7-11-20.txt', sep='\t', index=False)
mod_df.to_csv('Final COVID Only Dataset 7-11-20.csv', sep=',', index=False)

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-colorblind')
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_CASES'],'bo', label='New Cases')
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_NEGATIVES'], color='#332244',marker='o', linestyle='' , label= 'Negatives', alpha=0.2)
plt.title('Scatter Plot of number of Total Daily Test (X) and Number of New Cases (Y)')
plt.xlabel('Number of Tests')
plt.ylabel('Number of New Cases')
plt.legend()
plt.show()

# %%
mod_df['NEW_CASES'].hist(bins=[0,199,200,399, 400,1000,1001,5000,5001,10000])

# %%
mod_df[['TOTAL_TESTED','COUNTY']].describe()
# Out:
#         TOTAL_TESTED
# count    9659.000000
# mean     3637.450668
# std     17753.795273
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       282.500000
# max    397583.000000

# %% [markdown]
# ### Verifying that the shift worked correctly

# %%
mod_df[['COUNTY','NEGATIVE']].sum().to_frame()
# Out:
#                                                           0
# COUNTY    AlachuaAlachuaAlachuaAlachuaAlachuaAlachuaAlac...
# NEGATIVE                                        6.28858e+07

# %% [markdown]
# ### The extreme minimum and maximum might be  correct.
# ### In the case of negatives they are corrections.

# %%
mod_df['NEW_CASES'].describe().to_frame()
# Out:
#           NEW_CASES
# count   9591.000000
# mean       7.652174
# std      741.385345
# min   -33261.000000
# 25%        0.000000
# 50%        2.000000
# 75%        9.000000
# max    30186.000000

# %%
mod_df.filter(items=['NEW_CASES','COUNTY'], axis=1)
# Out:
#       NEW_CASES      COUNTY
# 0           NaN     Alachua
# 1           3.0     Alachua
# 2           0.0     Alachua
# 3           0.0     Alachua
# 4           0.0     Alachua
# ...         ...         ...
# 8235        5.0  Washington
# 8236        1.0  Washington
# 8237        3.0  Washington
# 8239       -1.0  Washington
# 8238      -33.0  Washington
#
# [8116 rows x 2 columns]

# %% [markdown]
# ## Observations where the number of new cases is less than 0

# %%
# Getting Counties with over 1000 cases reported in one day
high_case = mod_df[mod_df['NEW_CASES']> 1000]
high_case.sort_values(by='NEW_CASES', inplace=True, ascending =False)
print(high_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(100))
top_100 = pd.DataFrame(high_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(100))
# Out:
#             COUNTY  NEW_CASES        DATE
# 8536          Dade    30186.0  07-07-2020
# 8537       Broward    14006.0  07-07-2020
# 8539  Hillsborough    12067.0  07-07-2020
# 8540        Orange    11995.0  07-07-2020
# 8538    Palm Beach     9429.0  07-07-2020
# ...            ...        ...         ...
# 6612    Palm Beach     1122.0  06-03-2020
# 8273       Broward     1113.0  07-03-2020
# 8546       Manatee     1080.0  07-07-2020
# 7877        Orange     1062.0  06-26-2020
# 800         Orange     1035.0  03-25-2020
#
# [65 rows x 3 columns]
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [ipykernel_launcher.py:3]

# %%
# County
pd.value_counts(high_case['COUNTY'].head(100)).to_frame(name="County")
# Out:
#               County
# Dade              18
# Broward            9
# Orange             6
# Hillsborough       5
# Palm Beach         4
# Duval              3
# Collier            2
# Lee                2
# St. Lucie          1
# Lake               1
# Martin             1
# Manatee            1
# Brevard            1
# Pasco              1
# St. Johns          1
# Leon               1
# Seminole           1
# Osceola            1
# Escambia           1
# Volusia            1
# Sarasota           1
# Polk               1
# Pinellas           1
# Alachua            1

# %%
neg_case = mod_df[mod_df['NEW_CASES']< 0]
neg_case.sort_values(by='NEW_CASES', inplace=True)
print(neg_case[['COUNTY', 'NEW_CASES' ,'DATE']].head(20))
print(neg_case[['COUNTY', 'NEW_CASES' ,'DATE']].tail(20))
# Out:
#             COUNTY  NEW_CASES        DATE
# 8722          Dade   -33261.0  07-10-2020
# 8404          Dade   -23857.0  07-06-2020
# 8723       Broward   -15868.0  07-10-2020
# 8725  Hillsborough   -12343.0  07-10-2020
# 8726        Orange   -11579.0  07-10-2020
# 8405       Broward   -10986.0  07-06-2020
# 8408        Orange   -10489.0  07-06-2020
# 8407  Hillsborough   -10405.0  07-06-2020
# 8907          Dade   -10069.0   5-15-2020
# 8730         Duval    -9077.0  07-10-2020
# 8724    Palm Beach    -8727.0  07-10-2020
# 8406    Palm Beach    -7940.0  07-06-2020
# 8728      Pinellas    -6855.0  07-10-2020
# 8412         Duval    -6691.0  07-06-2020
# 8411      Pinellas    -6175.0  07-06-2020
# 8909    Palm Beach    -6115.0   5-15-2020
# 8727           Lee    -5018.0  07-10-2020
# 8908       Broward    -4704.0   5-15-2020
# 8409           Lee    -4652.0  07-06-2020
# 8731          Polk    -4641.0  07-10-2020
#           COUNTY  NEW_CASES        DATE
# 2712  Okeechobee       -1.0  04-08-2020
# 5592  Okeechobee       -1.0  05-05-2020
# 9279      Sumter       -1.0   5-27-2020
# 9038      Glades       -1.0   5-17-2020
# 5130      Glades       -1.0  04-28-2020
# 5220     Osceola       -1.0  04-30-2020
# 9661   Gilchrist       -1.0   5-31-2020
# 5166      Sumter       -1.0  04-29-2020
# 8061   Gilchrist       -1.0  06-29-2020
# 2111     Calhoun       -1.0  04-04-2020
# 6938   Gilchrist       -1.0  06-08-2020
# 7458     Calhoun       -1.0  06-18-2020
# 9765     Gadsden       -1.0   6-13-2020
# 5562   St. Lucie       -1.0  05-05-2020
# 3823   St. Lucie       -1.0  04-17-2020
# 2610   St. Lucie       -1.0  04-08-2020
# 1613       Pasco       -1.0  03-31-2020
# 3822       Pasco       -1.0  04-17-2020
# 8526    Bradford       -1.0  07-06-2020
# 533      Alachua       -1.0  03-23-2020
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [ipykernel_launcher.py:2]

# %%
pd.value_counts(neg_case.COUNTY)
# Out:
# St. Johns    34
# Collier      33
# Brevard      33
# Orange       33
# Total        33
#              ..
# Gulf          9
# Calhoun       8
# Lafayette     8
# Franklin      7
# Glades        6
# Name: COUNTY, Length: 69, dtype: int64

# %%
mod_df[mod_df['NEW_CASES']< 0].describe()
# Out:
#         Unnamed: 0  AWAITING_TESTING  INCONCLUSIVE      NEGATIVE  \
# count  1548.000000       1396.000000    779.000000  1.547000e+03
# mean   2962.465762         56.161175     28.057766  7.762021e+03
# std    2059.319013        195.983714    108.466943  4.923870e+04
# min     508.000000          0.000000      0.000000  0.000000e+00
# 25%    1519.750000          2.000000      1.000000  0.000000e+00
# 50%    2450.500000          8.000000      2.000000  5.010000e+02
# 75%    3804.250000         29.000000      7.000000  2.972000e+03
# max    8240.000000       1551.000000   1221.000000  1.264928e+06
#
#             POSITIVE  PERCENT_POSITIVE  TOTAL_TESTED  NEW_NEGATIVES  \
# count    1548.000000       1548.000000  7.080000e+02    1547.000000
# mean     1454.863695         89.988372  1.802531e+04   -1925.260504
# std      6297.361781        629.437455  7.702989e+04   29389.717986
# min         0.000000          0.000000  1.200000e+01 -845018.000000
# 25%        61.000000          5.000000  1.426250e+03     -31.000000
# 50%       179.500000          8.000000  3.333000e+03       0.000000
# 75%       584.000000         16.000000  9.616250e+03       0.000000
# max    101253.000000      12151.000000  1.338137e+06  110975.000000
#
#            NEW_CASES
# count    1548.000000
# mean     -484.986434
# std      5302.518945
# min   -129140.000000
# 25%       -39.000000
# 50%        -6.000000
# 75%        -2.000000
# max        -1.000000

# %%
# mod_df.drop('FILE_NAME1', axis = 1, inplace=True)
mod_df.columns
# Out:
# Index(['Unnamed: 0', 'COUNTY', 'AWAITING_TESTING', 'INCONCLUSIVE', 'NEGATIVE',
#        'POSITIVE', 'PERCENT_POSITIVE', 'TOTAL_TESTED', 'FILE_NAME', 'DATE',
#        'NEW_NEGATIVES', 'NEW_CASES'],
#       dtype='object')

# %% [markdown]
# # Messing around with matplotlib

# %%
plt.xkcd()
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_CASES'],'bo', label='New Cases')
plt.plot(mod_df['TOTAL_TESTED'],mod_df['NEW_NEGATIVES'], color='#332244',marker='o', linestyle='' , label= 'Negatives', alpha=0.2)
plt.title('Scatter Plot of number of Total Daily Test (X) and Number of New Cases (Y)')
plt.xlabel('Number of Tests')
plt.ylabel('Number of New Cases')
plt.legend()
plt.savefig('plot.png')
plt.show()
