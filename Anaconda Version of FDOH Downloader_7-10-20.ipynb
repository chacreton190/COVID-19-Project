# %% [markdown]
# # Downloading COVID Data From FloridaDisaster.ORG

# %% [markdown]
# ### To Do
# - [ ] Fix the problem where before doh reported 0 as 0 and not missing, I can't use the data
# - [X] Extract the page range 12-25
# - [X] Find the pages that contain the words "Coronavirus: All persons tested"
# - [X] Extract just those two pages pdf
# - [X] Export individual files to txt for storage

# %%
import ipykernel

# %%
from selenium import webdriver
import os
import wget
import PyPDF2 as pdf
from PyPDF2 import PdfFileReader, PdfFileWriter
import time
import textract
from pathlib import Path
import re
import pandas as pd
import datetime

# %%
chrome_path = r"chromedriver.exe"

# %% [markdown]
# ## Initializing driver element and finding

# %%
driver = webdriver.Chrome(chrome_path)

# %%
driver.get('https://floridadisaster.org/covid19/covid-19-data-reports/')
title = driver.title
time.sleep(3)
result = driver.find_elements_by_xpath("//a[@href]")

# %%
cwd = os.getcwd()

# %%
pdf_output_path = Path(f'{cwd}/Data/PDF')

# %% [markdown]
# ## Downloads the PDF Files from the FDEM Website

# %%
link_counter = 0
len_result = len(result)
for links in result:
    if links.text.find('Data Report') > 0:
        link_url = links.get_attribute('href')
        filename = wget.filename_from_url(link_url)
        if not os.path.exists(f'{pdf_output_path}/{filename}'):
            wget.download(link_url, out = f'{pdf_output_path}')
        link_counter +=1
        print (f'{round((link_counter * 2)/len_result,3)*100}% Complete',end='\r')
# Out:
# 0.498% Complete

# %% [markdown]
# ### Extracting PDF text

# %%
print(pdf_file)

# %%
county_list = ['Alachua', 'Dade','Baker', 'Bay', 'Bradford', 'Brevard', 'Broward', 'Calhoun', 'Charlotte', 'Citrus', 'Clay', 'Collier', 'Columbia', 'Dade', 'Desoto', 'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gadsden', 'Gilchrist', 'Glades', 'Gulf', 'Hamilton', 'Hardee', 'Hendry', 'Hernando', 'Highlands', 'Hillsborough', 'Holmes', 'Indian River', 'Jackson', 'Jefferson', 'Lafayette', 'Lake', 'Lee', 'Leon', 'Levy', 'Liberty', 'Madison', 'Manatee', 'Marion', 'Martin', 'Monroe', 'Nassau', 'Okaloosa', 'Okeechobee', 'Orange', 'Osceola', 'Palm Beach', 'Pasco', 'Pinellas', 'Polk', 'Putnam', 'Santa Rosa', 'Sarasota', 'Seminole', 'St. Johns', 'St. Lucie', 'Sumter', 'Suwannee', 'Taylor', 'Union', 'Unknown', 'UNKOWN', 'Volusia', 'Wakulla', 'Walton', 'Washington', 
]

# %%
pdf_output_path
# Out:
# WindowsPath('C:/Users/chacr/OneDrive/Documents/Coding/Python/USF/COVID-19 Project/Data/PDF')

# %%
output
# Out:
# 'Data/Unclean PDF/Unclean Extract from covid-daily-report-5.15.2020_.pdf (2020-07-06)'

# %% [markdown]
# ### Extracting a page range from PDF files (recursive)

# %%
#turn into a function
page_counter = 0
today = datetime.date.today()
file_num = len(os.listdir(pdf_output_path))
progress = 0
for files in os.listdir(pdf_output_path):
    progress += 1
    output = f'Data/Unclean PDF/({today}) Unclean Extract from {files}'
    pdf_writer = PdfFileWriter()
    pdf_file = open(f'{pdf_output_path}/{files}','rb')
    pdfreader = PdfFileReader(pdf_file)
    num_pages = pdfreader.numPages
    if num_pages < 23:
        up_limit = num_pages
    else:
        up_limit = 23
    for pages in range(3, up_limit):
        page =  pdfreader.getPage(pages)  
        if page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All persons with tests reported') > 0:
            pdf_writer.addPage(page)          
    with open(output, 'wb') as output_pdf:
        pdf_writer.write(output_pdf)
    print(f'{round(progress/file_num, ndigits=3)* 100}% Complete')
# Out:
# 0.7000000000000001% Complete
# 1.4000000000000001% Complete
# 2.1% Complete
# 2.7% Complete
# 3.4000000000000004% Complete
# 4.1000000000000005% Complete
# 4.8% Complete
# 5.5% Complete
# 6.2% Complete
# 6.800000000000001% Complete
# 7.5% Complete
# 8.200000000000001% Complete
# 8.9% Complete
# 9.6% Complete
# 10.299999999999999% Complete
# 11.0% Complete
# 11.600000000000001% Complete
# 12.3% Complete
# 13.0% Complete
# 13.700000000000001% Complete
# 14.399999999999999% Complete
# 15.1% Complete
# 15.8% Complete
# 16.400000000000002% Complete
# 17.1% Complete
# 17.8% Complete
# 18.5% Complete
# 19.2% Complete
# 19.900000000000002% Complete
# 20.5% Complete
# 21.2% Complete
# 21.9% Complete
# 22.6% Complete
# 23.3% Complete
# 24.0% Complete
# 24.7% Complete
# 25.3% Complete
# 26.0% Complete
# 26.700000000000003% Complete
# 27.400000000000002% Complete
# 28.1% Complete
# 28.799999999999997% Complete
# 29.5% Complete
# 30.099999999999998% Complete
# 30.8% Complete
# 31.5% Complete
# 32.2% Complete
# 32.9% Complete
# 33.6% Complete
# 34.2% Complete
# 34.9% Complete
# 35.6% Complete
# 36.3% Complete
# 37.0% Complete
# 37.7% Complete
# 38.4% Complete
# 39.0% Complete
# 39.7% Complete
# 40.400000000000006% Complete
# 41.099999999999994% Complete
# 41.8% Complete
# 42.5% Complete
# 43.2% Complete
# 43.8% Complete
# 44.5% Complete
# 45.2% Complete
# 45.9% Complete
# 46.6% Complete
# 47.3% Complete
# 47.9% Complete
# 48.6% Complete
# 49.3% Complete
# 50.0% Complete
# 50.7% Complete
# 51.4% Complete
# 52.1% Complete
# 52.7% Complete
# 53.400000000000006% Complete
# 54.1% Complete
# 54.800000000000004% Complete
# 55.50000000000001% Complete
# 56.2% Complete
# 56.8% Complete
# 57.49999999999999% Complete
# 58.199999999999996% Complete
# 58.9% Complete
# 59.599999999999994% Complete
# 60.3% Complete
# 61.0% Complete
# 61.6% Complete
# 62.3% Complete
# 63.0% Complete
# 63.7% Complete
# 64.4% Complete
# 65.10000000000001% Complete
# 65.8% Complete
# 66.4% Complete
# 67.10000000000001% Complete
# 67.80000000000001% Complete
# 68.5% Complete
# 69.19999999999999% Complete
# 69.89999999999999% Complete
# 70.5% Complete
# 71.2% Complete
# 71.89999999999999% Complete
# 72.6% Complete
# 73.3% Complete
# 74.0% Complete
# 74.7% Complete
# 75.3% Complete
# 76.0% Complete
# 76.7% Complete
# 77.4% Complete
# 78.10000000000001% Complete
# 78.8% Complete
# 79.5% Complete
# 80.10000000000001% Complete
# 80.80000000000001% Complete
# 81.5% Complete
# 82.19999999999999% Complete
# 82.89999999999999% Complete
# 83.6% Complete
# 84.2% Complete
# 84.89999999999999% Complete
# 85.6% Complete
# 86.3% Complete
# 87.0% Complete
# 87.7% Complete
# 88.4% Complete
# 89.0% Complete
# 89.7% Complete
# 90.4% Complete
# 91.10000000000001% Complete
# 91.8% Complete
# 92.5% Complete
# 93.2% Complete
# 93.8% Complete
# 94.5% Complete
# 95.19999999999999% Complete
# 95.89999999999999% Complete
# 96.6% Complete
# 97.3% Complete
# 97.89999999999999% Complete
# 98.6% Complete
# 99.3% Complete
# 100.0% Complete

# %% [markdown]
# # Converting the PDFs to html files

# %%
import pdftotree

input_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\Unclean PDF')
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html')
file_n = len(os.listdir(input_path))
file_ct = 0
error_list = []
for files in os.listdir(input_path):
    file_ct += 1
    print(files)
    new_file_name = files.replace('.pdf','')
    html = pdftotree.parse('Data\\Unclean PDF\\'+ files)
    try:
        with open(f"{output_path}/{new_file_name}.html",'w') as f:
            f.write(html)
    except: error_list.append(files)
    print(f'{round((file_ct/file_n),3)*100}% Complete') 
    break
print(error_list)

# %%
print(files.replace('.pdf',''))
# Out:
# (2020-07-06) Unclean Extract from state_reports_latest_6_12_2020

# %% [markdown]
# Importing and cleaning html

# %%
from pandas import read_html
import html5lib

# %%
driver = webdriver.Chrome(chrome_path)

# %%
import pypandoc
input_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\html')
output_path = Path('C:\\Users\\chacr\\OneDrive\\Documents\\Coding\\Python\\USF\\COVID-19 Project\\Data\\WORD2')

os.chdir(input_path)
for files in os.listdir(input_path):
    output = pypandoc.convert(source=files, format='html', to='docx', outputfile=f'{output_path}/{today}Converted Word Files{files}.docx', extra_args=['-RTS'])

# %%
df2 = pd.DataFrame(columns=['County','Num Col', 'Source'])
text_line_search = '\w+\s[\w,:]+\s.*\Z'#'^[\w+\s\D+].+\Z'
digit_search ='^\d.*\Z'
date_search = '^\w+\s\d.+'
#turn into a function
page_counter = 0

today = datetime.date.today()
for files in os.listdir(pdf_output_path):
    
    pdf_writer = PdfFileWriter()
    header = []
    print(files)
#     print(f'This is the start of the output for: {files}')
    headerset = 0
    data_row = []
    pdf_file = open(f'{pdf_output_path}/{files}','rb')
    pdfreader = PdfFileReader(pdf_file)
    num_pages = pdfreader.numPages
    if num_pages < 23:
        up_limit = num_pages
    else:
        up_limit = 23
    dfset =0
    county_added_list = []
    for pages in range(3, up_limit):
        
        datalines = 0
        page =  pdfreader.getPage(pages)
        
        if page.extractText().find('Coronavirus: PUI testing by county') > 0 or page.extractText().find('Coronavirus: All persons with tests reported') > 0:
            pdf_writer.addPage(page)
            page_text = page.extractText()
            print(page_text)
            col_num = 0
            index_num = 0
            for lines in page_text.split('\n'):
                line_n = len(page_text.split('\n'))
                write_line = 0
                if not re.match(text_line_search, lines, flags=0)and not re.match(date_search, lines, flags=0)and datalines == 0 and lines not in county_list and headerset !=1:
                    header.append(lines)         
                if re.match(date_search, lines, flags=0):
                    date = lines[0:12]
                if lines in county_list:
                    datalines = 1
                    data_row = []
                    data_row_app_n = 0
                    col_num=0
                if datalines == 1:
                    for names in header:
                        if names == 'Awaiting ':
                            header[index_num + 1] = 'Awaiting Testing'
                            header.pop(index_num)
                        if names == 'Percent ':
                            header[index_num + 1] = 'Pecent Positive'
                            header.pop(index_num) 
                        index_num += 1
                    headerset = 1
                    if headerset == 1 and dfset == 0 and len(lines) <30:       
                        df = pd.DataFrame(columns=header)
                        dfset = 1
                    if (len(data_row) + 1) <= len(header) and len(lines) < 20:
                        if len(lines) == 0:
#                             data_row[col_num] = 0
#                             data_row.append('0')
                            print('')

                        else:
                            data_row.append(lines)
                            data_row_app_n += 1
                            
                    if datalines == 1 and len(lines) > 2 and not re.match(date_search, lines, flags=0) and not re.match(text_line_search, lines, flags=0):
                        write_line = 1                        
                    if len(data_row) == len(header):
                        if data_row[0] not in county_added_list:
                            data = pd.DataFrame([data_row], columns=header)
                            df = pd.concat([df, data])
                            county_added_list.append(data_row[0])
                try:
                    data2 = [data_row[0], data_row_app_n, files]
                    data2df = pd.DataFrame([data2], columns=['County','Num Col', 'Source'] )
                    df2 = pd.concat([df2, data2df])
                except: IndexError
                col_num += 1
    df.describe()
    df.to_csv(f'data/TXT2/Text files of {files}.txt', index=False, sep="\t")
    output = f'Data/Unclean PDF/Unclean Extract from {files} ({today})'
    with open(output, 'wb') as output_pdf:
        pdf_writer.write(output_pdf)

        df2.describe 
#             print(df)
# Out:
# 06062020state_reports_latest.pdf
# Data verified as of Jun 6, 2020 at 10 AM
# Data in this report are provisional and subject to change.
# County
# Awaiting
# testing
# Inconclusive
# Negative
# Positive
# Percent
# positive
# Total tested
# Dade
# 74
# 198
# 180,521
# 19,299
# 10%
# 200,018
# Broward
# 21
# 62
# 113,619
# 7,690
# 6%
# 121,371
# Palm Beach
# 131
# 234
# 81,209
# 7,074
# 8%
# 88,517
# Hillsborough
# 31
# 79
# 66,805
# 2,643
# 4%
# 69,527
# Orange
# 16
# 53
# 78,560
# 2,256
# 3%
# 80,869
# Lee
# 23
# 6
# 31,530
# 2,253
# 7%
# 33,789
# Collier
# 16
# 8
# 17,792
# 1,968
# 10%
# 19,768
# Duval
# 77
# 28
# 61,197
# 1,764
# 3%
# 62,989
# Pinellas
# 201
# 16
# 47,185
# 1,532
# 3%
# 48,733
# Manatee
# 8
# 21,567
# 1,177
# 5%
# 22,752
# Polk
# 10
# 8
# 23,305
# 1,145
# 5%
# 24,458
# Escambia
# 1
# 7
# 21,445
# 879
# 4%
# 22,331
# Martin
# 8
# 7
# 9,888
# 849
# 8%
# 10,744
# Volusia
# 3
# 20
# 23,603
# 804
# 3%
# 24,427
# Osceola
# 44
# 14
# 15,217
# 741
# 5%
# 15,972
# Sarasota
# 2
# 5
# 20,284
# 669
# 3%
# 20,958
# St. Lucie
# 99
# 7
# 13,114
# 607
# 4%
# 13,728
# Hendry
# 2
# 2,639
# 552
# 17%
# 3,191
# Seminole
# 3
# 13
# 21,340
# 521
# 2%
# 21,874
# Charlotte
# 4
# 1
# 6,625
# 488
# 7%
# 7,114
# Brevard
# 1
# 2
# 25,348
# 453
# 2%
# 25,803
# Leon
# 12
# 4
# 17,323
# 438
# 2%
# 17,765
# Pasco
# 16
# 10
# 18,047
# 419
# 2%
# 18,476
# Alachua
# 7
# 24,130
# 396
# 2%
# 24,533
# Clay
# 5
# 10,602
# 396
# 4%
# 11,003
# Lake
# 9
# 11
# 19,369
# 321
# 2%
# 19,701
# Jackson
# 1
# 7
# 3,717
# 298
# 7%
# 4,022
# Gadsden
# 7
# 4,328
# 293
# 6%
# 4,628
# Marion
# 294
# 3
# 15,331
# 274
# 2%
# 15,608
# St. Johns
# 6
# 22
# 12,203
# 272
# 2%
# 12,497
# Sumter
# 23
# 5
# 4,479
# 261
# 6%
# 4,745
# Hamilton
# 1
# 2,020
# 261
# 11%
# 2,282
# Desoto
# 8
# 1
# 2,622
# 258
# 9%
# 2,881
# Santa Rosa
# 1
# 3
# 9,075
# 257
# 3%
# 9,335
# Okaloosa
# 6
# 8,507
# 253
# 3%
# 8,766
# Liberty
# 2
# 2,046
# 218
# 10%
# 2,266
# Flagler
# 4
# 5,331
# 195
# 4%
# 5,530
# Suwannee
# 2
# 2,370
# 174
# 7%
# 2,546
# Putnam
# 2
# 2
# 3,968
# 173
# 4%
# 4,143
# Columbia
# 4
# 6
# 4,094
# 171
# 4%
# 4,271
# Indian River
# 40
# 6,715
# 160
# 2%
# 6,875
# Highlands
# 3
# 3
# 4,732
# 143
# 3%
# 4,878
# Hardee
# 1
# 1,080
# 140
# 11%
# 1,221
# Walton
# 4
# 1,945
# 130
# 6%
# 2,079
# Citrus
# 2
# 3
# 5,862
# 125
# 2%
# 5,990
# Okeechobee
# 1,894
# 125
# 6%
# 2,019
# Bay
# 3
# 2
# 4,258
# 123
# 3%
# 4,383
# Hernando
# 1
# 5,150
# 122
# 2%
# 5,273
# Coronavirus: All persons with tests reported
# The table below includes persons with laboratory results that the Department of Health has received
# electronically or by mail/fax for Florida residents and non-Florida residents.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c69da6a0d9b2> in <module>
#      74                     if len(data_row) == len(header):
#      75                         if data_row[0] not in county_added_list:
# ---> 76                             data = pd.DataFrame([data_row], columns=header)
#      77                             df = pd.concat([df, data])
#      78                             county_added_list.append(data_row[0])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     472                     if is_named_tuple(data[0]) and columns is None:
#     473                         columns = data[0]._fields
# --> 474                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     475                     columns = ensure_index(columns)
#     476
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     459         return [], []  # columns if columns is not None else []
#     460     if isinstance(data[0], (list, tuple)):
# --> 461         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     462     elif isinstance(data[0], abc.Mapping):
#     463         return _list_of_dict_to_arrays(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     495     try:
#     496         result = _convert_object_array(
# --> 497             content, columns, dtype=dtype, coerce_float=coerce_float
#     498         )
#     499     except AssertionError as e:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     590         return arr
#     591
# --> 592     arrays = [convert(arr) for arr in content]
#     593
#     594     return arrays, columns
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in <listcomp>(.0)
#     590         return arr
#     591
# --> 592     arrays = [convert(arr) for arr in content]
#     593
#     594     return arrays, columns
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in convert(arr)
#     586     def convert(arr):
#     587         if dtype != object and dtype != np.object:
# --> 588             arr = lib.maybe_convert_objects(arr, try_float=coerce_float)
#     589             arr = maybe_cast_to_datetime(arr, dtype)
#     590         return arr
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in full(shape, fill_value, dtype, order)
#     323     if dtype is None:
#     324         dtype = array(fill_value).dtype
# --> 325     a = empty(shape, dtype, order)
#     326     multiarray.copyto(a, fill_value, casting='unsafe')
#     327     return a
#
# KeyboardInterrupt:

# %% [markdown]
# Eventually you need to clean up the formating of the filenames. They are very sloppy coming out of DOH.

# %%
print(page_text)
# Out:
# Data verified as of May 15, 2020 at 10 AM
# Data in this report are provisional and subject to change.
# County
# Awaiting
# testing
# Inconclusive
# Negative
# Positive
# Percent
# positive
# Total tested
# Coronavirus: All persons with tests reported
# The table below includes persons with laboratory results that the Department of Health has received
# electronically or by mail/fax for Florida residents and non-Florida residents.
# Nassau
# 2,137
# 653%2,202
# Madison
# 115346210%597Desoto
# 51,357
# 614%1,418
# Bradford
# 11,056
# 494%1,105
# Hardee
# 3123911%351Calhoun
# 13033811%342Okeechobee
# 21,018
# 333%1,053
# Wakulla
# 1717314%748Jefferson
# 272289%300Baker
# 581264%607Levy
# 963242%987Dixie
# 330226%352Union
# 447143%461Washington
# 373144%387Holmes
# 551112%562Glades
# 901010%100Gilchrist
# 35572%362Lafayette
# 10954%114Taylor
# 36231%365Franklin
# 21821%220Gulf
# 30610%307Total
# 1,409
# 747574,075
# 44,138
# 7%618,960

# %% [markdown]
# # Data Validation and Cleaning

# %%
type(pd.value_counts(df2['Source']))
seri = pd.value_counts(df2['Source'])
# print(type(seri))
n_reports = pd.DataFrame([seri])

n_reports.to_csv("Number of Rows For Each County found 7-6-20.csv", sep='\t')
# Out:
# <class 'pandas.core.series.Series'>

# %%
seri[0:]
# Out:
# covid-19-data---daily-report-2020-04-08-0954.pdf    509
# covid-19-data---daily-report-2020-03-28-1015.pdf    505
# covid-19-data---daily-report-2020-03-27-1819.pdf    505
# covid-19-data---daily-report-2020-04-05-1648.pdf    503
# covid-19-data---daily-report-2020-04-08-1702.pdf    503
#                                                    ...
# covid-daily-report_compressed_2_2020-05-22.pdf      207
# covid-daily-report-5.18.20-.pdf                     202
# covid-daily-report-5.17.20_.pdf                     199
# covid-daily-report-51620_compressed.pdf             196
# covid-daily-report-5.15.2020_.pdf                   191
# Name: Source, Length: 133, dtype: int64

# %%
testi = seri.to_frame().reset_index()

# %%
testi.to_csv("Number of Rows For Each County found 7-6-20.csv", sep='\t')

# %%
n_reports.shape
# Out:
# (133,)

# %%
n_reports.groupby().describe()
# Out:
# count    133.000000
# mean     435.368421
# std       88.755322
# min      191.000000
# 25%      444.000000
# 50%      456.000000
# 75%      503.000000
# max      509.000000
# Name: Source, dtype: float64

# %%
test2.head(7)
# Out:
#          County Num Col                            Source
# 0          Dade       1  06062020state_reports_latest.pdf
# 0          Dade       2  06062020state_reports_latest.pdf
# 0          Dade       3  06062020state_reports_latest.pdf
# 0          Dade       4  06062020state_reports_latest.pdf
# 0          Dade       5  06062020state_reports_latest.pdf
# 0          Dade       6  06062020state_reports_latest.pdf
# 0          Dade       7  06062020state_reports_latest.pdf
# 0       Broward       1  06062020state_reports_latest.pdf
# 0       Broward       2  06062020state_reports_latest.pdf
# 0       Broward       3  06062020state_reports_latest.pdf
# 0       Broward       4  06062020state_reports_latest.pdf
# 0       Broward       5  06062020state_reports_latest.pdf
# 0       Broward       6  06062020state_reports_latest.pdf
# 0       Broward       7  06062020state_reports_latest.pdf
# 0    Palm Beach       1  06062020state_reports_latest.pdf
# 0    Palm Beach       2  06062020state_reports_latest.pdf
# 0    Palm Beach       3  06062020state_reports_latest.pdf
# 0    Palm Beach       4  06062020state_reports_latest.pdf
# 0    Palm Beach       5  06062020state_reports_latest.pdf
# 0    Palm Beach       6  06062020state_reports_latest.pdf
# 0    Palm Beach       7  06062020state_reports_latest.pdf
# 0  Hillsborough       1  06062020state_reports_latest.pdf
# 0  Hillsborough       2  06062020state_reports_latest.pdf
# 0  Hillsborough       3  06062020state_reports_latest.pdf
# 0  Hillsborough       4  06062020state_reports_latest.pdf
# 0  Hillsborough       5  06062020state_reports_latest.pdf
# 0  Hillsborough       6  06062020state_reports_latest.pdf
# 0  Hillsborough       7  06062020state_reports_latest.pdf
# 0        Orange       1  06062020state_reports_latest.pdf
# 0        Orange       2  06062020state_reports_latest.pdf
# 0        Orange       3  06062020state_reports_latest.pdf
# 0        Orange       4  06062020state_reports_latest.pdf
# 0        Orange       5  06062020state_reports_latest.pdf
# 0        Orange       6  06062020state_reports_latest.pdf
# 0        Orange       7  06062020state_reports_latest.pdf
# 0           Lee       1  06062020state_reports_latest.pdf
# 0           Lee       2  06062020state_reports_latest.pdf
# 0           Lee       3  06062020state_reports_latest.pdf
# 0           Lee       4  06062020state_reports_latest.pdf
# 0           Lee       5  06062020state_reports_latest.pdf
# 0           Lee       6  06062020state_reports_latest.pdf
# 0           Lee       7  06062020state_reports_latest.pdf
# 0       Collier       1  06062020state_reports_latest.pdf
# 0       Collier       2  06062020state_reports_latest.pdf
# 0       Collier       3  06062020state_reports_latest.pdf
# 0       Collier       4  06062020state_reports_latest.pdf
# 0       Collier       5  06062020state_reports_latest.pdf
# 0       Collier       6  06062020state_reports_latest.pdf
# 0       Collier       7  06062020state_reports_latest.pdf

# %%
files_t = '06062020state_reports_latest.pdf'
date_format = ["r'^(\d{8})'","r'^([\d_]+)\w'"]
for date_types in date_format:
    print(date_types)
    output = re.findall(r'^(\d{8})', files_t, flags=0)[0]
    print(output)
#     report_date = f'{output[0]}{output[1]}-{output[2]}{output[3]}-{output[4]}{output[5]}{output[6]}{output[7]}'
print(report_date)
# print(report_date)
# if bool(re.search(r'^\d{8}',test, flags=0)) == True:
#     print('FUCK YEAR FUCKERS!!!!')
# Out:
# r'^(\d{8})'
# 06062020
# r'\w'
# 06062020
# 06-06-2020

# %%
print(data2)
# Out:
# ['Franklin', 7, 'state_reports_latest_6_12_2020.pdf']

# %%
test = pd.DataFrame([data2], columns=['County','Num Col', 'Source'] )

# %% [markdown]
# ## Extracting a page range from the PDFs

# %% [markdown]
# ### Steps:
# - [X] Open PDFs
# - [ ] Extract the page range 12-25
# - [ ] Convert that to a word document
# - [ ] Find the pages that contain the words "Coronavirus: All persons tested"
# - [ ] Extract just those two pages from the Word Document or the

# %%
print(os.listdir(pdf_output_path))

# %%
def ExtractPDF(input_path):
    import datetime
    today = datetime.date.today()
    pdf_writer = PdfFileWriter()
    
    for files in os.listdir(input_path):
        pdf_file = open(f'{input_path}/{files}','rb')
        print(files)
        print(pdf_file)
        
        print(f'This is the filename: {files}')
        pdfreader = PdfFileReader(pdf_file)
        num_pages = pdfreader.numPages
        for pages in range(12,26):
            page = pdfreader.getPage(pages)
#             print(page)
            pdf_writer.addPage(page)
        output = f'Data/Unclean PDF/Unclean Extract from {files} ({today})'
        with open(output, 'wb') as output_pdf:
            pdf_writer.write(output_pdf)
        break
ExtractPDF(pdf_output_path)

# %%
driver.close()

# %%
os.listdir(cwd)

# %%
print(cwd)
os.chdir('Data/Unclean PDF')
